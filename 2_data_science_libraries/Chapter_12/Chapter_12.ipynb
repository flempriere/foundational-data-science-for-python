# %% [markdown]
# # Chapter 12: Natural Language Toolkit
#
# ## Notes
#
# - A specialised field of data science is the study of text or *natural
#   language*
# - The Natural Language Toolkit ([NLTK](https://www.nltk.org/)) is a
#   python package for language processing
#
# ### NLTK Sample Texts
#
# - NTLTK comes with sample texts that can be downloaded and used
# - [Project Gutenburg](https://www.gutenberg.org/) is an online library
#   of E-Books
#   - Mostly Public Domain works
#   - NLTK packages a subset of this collection
# - `nltk.download` is used to download data into a local `nltk/corpora`
#   directory
#   - Data can then be imported for use
#   - Stored as a *corpus reader* object
#   - A useful feature to download is `punkt_tab`
#     - This is a tokenizer used to define sentence endings

# %%
import nltk

nltk.download("gutenberg")
nltk.download("punkt_tab")

from nltk.corpus import gutenberg

gutenberg
# Out:
# [nltk_data] Downloading package gutenberg to /home/runner/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/runner/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# <PlaintextCorpusReader in '/home/runner/nltk_data/corpora/gutenberg'>

# %% [markdown]
# > **Tip**
# >
# > **Corpus Readers**
# >
# > Corpus readers are designed to read a specific set of texts. There are
# > different corpus readers for different types of text. For plain text
# > like books typically the corpus reader is plain text via the
# > `PlainTextCorpusReader`.
#
# - Once a corpus is loaded, individual texts can be listed via the
#   `fileids` method.
#   - Text’s are stored as files

# %%
from nltk.corpus import gutenberg

gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# - Corpus readers support various mechanisms for analysing text
#   - Text can be loaded broken into
#     - Words
#     - Sentences
#     - Paragraphs
# - For example, loading Shakespeare’s *Julius Caesar*

# %%
from nltk.corpus import gutenberg

caesar = gutenberg.sents("shakespeare-caesar.txt")

caesar
# Out:
# [['[', 'The', 'Tragedie', 'of', 'Julius', 'Caesar', 'by', 'William', 'Shakespeare', '1599', ']'], ['Actus', 'Primus', '.'], ...]

# %% [markdown]
# - As mentioned to parse text into sentences you need to use a
#   *tokenizer*
# - Punkt is a general-purpose tokenizer
#   - Designed to work across multiple languages
# - As mentioned before NLTK will download into a local `nltk_data` folder
#   - It is divided up into,
#     1.  *corpora*
#         - Texts to analyse
#     2.  *tokenizers*
#         - Text analysis engines

# %%
# !ls ~/nltk_data
# Out:
# corpora  tokenizers

# %% [markdown]
# - Inside the corpora directory we can see the text set’s we have
#   downloaded

# %%
# !ls ~/nltk_data/corpora
# Out:
# brown      gutenberg      names      stopwords
# brown.zip  gutenberg.zip  names.zip  stopwords.zip

# %% [markdown]
# - and of-course the text’s they contain

# %%
# !ls ~/nltk_data/corpora/gutenberg
# Out:
# README             burgess-busterbrown.txt  milton-paradise.txt
# austen-emma.txt        carroll-alice.txt    shakespeare-caesar.txt
# austen-persuasion.txt  chesterton-ball.txt  shakespeare-hamlet.txt
# austen-sense.txt       chesterton-brown.txt shakespeare-macbeth.txt
# bible-kjv.txt          chesterton-thursday.txt  whitman-leaves.txt
# blake-poems.txt        edgeworth-parents.txt
# bryant-stories.txt     melville-moby_dick.txt

# %% [markdown]
# - Inside the tokenizers directory we can see the tokenizers we’ve
#   downloaded

# %%
# !ls ~/nltk_data/tokenizers
# Out:
# punkt_tab  punkt_tab.zip

# %% [markdown]
# - and within the `punkt_tab` directory we can see the languages it
#   supports

# %%
# !ls ~/nltk_data/tokenizers/punkt_tab
# Out:
# README  dutch     finnish  greek      norwegian   russian  swedish
# czech   english   french   italian    polish      slovene  turkish
# danish  estonian  german   malayalam  portuguese  spanish

# %% [markdown]
# ### Frequency Distributions
#
# - The `nltk.freqDist` class can be used to examine the occurrences of
#   words within a text
# - Can look at,
#   - Which words are the most frequent
#   - How many unique words there are
#   - etc.

# %%
import nltk
from nltk.corpus import gutenberg

caesar = gutenberg.words("shakespeare-caesar.txt")
caesar_dist = nltk.FreqDist(caesar)
caesar_dist.most_common(15)
# Out:
# [(',', 2204),
#  ('.', 1296),
#  ('I', 531),
#  ('the', 502),
#  (':', 499),
#  ('and', 409),
#  ("'", 384),
#  ('to', 370),
#  ('you', 342),
#  ('of', 336),
#  ('?', 296),
#  ('not', 249),
#  ('a', 240),
#  ('is', 230),
#  ('And', 218)]

# %% [markdown]
# - NLTK defines a word as any piece of text that is not whitespace
# - This means punctuation is counted as separate “words”
# - To filter out punctuation we can use the built-in `string` library
#   - Contains a `punctuation` attribute
#     - String containing every punctuation character
# - For example, to filter the punctuation out of the above example, we
#   can,

# %%
import string

import nltk
from nltk.corpus import gutenberg

print("punctuation:", string.punctuation)

caesar = gutenberg.words("shakespeare-caesar.txt")

caesar_filtered = [word for word in caesar if word not in string.punctuation]

print("Number of punctuation symbols:", len(caesar) - len(caesar_filtered))

caesar_dist = nltk.FreqDist(caesar_filtered)
caesar_dist.most_common(15)
# Out:
# punctuation: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Number of punctuation symbols: 4960
# [('I', 531),
#  ('the', 502),
#  ('and', 409),
#  ('to', 370),
#  ('you', 342),
#  ('of', 336),
#  ('not', 249),
#  ('a', 240),
#  ('is', 230),
#  ('And', 218),
#  ('d', 215),
#  ('in', 204),
#  ('that', 200),
#  ('Caesar', 189),
#  ('my', 188)]

# %% [markdown]
# > **Note**
# >
# > **List Comprehension**
# >
# > The syntax we’ve used above is called a list comprehension, and is
# > designed for quickly creating a list based on the elements of an
# > existing collection. You could achieve the same with a simple `for`
# > loop as described in [Chapter
# > 5](../../1_learning-python-in-a-notebook-environment/Chapter_05/Chapter_05.qmd),
# > but the list comprehension syntax is more compact. List comprehensions
# > will be discussed in more detail later.
#
# - Another common filtering step is remove common words that don’t
#   provide much contextual understanding
#   - These are simple words like “the”, “and”, “as” etc.
#   - Commonly referred to as *stopwords*
# - NLTK provides the `stopwords` corpus which can be downloaded to
#   perform this filtering

# %%
import nltk

nltk.download("stopwords")

from nltk.corpus import stopwords

english_stopwords = stopwords.words("english")
english_stopwords[:10]  # show the first ten stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/runner/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %% [markdown]
# - Once we’ve downloaded the `stopwords` corpus we can use it to filter
#   out the these common words from our analysis of Julius Caesar.

# %%
import string

import nltk
from nltk.corpus import gutenberg, stopwords

caesar = gutenberg.words("shakespeare-caesar.txt")

# filter out punctuation
caesar_punctuation_filtered = [
    word for word in caesar if word not in string.punctuation
]

# filter out stopwords
english_stopwords = stopwords.words("english")
caesar_filtered = [
    word
    for word in caesar_punctuation_filtered
    if word.lower() not in english_stopwords
]

print("Number of stop words:", len(caesar_punctuation_filtered) - len(caesar_filtered))

caesar_dist = nltk.freqDist(caesar_filtered)
caesar_dist.most_common(15)
# Out:
# Number of stop words: 9746

# %% [markdown]
# - With the extraneous words removed we can start deriving insight into
#   the text
#   - For example, the above shows Caesar and Brutus are mentioned the
#     most out of any other characters
# - The `freqDist` class also comes with a bunch of other methods for
#   analysing a text

# %%
import string

import nltk
from nltk.corpus import gutenberg, stopwords

caesar = gutenberg.words("shakespeare-caesar.txt")

# filter out punctuation
caesar_filtered = [word for word in caesar if word not in string.punctuation]

# filter out stopwords
english_stopwords = stopwords.words("english")
caesar_filtered = [
    word for word in caesar_filtered if word.lower() not in english_stopwords
]

caesar_dist = nltk.FreqDist(caesar_filtered)


print("caesar_dist.max():", caesar_dist.max())  # The word with the most appearances

print(
    "caesar_dist['Cassi']:", caesar_dist["Cassi"]
)  # perform a key lookup for the count of a particular word

print(
    "caesar_dist.freq('Cassi'):", caesar_dist.freq("Cassi")
)  # Count of the word divided by the total count

print("caesar_dist.N():", caesar_dist.N())  # The number of words

print(
    "caesar_dist.tabulate(10):\n", caesar_dist.tabulate(10)
)  # Display the count for the top 10 words

# plot the 10 most frequent words
caesar_dist.plot(10)
# Out:
# caesar_dist.max(): Caesar
# caesar_dist['Cassi']: 107
# caesar_dist.freq('Cassi'): 0.009616248764267098
# caesar_dist.N(): 11127
#  Caesar  Brutus     Bru    haue   shall   Cassi    thou Cassius  Antony    know
#     189     161     153     128     107     107     100      85      75      66
# caesar_dist.tabulate(10):
#  None

# %% [markdown]
# ### Text Objects
#
# - The `Text` class is provides functionality for exploring a text
# - Is initialised from a list of words

# %%
import nltk
from nltk.corpus import gutenberg
from nltk.text import Text

caesar = gutenberg.words("shakespeare-caesar.txt")
caesar_t = Text(caesar)
type(caesar_t)
# Out:
# nltk.text.Text

# %% [markdown]
# - `Text` provides a number of useful methods for studying a text
#   - `concordance`
#     - Show’s the context around a given word
#   - `collocations`
#     - Displays words commonly appearing together
#   - `similar` finds words appearing in a similar context
#   - `findall` returns all text matching a regular expression
#     - Use `<` and `>` to define word boundaries
#     - `*` as a match anything wildcard
#   - `dispersion_plot` compares where words appear in a given text

# %%
import nltk
from nltk.corpus import gutenberg
from nltk.text import Text

caesar = gutenberg.words("shakespeare-caesar.txt")
caesar_t = Text(caesar)

print(
    "caesar_t.concordance('Antony', lines=5):\n",
    caesar_t.concordance("Antony", lines=5),
)

print("caesar_t.collocations(num=4):")
caesar_t.collocations(num=4)

print("caesar_t.similar('Caesar'):")
caesar_t.similar("Caesar")

print("caesar_t.findall(r'<O><C.*>'):"
caesar_t.findall(r"<O><C.*>"))

caesar_t.dispersion_plot(["Caesar", "Antony", "Brutus", "Cassi"])

# %% [markdown]
# ### Classifying Text
#
# - Classifier classes are designed to label text data
# - To label text data typically you need prepare data with category or
#   label features
#   - Can then build a model (See [Chapter
#     11](../Chapter_11/Chapter_11.qmd))
# - This section steps through a simple example using the [Brown
#   Corpus](http://korpus.uib.no/icame/brown/bcm.html)
#   - This corpus simplifies the process since the data comes pre-labelled
# - For example, let us consider attempting to label paragraphs as either
#   *editorial* or *fiction*
#   - We might do this based on the appearance of certain words
#   - Here a simple dictionary `tell_words`
# - First need to download our data

# %%
import nltk

nltk.download('brown')

from nltk.corpus import brown

brown
# Out:
# [nltk_data] Downloading package brown to /home/runner/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# <CategorizedTaggedCorpusReader in '/home/runner/nltk_data/corpora/brown'>

# %% [markdown]
# - Now we need to load our data, clean it and define our `tell_words`
#   dictionary

# %%
import nltk
from nltk.corpus import brown, stopwords

tell_words = {
    "american",
    "city",
    "congress",
    "country",
    "county",
    "editor",
    "fact",
    "government",
    "national",
    "nuclear",
    "party",
    "peace",
    "political",
    "power",
    "president",
    "public",
    "state",
    "states",
    "united",
    "war",
    "washington",
    "world",
    "big",
    "church",
    "every",
    "eyes",
    "face",
    "felt",
    "found",
    "god",
    "hand",
    "head",
    "home",
    "house",
    "knew",
    "moment",
    "night",
    "room",
    "seemed",
    "stood",
    "think",
    "though",
    "thought",
    "told",
    "voice",
}

english_stopwords = stopwords.words("english")
editorial_paragraphs = brown.paras(categories="editorial")  # load editorial paragraphs
fiction_paragraphs = brown.paras(categories="fiction")  # load only fiction paragraphs

print("There are", len(editorial_paragraphs), "editorial paragraphs")
print("There are", len(fiction_paragraphs), "fiction paragraphs")
# Out:
# There are 1003 editorial paragraphs
# There are 1043 fiction paragraphs

# %% [markdown]
# - Each paragraph is a list of lists
#   - Each sub-list is a sentence in a paragraph
# - For this analysis we only care about the unique words in a paragraph
#   - So we want to flatten each paragraph into the set of words it
#     contains
#   - We can do this with a simple function and a *set comprehension* (See
#     the earlier discussion of list comprehensions)
#     - We’ve added *type hints* to help the reader understand what is
#       happening to the dimensions of the data

# %%
import nltk
from nltk.corpus import brown, stopwords
from typing import Sequence

tell_words = {
    "american",
    "city",
    "congress",
    "country",
    "county",
    "editor",
    "fact",
    "government",
    "national",
    "nuclear",
    "party",
    "peace",
    "political",
    "power",
    "president",
    "public",
    "state",
    "states",
    "united",
    "war",
    "washington",
    "world",
    "big",
    "church",
    "every",
    "eyes",
    "face",
    "felt",
    "found",
    "god",
    "hand",
    "head",
    "home",
    "house",
    "knew",
    "moment",
    "night",
    "room",
    "seemed",
    "stood",
    "think",
    "though",
    "thought",
    "told",
    "voice",
}

# Load the datasets
english_stopwords = stopwords.words("english")
editorial_paragraphs = brown.paras(categories="editorial")  # load editorial paragraphs
fiction_paragraphs = brown.paras(categories="fiction")  # load only fiction paragraphs


# Clean the data format


def flatten(paragraph: Sequence[Sequence[str]]) -> Set[str]:
    return {word for sentence in paragraph for word in sentence}


editorial_paragraphs_flattened = [
    flatten(paragraph) for paragraph in editorial_paragraphs
]
fiction_paragraphs_flattened = [flatten(paragraph) for paragraph in fiction_paragraphs]

print(
    "Flattened editorial paragraphs:\n",
    "\n".join([str(paragraph) for paragraph in editorial_paragraphs_flattened]),
)
# Out:
# Flattened editorial paragraphs:
#  {'a', 'brought', ',', 'an', 'to', 'much', 'and', 'struggle', 'adjourns', 'met', 'showdown', 'abandoning', 'in', 'governor', 'schools', 'from', 'risk', 'good', 'convened', 'Assembly', 'performed', 'was', 'faced', 'issue', 'on', 'decision', 'atmosphere', 'conjunction', 'which', 'The', 'of', 'day', 'with', 'squarely', 'not', 'It', 'crisis', 'public', 'education', 'it', 'session', 'has', 'today', 'General', 'the', 'immediately', '.'}
# {'a', 'provide', ',', 'budget', 'to', 'followed', 'procedures', 'and', 'strengthening', 'budgeting', 'fight', 'in', 'There', 'final', 'historic', 'legislators', 'need', 'decided', 'went', 'Assembly', 'tackle', 'decision', 'but', 'which', 'The', 'appropriations', 'opened', 'they', 'executive', 'for', 'way', 'has', 'been', 'information', 'General', 'the', '.', 'powers'}
# {'a', 'state', ',', 'to', 'finance', 'and', 'now', 'crisis-to-crisis', 'in', 'ways', 'if', 'become', 'from', 'government', 'them', 'This', 'is', 'have', 'two', 'of', 'may', 'programs', 'crisis', 'musts', 'for', 'avoid', 'session', 'insured', 'financial', '.', 'planning', 'the', 'next', 'few', 'years', 'Long-range', 'instance'}
# {'acceptance', 'an', ',', 'state', 'and', 'responsibility', 'all', 'bond', 'shuffle', 'law', 'legislation', 'Some', 'In', 'teacher', 'in', 'by', 'maintenance', 'can', 'municipalities', 'passed', 'at', 'some', 'limit', 'road', 'increase', 'await', 'passage', 'city', 'action', 'good', 'roads', 'repeal', 'was', 'age', 'on', 'issue', 'outside', 'college', 'drag', 'of', 'ban', 'same', 'as', 'auto', 'limits', 'racing', 'for', 'pensions', 'rate', 'Certainly', 'bills', 'the', 'were', 'turmoil', 'other', 'applaud', 'future', 'school', '.', 'lost', 'title'}
# {'a', 'Only', 'taken', ',', 'problems', 'to', 'state', 'and', 'such', 'made', 'No', 'unit', 'attacking', 'in', 'reappraisal', 'however', 'ending', 'action', 'penal', 'start', 'was', 'tax', 'issue', 'question', 'major', 'token', 'outright', 'banning', 'fireworks', 'of', 'as', 'system', 'attracting', 'fee', 'reform', 'has', 'been', 'its', '.', 'the', 'county', 'companion', 'industry', 'sales', 'on', 'modification'}
# {'state', 'spared', 'and', 'look', 'usual', 'made', 'in', 'schools', 'from', 'anything', 'South', 'time', 'on', 'like', 'resolutions', 'have', 'but', 'questions', 'legislature', "''", 'past', 'us', 'of', 'The', 'which', 'appropriations', 'empire', 'Fortunately', 'most', 'spate', 'it', 'its', 'the', 'expended', 'silly', '.', 'Georgia', '``'}
# {'will', ',', 'problems', 'to', 'studying', 'and', 'all', 'without', 'now', 'very', 'their', 'In', 'legislation', 'trust', 'answers', 'congratulate', 'record', 'come', 'up', 'real', 'good', 'fiscal', 'on', 'entire', 'Senate', 'of', 'with', 'political', 'membership', 'year', 'put', 'minds', "Georgia's", 'its', 'the', 'between', 'next', 'economic', 'House', 'heroics', 'we', 'We', 'social', '.', 'interim'}
# {'a', 'Women', ',', 'and', 'stands', 'money', "It's", 'now', 'use', 'in', 'windup', 'regularly', 'contributions', 'drive', 'good', 'is', 'fund', 'League', 'Voters', 'of', 'The', 'side', '40', 'it', 'right', 'financial', 'its', '.', 'the', 'admitting', 'inviting', 'on', 'proudly'}
# {'are', 'to', "Jefferson's", 'their', "people's", 'one', 'organization', 'out', 'spirit', 'whose', 'old', 'that', 'alive', 'dedicated', 'cherish', 'but', 'attention', "''", 'of', 'movement', 'suffrage', 'Keep', 'grew', 'These', 'must', 'the', 'dictum', 'women', '.', 'Thomas', '``'}
# {',', 'to', 'Congress', 'and', 'all', 'wolves', 'become', 'shall', 'If', "''", 'you', 'they', 'inattentive', 'assemblies', 'public', 'governors', 'affairs', 'Jefferson', 'said', 'once', 'the', 'judges', 'I', '.', '``'}
# {'a', 'harder', 'are', ',', 'And', 'to', 'and', 'especially', 'issues', 'cons', 'workers', 'choice', 'pros', 'in', 'out', 'search', 'willing', 'available', 'great', 'them', 'is', 'league', 'regularity', 'on', 'Newspapermen', 'wade', 'complex', 'attention', 'make', 'aware', 'of', 'The', 'with', 'gives', 'analysis', 'public', 'most', 'affairs', 'side', 'politicians', 'expert', 'right', 'the', 'takes', 'penetrating', '.', 'more', 'stand'}
# {'keep', 'Valley', 'are', 'members', 'to', 'and', 'interested', 'do', 'peeled', 'their', 'Development', 'months', 'Commission', 'in', 'industrial', 'progress', 'toward', 'that', 'development', 'Coosa', 'Area', 'counties', 'Planning', '13', 'of', 'ahead', 'eyes', 'would', 'northwest', 'for', 'Cities', 'Look', 'the', 'well', '.', 'Georgia'}
# {'a', 'will', 'state', 'budget', 'Vandiver', ',', 'to', 'an', 'and', 'authorized', 'grant', 'work', 'staff', 'be', 'by', '$83,750', 'in', 'Then', 'industrial', 'expects', 'Coupling', 'development', 'Rome', 'area', 'full-time', 'Gov.', 'sign', 'of', 'with', 'program', 'own', 'contract', 'group', 'March', 'Tech.', 'for', '$30,000', 'office', 'its', 'established', 'the', 'planning', 'research', '.', 'Georgia', 'Tech', 'five-member'}
# {'through', 'an', 'and', 'results', 'effort', 'promise', 'be', 'by', 'in', 'one', 'undertaking', 'can', 'banding', 'go-it-alone', 'abundant', 'that', 'area-wide', 'neighbors', 'helps', 'together', 'recognizes', 'The', 'than', 'what', 'It', 'fact', 'has', 'its', 'better', 'accomplished', 'the', 'county', '.', 'approach'}
# {'a', ',', 'United', 'States', 'in', 'existed', 'that', 'Dulles', 'theory', 'removes', 'retaliation', 'grave', 'defense', 'of', 'The', 'idea', 'Rusk', 'danger', 'has', 'strengthens', 'balanced', 'the', 'massive', 'replacing', '.', 'belief'}
# {'deter', 'and', 'use', ';', 'our', 'in', 'lay', 'that', 'delusion', 'A-bombs', 'is', 'sound', 'theory', 'was', 'enough', 'believing', 'of', 'The', 'not', 'own', 'would', 'nuclear', 'danger', 'hers', 'the', 'American', 'deterrence', "Russia's", '.'}
# {'a', ',', 'to', 'kind', 'besides', 'much', 'strength', 'fight', 'limiting', 'that', 'ability', 'country', 'This', 'strategy', 'By', 'have', 'war', 'of', 'possibility', 'would', 'any', 'nuclear', 'this', 'its', 'the', 'American', 'limited', 'heightened', '.', 'too', 'we'}
# {'a', 'except', ',', 'easily', 'did', 'because', 'our', 'in', 'could', 'also', 'guess', 'extremity', 'war', 'ultimate', 'weakened', 'not', 'It', 'diplomatic', 'nuclear', 'the', 'stance', 'desire', '.', 'Russia', 'we'}
# {'left', 'to', 'Soviets', 'of', 'with', 'the', 'low-grade', 'brushfire', 'impunity', 'plenty', 'aggressions', 'This', 'leeway', 'considerable', '.', 'start'}
# {',', 'Secretary', 'to', 'wars', 'and', 'muscle', 'builds', 'State', 'fight', 'gearing', 'our', 'bluff', 'junks', 'conventional', 'military', 'safety', 'By', 'but', 'maintaining', 'forces', 'of', 'into', 'Rusk', 'position', 'nuclear', 'deterrent', 'greater', 'the', 'American', '.', 'too', 'more', 'brinkmanship'}
# {'a', 'balance', 'budget', 'to', 'and', 'DeKalb', 'promise', 'one', 'carries', 'increase', 'shows', 'record', 'beam', 'is', 'tax', 'on', 'make', 'of', 'with', 'no', "DeKalb's", 'for', 'it', '.', 'the', 'county', '1961'}
# {'a', ',', 'wage', 'and', 'such', 'welfare', 'level', 'includes', 'efforts', 'in', 'maintenance', 'industrial', 'minimum', 'several', 'at', 'development', 'increased', 'jobs', 'beefed-up', 'creation', 'of', 'as', 'protection', 'financing', 'sanitation', 'services', 'fire', 'It', 'raise', 'executive', 'for', 'new', 'essential', '.', 'the', 'county', 'road', 'health', 'expenditures'}
# {'a', ',', 'to', 'growth', 'and', 'such', 'without', 'expansion', 'commissioners', 'Chairman', 'O.', 'obtained', 'be', 'by', 'taxes', 'in', 'can', 'trust', 'he', 'that', 'That', 'part', 'officials', 'is', 'sound', 'Emmerich', 'tax', 'was', 'due', 'fiscal', 'headed', 'digest', 'of', 'placed', 'Charles', 'public', 'raise', 'board', 'given', '.', 'the', 'planning', 'county', 'other', 'well', 'on', 'demonstrating', 'who'}
# {',', 'Secretary', 'to', '``', 'should', 'Zanzibar', 'and', 'carrying', 'diplomacy', 'learning', 'State', 'be', 'Then', 'in', 'signs', 'he', 'U.S.', 'Africans', 'imperialists', 'home', 'up', 'observed', 'is', 'denounced', 'Soapy', 'bound', 'Somewhere', 'Chin', 'Africa', "''", 'go', 'British', 'us', 'of', 'Touring', 'rapidly', 'love', 'Mennen', 'for', 'promptly', 'new', 'him', 'Assistant', 'Williams', 'arrived', 'saying', 'the', 'American', 'found', 'somebody', '.', 'G.', 'difficulties'}
# {"state's", 'budget', 'construction', 'backs', 'in', 'reflected', 'dollars', 'confidence', 'record', "Company's", 'is', 'with', 'company', 'year', 'for', 'this', 'Confidence', 'Power', 'the', 'economic', 'future', '.', 'Georgia'}
# {'a', 'amount', 'forecasts', 'will', 'encourage', 'to', 'growth', 'and', 'meaning', 'electrical', 'sufficient', 'industrialization', 'that', 'meet', 'rapid', 'good', 'only', 'is', 'power', 'have', 'but', 'large', 'of', 'The', 'not', 'It', 'does', 'demands', 'know', 'rate', 'its', 'the', 'research', 'continue', 'firm', '.', 'Georgia', 'more', 'normal'}
# {'a', 'budget', 'form', 'State', 'Hospital', 'in', 'from', 'increase', 'badly', 'Assembly', '$1,750,000', 'of', 'Milledgeville', 'program', 'for', "Georgia's", 'mental', 'received', 'needed', 'boost', 'the', 'General', 'health', '.'}
# {',', 'Vandiver', 'to', 'state', 'half-million', 'dollars', 'institution', 'from', 'surplus', '$1,250,000', 'is', 'allocated', 'receiving', 'additional', 'Gov.', 'above', 'last', 'what', 'year', 'amounts', 'it', 'considering', 'the', 'already', 'Actually', '.'}
# {'a', 'will', 'there', 'sounds', 'much', 'and', 'money', 'because', 'toward', 'that', 'Either', 'far', 'another', 'hunk', 'so', 'is', 'exactly', 'But', 'doing', 'like', 'question', 'needs', 'go', 'of', 'how', 'conditions', 'improving', 'way', 'it', 'sizable', '.'}
# {'practice', 'are', 'should', 'and', 'work', 'hospital', 'be', '65', 'employes', 'at', 'meals', 'per', 'reduced', 'hours', 'on', 'or', 'of', 'The', 'charging', 'they', 'week', 'not', 'whether', 'for', 'the', 'duty', 'eat', 'abolished', '.', 'attendants', 'more', 'who'}
# {'deserve', 'are', ',', 'should', 'nurses', 'More', 'Patients', 'more', 'and', 'attention', 'than', 'doctors', 'they', 'be', '.', 'attendants', 'hired', 'getting'}
# {'will', ',', 'to', '$3.15', 'spends', 'and', 'figure', '$4', 'treatment', 'low', 'mentally', 'Even', 'be', 'by', 'in', 'per', 'that', 'ill', 'increase', 'field', 'only', 'is', 'considered', 'spending', 'fiscal', 'national', 'around', 'with', 'day', 'The', 'than', 'as', 'of', 'experts', 'tops', 'year', 'for', 'mental', 'funds', 'regarded', 'too', 'patient', 'Kansas', 'its', 'the', 'next', '$9', 'nation', 'average', 'health', '.', 'Georgia', 'more'}
# {'are', ',', 'still', 'areas', 'made', 'treatment', 'dragging', 'in', 'some', 'intensive', 'so', 'is', 'true', 'But', 'many', 'The', 'program', 'reforms', 'working', 'has', 'other', 'well', '.', 'Georgia', 'we'}
# {',', 'inadequate', 'done', 'compared', 'to', 'mighty', 'do', 'hospital', 'use', 'be', 'toward', 'some', 'increase', 'helpful', 'best', 'granted', 'is', 'being', 'possible', 'Considering', 'needs', 'but', 'management', 'of', 'The', 'what', 'behooves', 'it', 'boost', 'the', 'planning', 'careful', 'making', '.'}
# {'a', 'an', ',', 'history', 'to', 'blood-thirsty', 'cannot', 'end', 'repulsive', 'now', 'Ciudad', 'be', 'means', 'in', 'Assassination', 'that', 'answered', 'El', 'conscience', 'good', 'fate', 'is', 'Caribbean', 'even', 'But', 'Trujillo', 'men', 'question', 'tyrant', 'Republic', 'Rafael', 'dictator', 'of', 'The', 'his', 'murder', 'appraisal', 'Benefactor', 'people', 'whether', 'Dominican', 'deserved', 'freedom', 'for', '31', 'often', 'even-handed', 'perhaps', 'fiefdom', 'the', 'years', '.'}
# {'countless', 'schemes', 'do', 'away', 'Venezuelan', 'leaders', 'that', 'scores', 'government', 'great', 'time', 'Betancourt', 'Trujillo', 'neighboring', 'Dictator', 'of', 'with', 'as', 'Galindez', 'Jimenez', 'It', 'Maria', 'about', 'has', 'had', 'deal', 'democratic', 'by', 'at', 'justice', 'deaths', 'door', 'involving', 'President', 'Venezuela', 'University', 'his', 'professor', 'the', '.', 'overthrow', ',', 'to', 'arms', 'Columbia', 'assassination', 'Marcos', 'including', 'demise', 'Dominican', 'own', 'York', 'for', 'Perez', 'laid', 'been', 'involved', 'a', 'abduction', 'uncovered', 'knew', 'responsibility', 'and', 'such', 'countries', 'use', 'poetic', 'in', 'Romulo', 'He', 'former', 'plot', 'sort', 'was', 'murder', 'reportedly', 'The', 'New', 'Jesus', 'new', 'quashed'}
# {'a', 'recent', 'an', ',', 'history', 'to', 'did', 'professedly', 'and', 'such', 'investment', 'all', 'study', 'facilities', 'notably', 'standard', 'in', 'improved', 'silence', 'things', 'benevolent', 'he', 'become', 'some', 'almost', 'raised', 'country', 'good', 'roads', 'is', 'living', 'even', 'But', 'was', 'Trujillo', 'dictatorship', 'grave', 'price', 'Republic', 'or', 'of', 'The', 'which', 'Unquestionably', 'his', 'as', 'sanitation', 'Dominican', 'public', 'opposition', 'for', 'way', ':', 'oppressive', 'tends', 'classical', 'the', 'attracted', 'criticism', 'industry', '.'}
# {'filled', ',', 'jails', 'to', 'Congress', 'and', 'United', 'States', "Benefactor's", 'extended', 'overflowing', 'in', 'chanted', 'influence', 'He', 'vanity', 'incurred', 'El', 'displeasure', 'prisoners', 'even', 'financed', 'his', 'with', 'The', 'which', 'political', 'sycophantically', 'praise', 'grew', 'personal', 'wealth', 'lobbies', 'had', 'amply', 'the', 'were', 'maintained', '.', 'elsewhere', 'who'}
# {'an', ',', 'altogether', 'to', 'members', 'and', 'after', 'United', 'broke', 'States', 'Until', 'by', 'in', 'accepted', 'repression', 'friendship', 'so', 'here', 'good', 'faith', 'Caribbean', 'character', 'was', 'came', 'Last', 'evidence', 'Trujillo', 'many', 'Tardily', 'understand', 'or', 'of', 'with', 'his', 'as', 'Government', 'last', 'how', 'association', 'diplomatic', 'year', 'own', 'tarnished', 'this', 'for', 'often', 'him', 'numerous', 'had', 'been', "country's", 'cited', 'the', 'relations', 'American', 'profession', 'aggressions', 'other', 'Organization', '.', 'too', 'reputation', 'article'}
# {'a', ',', 'lines', 'to', 'followed', 'and', 'after', 'previously', '--', 'thus', 'slogans', 'Cuba', 'conservative', 'in', 'There', 'left', 'he', 'that', 'totalitarianism', 'along', 'censure', 'tyranny', 'right-wing', 'rapprochement', 'illustrating', 'was', "Trujillo's", 'But', 'evidence', 'Thereupon', 'tacit', 'noire', 'dictatorship', 'Trujillo', 'coalesces', 'demonstration', 'propaganda', 'his', 'of', 'with', 'which', 'ideological', 'started', 'mouthing', 'no', 'bete', 'Castro', 'way', 'right', 'had', 'been', 'knows', 'the', 'considerable', 'Communist', '.', 'confines'}
# {'easily', 'Such', 'that', 'institutions', 'could', 'government', 'great', 'What', 'Trujillo', 'have', 'leadership', 'of', 'as', 'able', 'reform', 'free', 'no', 'any', 'creates', 'has', 'who', 'will', 'all', 'without', 'effort', 'now', 'little', 'democratic', 'comes', 'greatest', 'representative', 'need', 'genuine', 'Republic', 'sympathy', 'people', 'turn', 'vacuum', 'twist', 'the', 'tragedy', '.', ',', 'to', 'after', 'known', 'Communist-type', 'help', 'be', 'Western', 'generation', 'but', 'Dominican', 'for', 'Perhaps', 'authoritarianism', 'been', 'puzzle', 'precious', 'a', 'and', 'reason', 'bring', 'army', 'toward', 'is', 'deserve', 'stability', 'maintain', 'For', 'The', 'fear', 'alternative', 'would', 'freedom', 'danger', 'breathe', 'suppressed'}
# {'Montgomery', 'an', 'should', 'Such', 'do', 'Washington', 'frankly', 'if', 'County', 'transit', 'area', 'express', 'of', 'as', 'Start', 'Glen', 'soon', 'Brookmont', 'on', 'will', 'coming', 'all', 'C.', 'presenting', 'Darwin', 'agency', 'by', 'can', 'before', 'Parkway', 'city', 'rapid', 'sample', 'his', 'buses', 'presented', 'what', 'George', 'administrator', 'this', 'projects', 'the', 'between', '.', 'are', ',', 'to', 'High-speed', 'Capital', 'In', 'be', 'plans', 'seeking', 'launching', 'come', 'Echo', 'constitute', 'downtown', 'for', 'outline', 'attractive', 'Transportation', 'support', 'Stolzenbach', 'and', 'such', 'Agency', 'alluring', 'John', 'operating', 'was', 'National', 'into', 'Cabin', 'NCTA', 'not', 'would', 'Memorial', 'new', 'Council', 'difficult'}
# {'parking', 'will', ',', 'to', 'Congress', 'and', 'areas', 'parkway', 'be', 'advised', 'stations', 'from', 'is', 'present', 'stop', 'Because', 'land', 'bus', 'of', 'The', 'buses', 'not', 'NCTA', 'would', 'for', 'this', 'session', 'seek', 'funds', 'needed', '.', 'the', 'purpose', 'well', 'on', 'nearby'}
# {'divided', '?', 'Must', 'remain', 'Berlin'}
# {'widely', 'barricades', 'because', 'succeeded', 'in', 'accepted', 'Communists', 'that', 'city', 'living', 'across', 'have', 'of', 'The', 'building', 'dismemberment', 'free', 'Berlin', 'inference', 'must', 'has', 'been', 'the', 'world', 'acquiesce', '.', 'too'}
# {'have', ',', 'should', 'Western', 'and', 'record', 'far', 'the', 'as', 'do', 'concerned', 'so', '.', 'is', 'not', 'acquiesced', 'powers', 'So'}
# {'usurp', ',', 'to', 'Walter', 'Though', 'be', 'by', 'in', 'that', 'absorb', 'government', 'head', 'Germany', 'grace', 'give', 'Soviet', 'or', 'man', 'of', 'Ulbricht', 'may', 'into', 'tanks', 'not', 'semi-city', 'Berlin', 'any', 'does', 'him', 'right', 'zone', 'the', '.', 'East'}
# {'a', ',', 'to', 'Ministers', 'designated', 'and', 'administrative', 'French', 'comprising', 'be', 'by', 'three', 'one', 'wartime', 'later', 'occupation', 'troops', 'in', 'protocol', '12', 'four', 'respectively', 'city', '(', 'part', 'Foreign', 'Germany', 'present', 'area', 'September', 'was', 'special', 'mitigate', 'effects', 'division', '1949', 'blockade', 'Soviet', 'Greater', "''", 'entire', 'British', 'of', 'The', 'zones', '1944', 'airlift', 'not', 'It', 'declared', 'Berlin', 'joint', 'any', 'for', 'under', 'After', 'the', 'Council', 'American', 'purpose', ')', '.', '``'}
# {'to', 'and', 'areas', 'offices', 'moved', 'began', 'by', 'distinction', 'Then', 'Communists', 'some', 'government', 'promulgating', 'Germany', 'time', 'capital', 'sector', 'two', 'Soviet', 'For', 'of', 'they', 'into', 'treat', 'as', 'Berlin', 'illegally', 'for', 'it', 'German', 'zone', 'separately', 'the', 'between', 'honored', 'laws', 'puppet', '.', 'East'}
# {'a', 'governments', 'there', ',', 'to', 'appears', 'much', 'and', 'Eisler', 'after', 'United', 'States', 'sent', 'certainly', 'by', 'in', 'accepted', 'Adenauer', 'less', 'West', "latter's", 'Berlin-West', 'closing', 'Western', 'Chancellor', 'taunts', 'juvenile', 'That', 'provocative', 'gratuitous', 'visit', 'officials', 'Gerhard', 'was', 'have', 'protest', 'border', 'of', 'which', 'Britain', 'The', 'as', 'Ulbricht', 'than', 'over', 'not', 'sound-truck', 'Berlin', 'this', 'France', 'German', 'had', 'business', 'been', 'the', 'other', 'notes', '--', '.', 'East', 'Moscow'}
# {'whole', 'a', 'Moscow', 'to', 'integrate', 'isolating', 'and', 'efforts', 'quadripartite', 'by', 'out', 'that', 'pointed', 'from', 'attempting', 'Germany', 'status', 'insisted', 'capital', 'on', 'outside', 'They', "''", 'British', 'make', 'of', 'The', 'into', 'replies', 'Berlin', 'fact', 'it', 'has', 'note', '.', 'the', 'other', 'fundamental', 'authorities', 'East', 'Communist', '``'}
# {'an', ',', 'to', 'becoming', 'do', 'efforts', 'course', 'prevent', 'recognizing', 'There', 'can', 'West', 'from', 'beyond', 'far', 'This', 'is', 'those', 'question', 'protest', 'illegal', 'or', 'of', 'as', 'facts', 'what', 'diplomatic', 'fact', 'remains', 'accomplished', 'acknowledging', 'the', '.'}
# {'a', 'an', 'trivial', 'are', 'to', 'Army', 'when', 'such', 'certainly', 'try', 'residents', 'fusillades', 'vopos', 'West', 'gun', 'action', 'remained', 'broken', 'redressed', 'unarmed', 'was', 'fleeing', 'hooliganism', 'on', 'unless', 'feeds', 'but', "''", 'go', 'of', 'with', 'The', 'into', 'as', 'may', 'seem', 'they', 'over', 'Another', 'shots', 'glass', 'Berlin', 'One', 'official', 'incidents', 'ground', 'exists', 'stray', 'car', 'American', 'down', 'recovered', '.', 'Communist', '``'}
# {'a', 'stiffening', 'will', ',', 'hoped', 'to', 'and', 'dispatch', 'misgivings', 'be', 'passed', 'West', 'mark', 'that', 'representative', 'some', 'Remembering', 'also', 'fate', 'is', 'only', 'tactics', 'President', 'have', 'but', 'response', "''", 'of', 'as', 'salami', 'not', 'Berlin', "Kennedy's", 'about', 'it', 'German', 'Danzig', 'General', 'the', 'indignities', '.', 'aggressions', 'future', 'Clay', 'step-by-step', '``'}
# {'a', 'will', 'mobile', ',', 'to', 'upon', 'and', 'earth', 'rolling', 'binding', 'be', 'Thousands', 'never', 'dome', 'street', 'grassland', '(', 'grazing', 'bison', 'Park', 'even', 'National', 'like', "''", 'buffalo', 'dusty-green', 'A', 'man', 'of', 'they', 'seamless', 'vast', 'Prairie', 'horizon', 'brown', 'throw-rug', 'sky', '.', 'the', ')', 'on', 'sun-bleached', '``'}
# {'memory', 'a', 'whole', 'chicken', 'image', 'to', 'live-oak', 'when', 'and', 'Americans', 'fill', 'made', 'seas', 'Ohio', 'near', 'began', 'in', 'later', 'West', 'that', 'abundant', 'canyons', 'valleys', 'generation', 'That', 'them', 'take', 'Hollywood', 'is', 'was', 'those', 'endless', 'have', 'many', 'buffalo', 'symbolized', 'For', 'of', 'indelibly', 'as', 'picture', 'any', 'for', 'supply', 'it', 'conquest', 'cinema', 'continent', 'prairie', 'studied', 'Mississippi', 'grass', 'the', 'westward', 'American', 'fixed', '.', 'millions', 'who'}
# {'a', 'tapestry', 'an', 'proposes', ',', 'to', 'saw', 'earth', '--', 'extend', 'silo', 'now', 'northeast', 'barn', 'be', 'by', 'in', 'There', 'seen', 'Grasslands', 'stream', 'County', 'valleys', 'preserve', 'them', 'unfenced', 'moth-eaten', 'Wooded', 'specimens', 'Pottawatomie', 'area', 'Park', 'zoo', 'unbroken', 'National', "''", 'buffalo', 'or', 'of', 'The', 'as', 'Prairie', 'settlers', 'not', 'first', 'would', 'unplowed', 'saved', 'Kansas', 'roam', 'the', 'folds', 'Service', '.', '``'}
# {'clinch', 'an', 'history', 'should', 'to', 'Congress', 'when', 'and', 'is', 'ecological', 'case', 'Park', 'The', 'park', 'asked', 'for', 'this', 'new', 'statistical', 'makes', 'approve', 'the', 'impressive', 'American', 'creating', 'Service', '.'}
# {'Starting', 'members', ',', 'to', 'against', 'hard-liquor', 'and', 'distiller', 'TV', 'major-market', 'Association', 'customary', 'Whisky', 'in', 'stations', 'seeking', 'is', 'breaching', 'Philadelphia', 'break', 'on', 'National', 'A', 'prohibition', 'of', 'with', 'advertising', 'small', 'not', 'barriers', 'Broadcasters', 'radio', 'the', 'air', 'down', 'apparently', 'firm', '.', 'currently', 'anti-liquor'}
# {'through', 'to', 'kind', 'entering', 'such', 'answer', 'Communications', 'Commission', 'best', 'action', 'is', 'wedge', 'power', 'congressional', 'of', 'ban', 'advertising', 'this', 'Probably', 'its', 'the', 'Federal', 'requiring', '.', 'licensing'}
# {'a', 'hard-liquor', 'long', 'specifically', 'Association', 'Even', 'Distilled', 'popular', 'Institute', 'specific', 'show', 'bars', 'National', 'policy', 'code', 'Past', 'prohibition', 'of', 'The', 'polls', 'commercials', 'Spirits', 'public', 'opinion', 'favor', 'Broadcasters', 'for', 'this', 'has', 'had', 'the', '.'}
# {'are', ',', 'state', 'to', 'members', 'barricades', 'and', 'because', 'necessary', 'TV', 'barring', 'Distilled', 'stations', 'that', 'some', 'Institute', 'these', 'action', 'is', 'firms', 'Simply', 'NAB', 'congressional', 'ads', 'subverting', 'of', 'with', 'liquor', 'then', 'Spirits', 'not', 'Why', 'it', 'seek', 'radio', '?', 'tends', 'laws', 'the', 'voluntary', 'spread', '.'}
# {'want', 'members', 'groups', 'will', 'to', 'suffer', 'efforts', 'their', 'codes', 'that', 'some', 'from', 'competitors', 'Soon', 'doubtless', 'two', 'amend', 'unfairly', 'of', 'they', 'otherwise', '.', 'the', 'industry', 'grounds', 'non-code', 'on'}
# {'a', 'are', 'possibly', ',', 'there', 'enticing', 'and', 'soft-drinks', 'Oopsie-Cola', 'TV', 'glamour', 'fatuous', 'downed', 'applied', 'viewer', 'sipping', 'is', 'Although', 'pseudo-sophistication', 'gulling', 'false', 'or', 'downing', 'which', 'than', 'with', 'toothpaste', 'into', 'commercials', 'no', 'him', 'bourbon', 'surrounding', 'sad', 'whisky', 'the', 'difference', 'between', 'other', '.', 'more'}
# {'A', 'needed', 'law', 'is', '.'}
# {'will', "party's", 'to', 'and', 'choice', 'their', 'run', 'in', 'organization', 'elect', 'Mayor', 'Democrats', 'City', 'posts', 'men', 'have', "Democrats'", 'Registered', 'opportunity', 'New', 'year', 'York', 'this', 'for', ':', 'the', 'municipal', 'other', 'party', '.', 'candidates', 'who'}
# {',', 'central', 'In', 'pertinent', 'in', 'that', 'some', 'points', 'Mayor', 'have', 'they', 'may', 'contest', 'what', 'for', 'about', 'has', 'said', 'the', 'found', 'other', 'faction', '.', 'each'}
# {'assume', ',', 'problems', 'to', 'against', 'and', 'responsibility', 'all', 'policies', 'serious', 'law', 'Wagner', 'in', 'seen', 'schools', 'F.', 'While', 'Robert', 'Mayor', 'record', 'is', 'demand', 'blame', 'fiscal', 'share', 'citizens', 'performance', 'his', 'The', 'as', 'regime', 'own', 'must', 'enforcement', 'for', 'campaign', 'awkward', 'it', 'ethics', 'has', 'office', 'finding', 'lax', 'municipal', 'the', 'opponents', '.'}
# {'a', ',', 'to', 'cannot', 'welfare', 'shown', 'leaders', 'State', "city's", 'be', 'in', 'he', 'that', 'chosen', 'links', 'ills', 'deny', 'livelier', 'power', 'interest', 'those', 'have', 'They', 'of', 'than', 'with', 'as', 'political', 'Arthur', 'effectively', 'Levitt', 'hand', 'Controller', 'rule', 'has', 'too', '.', 'the', 'other', 'party', 'on', 'candidate', 'who'}
# {'are', 'an', 'state', 'to', 'and', 'known', 'be', 'mercilessly', 'in', 'left', 'Mayor', 'post', 'shortcomings', 'Mr.', 'exposed', 'men', 'have', 'those', 'public-spirited', 'impression', 'of', 'than', 'quiet', 'competence', 'his', 'protected', 'Levitt', 'been', "Wagner's", 'perhaps', 'honest', 'Both', '.', 'more', 'who'}
# {',', 'to', 'election', 'be', 'independent', 'out', 'As', 'some', 'Mayor', 'unquestionably', 'might', 'Mr.', 'leading', 'like', 'His', 'on', "''", 'regulars', 'of', 'than', 'his', 'Levitt', 'hand', 'would', 'strengthen', 'turn', 'supporters', 'the', 'other', '.', 'more', '``'}
# {'a', 'are', ',', 'to', 'now', 'course', 'leaders', 'Wagner', 'be', 'in', 'bosses', 'independent', 'he', 'that', 'whose', 'Mayor', 'might', 'calls', 'Mr.', 'only', 'is', 'term', 'third', 'those', "''", 'or', 'of', 'same', 'people', 'not', 'free', 'These', 'this', 'new', 'whom', 'has', 'seek', 'support', 'the', 'party', 'vote', 'pressure', '.', 'rejected', '``'}
# {'labor', 'liberal', 'him', 'and', 'unions', 'Democrats', 'back', 'his', 'reelection', 'the', 'strengthen', '.', 'But', 'would', 'who'}
# {'a', ',', 'still', 'and', 'made', 'choice', 'their', 'be', 'in', 'less', 'government', 'Democrats', 'is', 'voice', 'nevertheless', 'exciting', 'wish', 'citizens', 'If', 'of', 'than', 'The', 'gives', 'may', 'New', 'York', 'must', 'this', 'operation', 'it', 'the', 'party', 'vote', '.'}
# {',', 'softly', 'to', 'and', 'Laos', 'sticks', 'far', 'Mr.', 'so', "K's", 'have', 'Little', 'war', 'big', 'over', 'speak', 'continued', 'carry', 'Both', '.', 'test'}
# {'a', 'an', ',', 'And', 'still', 'to', 'Secretary', 'fighting', 'within', 'moved', 'be', 'Kennedy', 'at', 'hour', 'Bangkok', 'trying', 'he', 'arrangements', 'ultimatum', 'marines', 'time', 'is', 'possible', 'emergency', 'But', 'doubtless', 'President', 'two', 'refused', 'Australian', 'or', 'make', 'forces', 'same', 'his', 'quiet', 'into', 'of', 'en', 'route', 'drawn', 'helicopter-borne', 'Rusk', 'public', 'for', 'entry', 'demands', 'SEATO', 'Thursday', 'delivering', 'already', 'the', 'down', 'Thai', '.', 'Moscow'}
# {'a', ',', 'softly', 'to', 'and', 'carrying', 'outset', 'bad', 'stick', 'Kennedy', 'by', 'situation', 'speaking', 'in', 'means', 'at', 'He', 'out', 'he', 'that', 'best', 'Mr.', 'show', 'is', 'exactly', 'start', 'President', 'callable', 'For', 'of', 'The', 'his', 'with', 'what', 'no', 'position', 'bluffs', 'must', 'new', 'dealings', 'issuing', 'the', 'says', 'making', 'sizable', '.', 'Moscow'}
# {'a', 'want', ',', 'to', 'At', 'alternatives', 'Khrushchev', 'shown', 'cold', 'just', 'strength', 'In', 'Laos', 'Kennedy', 'peace', 'in', 'he', 'pawn', 'government', 'unprovocative', 'ready', 'Mr.', 'conference', 'time', 'is', 'military', 'case', 'third', 'but', 'war', "''", 'truly', 'press', 'his', 'as', 'All', 'not', 'put', 'position', 'this', 'for', 'scene', 'has', 'clearly', 'said', 'the', 'neutral', '.', 'we', '``'}
# {'a', 'value', ',', 'to', 'spot', 'bog', 'peculiar', 'Khrushchev', 'because', 'cost', 'course', 'little', 'tactical', 'appear', 'Laos', 'Washington', 'be', 'situation', 'in', 'things', 'that', 'ride', 'head', 'purely', 'might', 'let', 'Mr.', 'is', 'military', 'mess', 'expected', 'But', 'on', 'but', 'Since', 'Soviet', 'of', 'than', 'nature', 'no', 'would', 'must', 'this', 'for', 'approach', 'tempted', 'it', 'moment', 'him', 'off', 'the', 'itself', 'leader', '--', '.', 'more', 'Moscow'}
# {'a', 'terrain', 'an', ',', 'wars', 'to', 'and', 'force', 'United', 'core', 'States', 'tough', 'numbers', 'little', 'army', 'guerrilla', 'Laos', 'by', 'in', 'one', 'less', 'attempt', 'running', 'As', 'rebel', 'some', 'risk', 'government', "guerrilla-th'-wisp", 'up', 'Minh', 'allies', 'planners', 'only', 'is', 'But', 'hard', 'Pentagon', 'men', 'have', 'pro-Communist', 'go', 'combat-tested', 'Casualties', 'of', 'day', 'The', 'extremely', 'dozen', 'not', 'road-shy', 'fighters', 'about', 'for', 'shore', '2,000', 'been', 'SEATO', 'its', 'the', 'monsoon-shrouded', 'savored', 'Viet', '.'}
# {'will', ',', 'are', 'to', 'much', 'and', 'Khrushchev', 'bigger', 'bring', 'Braddock-against-the-Indians', 'be', 'Washington', 'can', 'attempt', 'he', 'if', 'that', 'from', 'home', 'closing', 'anything', 'ready', 'Mr.', 'probably', 'But', 'plus', 'forces', 'get', 'with', 'negotiations', 'enjoyment', 'idea', 'contest', 'not', 'fact', 'something', 'this', 'it', 'has', 'really', 'SEATO', 'the', 'off', 'disarmament', 'lose', 'other', '--', '.', 'watching', 'Moscow'}
# {'a', 'are', 'via', 'to', 'and', 'now', 'alliance', 'international', 'swung', 'fully', 'Laos', "America's", 'be', 'aim', 'that', 'Western', 'seeking', 'say', 'allies', 'behind', 'Republicans', 'both', 'policy', 'table', 'President', 'British', 'joined', 'of', 'achieve', 'Fortunately', 'would', 'chief', 'it', 'has', 'bargaining', 'the', 'Actually', 'accurate', 'leader', 'neutral', '.', 'more'}
# {'a', 'concept', ',', 'to', 'Geneva', 'and', 'struggle', 'after', 'Phouma', 'ousted', 'six', 'State', 'Laos', 'Washington', 'backed', 'coup', 'that', 'rightist', 'Premier', 'so', 'Souvanna', 'conference', 'is', 'of', 'The', 'as', 'last', 'idea', 'It', 'year', 'for', '1954', 'it', 'tacitly', 'bypassed', 'ironic', 'having', 'Department', 'the', 'years', 'neutral', '.', 'rejected', 'unreasonable'}
# {'a', 'fall', 'to', 'followed', 'and', 'United', 'interested', 'States', 'now', 'moving', 'by', 'plan', 'toward', 'back', 'ready', 'conference', 'is', 'But', 'cease-fire', 'outside', 'patrolled', 'British', 'of', 'last', 'since', 'position', 'for', 'has', 'been', 'observers', 'pro-neutralist', 'the', '.', 'powers'}
# {'a', 'terrain', ',', 'to', 'awaits', 'and', 'alternatives', 'effort', 'either', 'now', 'fighting', 'cold', 'made', 'choice', 'Laos', 'be', 'by', 'in', 'militant', "nation's", 'that', 'from', 'Southeast', "Khrushchev's", 'almost', 'difficult', 'country', 'Mr.', 'is', 'well-ruled', 'engaged', 'But', 'safety', 'war', 'seal', 'guaranteed-neutral', 'of', 'The', 'Asia', 'as', 'Laotian', 'last', 'people', 'big', 'sake', 'not', 'would', 'for', 'this', 'coup-proof', 'had', 'today', '.', 'the', 'minority', 'world', 'road', '--', 'on', 'warfare', 'who'}
# {'house', 'should', 'to', 'efforts', 'lower', 'TV', 'be', 'educational', 'in', 'emulated', '64-13', '(', 'A', 'locally', 'The', 'for', "Senate's", 'overwhelming', 'controlled', 'the', ')', 'vote', 'support', '.'}
# {'a', 'states', 'to', 'and', 'previously', 'federal', 'backing', 'be', 'out', 'them', 'let', 'ETV', 'communications', 'is', 'report', 'good', 'But', 'expected', 'prospects', 'Senate', 'approved', 'The', 'may', 'year', 'Twice', 'calling', 'subcommittee', 'this', 'for', 'bill', 'has', 'die', 'funds', 'better', 'the', 'measures', 'House', 'match', '.'}
# {'provide', 'state', ',', 'to', "year's", 'and', 'efforts', 'District', 'used', 'be', 'in', 'equipment', 'Columbia', 'private', 'ETV', 'measure', 'This', 'land', 'or', 'Senate', 'of', 'with', 'The', 'not', 'would', 'buildings', 'for', 'operation', 'funds', 'the', 'municipal', '$1,000,000', 'support', '.', 'each'}
# {'sponsors', ',', 'to', 'difficulties', 'such', 'money', 'difficulty', 'because', 'cost', 'their', 'be', 'educational', 'by', 'starting', 'high', 'equipment', 'stations', 'aided', 'that', 'from', 'meeting', 'them', 'But', 'have', 'relatively', 'service', 'or', 'Senate', 'of', 'The', 'communities', 'initial', 'most', 'expenses', 'lacking', 'improving', 'bill', 'commercial', 'ones', 'had', 'Other', 'the', 'few', 'found', 'considerable', '--', '.', 'value'}
# {'a', 'Sam', 'third', ',', 'A', 'Goodby', 'and', 'man', 'Democrat', 'American', 'Mr.', 'good', 'Rayburn', '.', 'was', 'departs'}
# {',', 'and', 'all', 'figure', ';', 'one', 'Sam', 'at', 'He', 'Speaker', 'these', 'rolled', 'Mr.', 'time', 'sturdy', 'was', 'Democrat', 'of', 'same', 'into', 'the', '.'}
# {'a', 'there', ',', 'and', 'finally', 'powerful', 'Washington', 'in', 'he', 'forceful', 'representative', 'from', 'Speaker', 'post', 'birth', 'was', 'young', 'man', 'his', 'The', 'which', 'as', 'of', 'then', 'second', 'first', 'most', 'for', 'habitat', 'committee', 'chairman', 'seemed', 'the', 'House', 'flourished', 'intended', '.'}
# {'a', 'miss', 'an', 'easy', ',', 'to', 'will', 'much', 'and', 'rear-looking', 'conservative', 'Rayburn', 'He', 'that', 'Mr.', 'persuasion', 'was', 'label', 'or', 'Fair', 'man', 'of', 'classify', 'as', 'yet', 'partisans', 'not', 'New', 'no', 'any', 'liberal', 'him', 'flaming', 'needed', 'the', 'Deal', 'Frontier', '.'}
# {'a', 'keep', 'are', ',', 'to', 'always', 'unnumbered', 'politician', 'and', 'took', 'others', 'Rayburn', 'secrets', 'demanded', 'be', 'by', 'retraction', 'never', 'Sam', 'he', 'that', 'loquacious', 'word', 'confidence', 'added', 'subject', 'might', 'so', 'Two', 'was', 'expected', 'vital', 'grave', 'of', 'his', 'with', 'as', 'theirs', 'qualities', 'not', 'It', 'kept', 'for', 'politicians', 'him', 'once', 'given', 'the', 'other', '.'}
# {'a', 'rise', 'When', ',', 'upon', 'and', 'usually', 'desk', 'Washington', 'be', 'theatrical', 'one', 'never', 'in', 'legislative', 'He', 'silence', 'growl', 'great', 'hands', 'nod', 'chin', 'was', 'power', 'enough', 'His', 'dramas', 'leadership', 'A', 'demonstration', 'flamboyant', 'or', 'his', 'of', 'The', 'into', 'political', 'presented', 'chest', 'not', 'would', 'side', 'for', 'it', 'chatter', 'gripping', 'the', 'subside', 'audiences', 'House', 'well', '.'}
# {',', 'to', 'upon', 'and', 'usually', 'without', 'sense', 'made', 'acted', 'He', 'common', 'plain', 'recognized', 'briefly', 'spoke', 'sensibly', 'good', 'flourishes', 'point', 'oratorical', 'it', 'the', 'American', 'House', '.'}
# {'a', 'memory', 'an', ',', 'to', 'did', 'and', 'when', 'do', 'because', 'efforts', 'Rayburn', 'long', 'their', 'in', 'before', 'He', 'out', 'reached', 'he', 'With', 'floor', 'pointed', 'Democrats', 'them', 'persuading', 'Mr.', 'patiently', 'excellent', 'expected', 'issue', 'service', 'normally', 'his', 'rare', 'political', 'public', 'These', 'it', 'thing', 'had', 'been', 'its', '.', 'the', 'duty', 'were', 'House', 'counseling', 'leader', 'educating', 'on', 'test'}
# {'a', 'generations', 'coincided', 'are', ',', 'declaration', 'against', 'Congress', 'though', 'Americans', 'very', 'course', 'long', 'Rayburn', 'existence', 'in', 'There', 'Sam', 'He', 'that', 'almost', '1917', 'To', 'Mr.', 'Germany', 'only', 'time', 'was', 'men', 'two', 'have', 'war', 'voted', 'of', 'with', 'as', 'must', 'for', 'it', 'remaining', 'seemed', 'the', 'House', '.', 'who'}
# {'And', 'to', 'and', 'end', 'ambition', 'officer', 'be', 'He', 'he', 'served', 'To', 'was', 'presiding', 'loved', 'body', 'those', "''", 'president', 'Senate', 'of', 'his', 'The', 'with', 'not', 'corrected', 'him', 'it', 'said', 'under', 'who', 'the', 'House', 'desire', 'upper', '.', '``'}
# {'a', 'Sound', ',', 'And', 'still', 'and', 'death', 'C.', 'S.', 'began', 'revolution', 'Washington', 'Herbert', 'in', 'John', 'Kennedy', 'he', 'served', 'F.', 'social', 'Harding', 'D.', 'FDR', 'those', 'Eisenhower', 'Warren', 'us', 'of', 'with', 'his', 'Truman', 'Hoover', 'Dwight', 'roll', 'whom', 'him', 'preceded', 'managed', 'Woodrow', 'the', 'Harry', 'Calvin', 'years', 'Coolidge', 'Wilson', '.', 'G.', 'who'}
# {'a', 'there', ',', 'to', 'administration', 'Congress', 'and', 'experience', 'because', 'fighter', 'sadder', 'Kennedy', 'Sam', 'He', 'he', 'As', 'final', 'Mr.', 'only', '1948', 'was', 'illness', 'those', 'have', 'hopeless', "''", 'partisan', 'of', 'his', 'Truman', 'with', 'than', 'recall', 'not', 'what', 'loyal', 'first', 'own', 'would', 'for', 'campaign', 'it', 'has', 'had', 'absence', 'been', 'the', 'party', 'remember', '.', 'blow', '``'}
# {'fair', ',', 'fought', 'an', 'to', 'campaigns', 'play', 'attacks', 'He', 'obstructionist', 'he', 'that', 'With', 'part', 'is', 'was', 'on', 'Republicanism', 'but', 'born', 'Republican', 'man', 'his', 'partisan', 'of', 'not', 'kept', 'own', 'for', 'game', 'presidents', 'the', '.', 'automatic'}
# {'a', 'Sam', ',', 'he', 'Speaker', 'Democrat', 'man', '.', 'Mr.', 'good', '--', 'Under', 'was', 'any', 'name'}
# {'to', 'airmen', 'death', 'United', 'met', 'their', 'peace', 'troops', 'banner', 'at', 'violent', 'track', 'supposedly', 'instead', 'hands', 'went', 'Italian', 'have', 'un', 'of', 'cause', 'Congolese', 'Nations', 'serve', 'under', 'Thirteen', 'off', 'Congo', 'the', 'friends', '.', 'who'}
# {'incident', '18', ',', 'Belgian', 'and', 'bloodlust', 'wearing', 'central', 'their', 'months', 'In', 'be', 'by', 'condoned', 'out', 'dismembered', 'that', 'from', 'bodies', 'Italians', 'savages', 'government', 'might', 'them', 'grisly', 'atrocities', 'Katanga', 'was', 'Simply', 'of', 'The', 'jungle', 'into', 'offered', 'they', 'mercenaries', 'uniform', 'serving', 'victims', 'murderers', 'river', 'dissident', 'no', 'for', 'words', 'has', 'had', 'remains', 'cause', 'been', 'excuse', 'the', 'mistaken', 'other', 'tossed', '.', 'reported', 'more'}
# {'work', 'adventures', 'six', 'that', 'government', 'goal', 'Katanga', 'basic', 'have', 'or', 'whatever', 'of', 'as', 'It', 'no', 'any', 'has', 'reckless', 'given', 'outlawry', 'Leopoldville', 'by', 'demonstrably', 'become', 'almost', 'occurrences', 'so', 'UN', 'which', 'political', 'fiction', 'commanding', 'this', 'pillage', 'rapes', 'its', 'the', 'troop', '.', 'daily', 'looting', ',', 'upon', 'Yet', 'Does', 'authority', 'progress', 'incapable', 'happens', 'mutinies', 'To', 'weeks', 'fit', 'territory', 'violence', 'gives', 'for', 'uncontrolled', 'been', 'Congo', 'itself', 'making', 'support', 'a', 'through', 'and', 'such', 'contrary', 'governing', 'in', 'sanction', 'toward', 'suggest', 'only', 'is', 'military', 'abroad', 'condition', 'past', 'piled', 'not', 'it', '?', 'credit', 'limited', 'Mass', 'nationhood', 'anarchy'}
# {'a', 'will', 'are', 'ruin', 'to', 'much', 'longer', 'main', 'chaos', 'and', 'pride', 'do', 'just', 'visiting', 'answer', 'long', 'until', 'by', 'in', 'exercise', 'can', 'bury', 'terms', 'out', 'that', 'sand', 'raised', 'head', 'up', 'instead', 'so', 'is', 'present', 'truth', 'bitter', 'Central', 'Russia', 'question', 'young', 'Africa', 'false', 'how', 'The', 'UN', 'of', 'as', 'nations', 'they', 'problem', 'African', 'fact', 'no', 'favor', 'facing', 'it', 'has', 'wake', '?', 'solution', 'its', '.', 'the', 'Congo', 'probable', 'veto', 'on', 'incident'}
# {'a', 'demoralized', 'are', ',', 'pushing', 'to', 'and', 'chaos', 'work', 'fantastically', 'sense', 'now', 'view', 'weak', 'use', 'army', 'invade', 'one', 'several', 'out', 'task', 'subjugate', 'Right', 'from', 'points', 'resolution', 'That', 'is', 'garrisoned', 'Katanga', 'cut', 'territory', 'Last', 'Further', 'have', 'forces', 'which', 'UN', 'of', 'they', 'The', 'into', 'wrong-headed', 'notion', 'no', 'would', 'stopping', 'for', 'it', 'has', 'existing', 'solid', 'makes', 'its', 'reasonably', 'where', 'the', 'deliver', '.', 'too', 'anarchy'}
# {'will', ',', 'should', 'independence', 'to', 'and', 'inconsistent', 'suggested', 'expediency', 'because', 'now', 'defeat', 'urge', 'mandate', 'in', 'feeling', 'if', 'some', 'blindly', 'march', 'prevailed', 'wisdom', 'ready', 'late', 'measure', 'is', 'time', 'truth', 'Assembly', 'even', 'was', 'But', 'on', 'men', 'have', 'failure', 'talk', 'of', 'The', 'with', 'termed', 'political', 'remain', 'idea', 'magnitude', 'over', 'UN', 'not', 'It', 'what', 'certain', 'realism', 'courage', 'any', 'mandated', 'for', 'new', 'Otherwise', 'it', 'been', 'perhaps', 'General', 'the', 'Congo', '.', 'too', 'approach'}
# {'a', 'recent', 'and', 'criticized', 'reached', 'that', 'Southern', 'Railroad', 'editorial', 'Order', 'was', 'Co.', 'on', 'Pacific', 'reversal', 'A', 'complete', 'agreement', 'based', 'of', 'Featherbed', 'not', 'it', 'has', 'been', 'labor-management', 'information', '.', 'the', 'between', 'grounds', 'Telegraphers', 'discussing'}
# {'job', 'an', 'cent', 'statement', 'made', 'form', 'their', 'misplaced', 'pay', 'per', 'that', 'comment', 'could', "''", 'worked', 'or', 'ultimate', 'week', '40', 'had', 'said', 'on', 'dispatch', 'imagine', 'editorial', 'also', 'railroad', 'reduction', 'telegraphers', 'based', 'which', 'sympathy', 'they', 'whether', 'what', 'entered', 'this', 'its', 'received', 'the', 'whereby', '.', ',', 'balance', 'to', 'life', 'but', 'agreement', 'association', '2', 'year', 'for', 'Our', 'news', 'were', '``', 'a', 'and', 'such', "hours'", 'number', 'in', 'benefit', 'some', 'from', 'was', 'guaranteed', 'The', 'into', 'not', 'since', 'it', 'compensating', 'undoubtedly', 'limited', 'featherbedding', 'difficult', 'secured'}
# {'a', 'job', ',', 'provision', 'to', 'personnel', 'in', 'less', 'that', 'academic', 'stabilized', 'need', 'was', 'Also', 'railroad', 'reduction', 'attrition', 'or', 'us', 'telegraphers', 'of', 'which', 'make', 'Additional', 'would', 'supply', 'it', 'information', 'discloses', 'supplied', 'the', 'gained', '.', 'more', 'normal'}
# {'a', 'to', 'acceptable', 'and', 'originally', 'included', 'applicable', 'situation', 'one', 'situations', 'in', 'reached', 'that', 'Southern', 'union', 'necessarily', 'therefore', 'special', 'was', 'industries', 'railroad', 'Pacific', 'agreement', 'of', 'with', 'The', 'than', 'series', 'not', 'demands', 'regard', 'solution', 'the', 'other', '.', 'more'}
# {'a', 'shelter', 'house', 'taken', ',', 'to', 'an', 'scarcely', 'when', 'and', 'there', 'sense', 'United', 'humidity', 'met', 'governing', 'bar', 'leaned', 'in', 'less', 'internationalists', 'common', 'that', 'from', 'lads', 'Meditations', 'Time', 'here', 'unanimously', 'St.', 'despite', 'was', 'But', 'body', 'have', 'but', 'Louis', 'of', 'than', 'fallout', 'association', 'delegates', 'over', 'not', 'grumble', 'Bar', 'side', 'about', 'Nations', 'imperfection', 'it', 'wonderful', 'the', 'American', 'vote', '.'}
# {'a', 'hope', ',', 'an', 'space', 'Russians', 'and', 'covenant', 'extending', 'law', 'international', 'before', 'jumper', 'some', "shouldn't", 'moon', 'best', 'writers', "it's", 'claim', 'was', 'Peace', "man's", 'on', "''", 'brief', 'get', 'into', 'It', 'put', 'for', 'abiding', 'wonderful', 'it', '?', '.', 'the', 'world', 'peaceful', 'decided', 'too', 'we', '``'}
# {'a', 'million', ',', 'to', 'bomb', 'sense', 'Meanwhile', 'Khrushchev', 'law', 'by', 'in', 'justice', 'West', 'build', 'oafs', 'march', 'surrendering', 'adding', 'bit', 'tons', 'was', 'those', 'heads', 'knock', 'his', 'of', 'with', 'into', 'see', 'Berlin', 'wallop', 'equal', '100', 'backward', 'who', 'the', 'TNT', 'promising', "can't", 'world', 'communism', '.', 'Moscow'}
# {'a', 'house', ',', 'there', 'to', 'and', 'times', 'United', 'Khrushchev', 'States', 'just', 'kicks', 'bigger', 'certainly', 'six', 'use', 'be', 'bang', 'some', 'from', 'anything', 'moon', 'produce', 'experimentally', 'these', 'might', 'beer', 'St.', 'even', 'pacifier', 'half', 'A', 'Louis', 'of', 'than', 'delegates', 'seminar', 'would', 'nuclear', 'triggered', 'for', 'any', 'it', 'has', 'dimensions', 'propel', 'where', 'the', 'drink', '--', '.', 'roughly', "wouldn't"}
# {'an', ',', 'to', 'appreciate', 'reason', 'west', 'suicide', 'by', 'in', 'at', 'philosopher', 'he', 'While', 'was', 'Kremlin', 'additional', 'those', 'coexistence', 'of', 'assist', 'rule', 'it', 'bellowing', 'the', "can't", 'contributed', 'thru', '.', 'who'}
# {'are', ',', 'doing', 'he', "''", '``', 'you', '?', 'do', 'bayed', 'think', 'what', 'Fools'}
# {'house', ',', 'feeble', 'effort', 'United', 'marimba', 'our', 'one', 'in', 'can', 'at', 'that', 'heavy', 'improve', 'shoes', 'only', 'is', 'playing', "aren't", 'domes', 'but', 'response', 'humble', 'of', 'The', 'with', 'think', 'delegates', 'least', 'Nations', 'this', 'perhaps', '.', 'the', 'on', 'we'}
# {'a', 'an', ',', 'will', 'to', 'provided', 'craft', 'familiar', 'United', 'reason', 'mortification', 'made', 'admirer', 'sent', 'States', 'demented', 'prove', 'revolution', 'flight', 'by', 'Colombian', "O'Clock", 'gun', 'some', 'from', 'old', 'City', 'back', 'minister', 'Algerian', 'is', 'was', 'express', 'suitable', 'evidence', 'gunman', 'unwelcome', 'but', 'recruit', 'of', 'with', 'The', 'hijacking', 'Shadow', 'Another', 'unknown', 'not', 'kept', 'rule', 'Castro', 'for', 'change', 'spreading', 'passenger', 'Havana', '.', 'the', 'where', 'who', 'American', 'rushed', 'Mexico', 'Ten', 'crazy', 'foreign', 'airport', 'plane', 'daily'}
# {'a', 'documents', 'embarrassing', ',', 'embassy', 'to', 'millennium', 'and', 'Americans', 'conventions', 'United', 'Caracas', 'States', 'Guevara', 'legal', 'edified', 'council', 'billion', 'Inter-American', 'promise', 'by', 'in', 'Latin', 'at', 'secret', 'from', 'contents', 'meeting', 'Che', 'reading', 'was', 'displayed', 'on', 'purloined', 'Venezuela', 'two', '20', 'Economic', 'respect', 'man', 'The', 'aid', 'hand', 'Social', 'Less', 'for', "Castro's", 'right', 'spokesmen', 'dollar', 'the', 'American', 'were', 'foreign', 'Montevideo', '.', 'highly', 'who'}
# {'a', 'are', ',', 'Cuban', 'to', 'administration', 'always', 'incompetence', 'and', 'felonious', 'Khrushchev', 'advanced', 'demurrer', 'invasion', 'law', 'interests', 'Kennedy', 'by', 'in', 'be', 'can', 'things', 'protecting', 'file', 'that', 'trust', 'methods', 'mounted', 'these', 'planes', 'is', 'symptomatic', 'holding', 'but', 'happen', 'effect', 'of', 'The', 'same', 'which', 'last', 'papers', 'stealing', 'not', 'diplomatic', 'own', 'moralities', 'would', 'Perhaps', 'for', 'about', 'April', 'said', 'its', 'half-hearted', 'invoked', 'the', 'off', 'American', 'world', '.', 'we'}
# {'a', 'candle', 'pass', ',', 'to', 'and', 'read', 'just', "we're", 'law', 'away', 'dark', 'please', 'another', 'here', "it's", 'time', 'bit', 'rations', 'Pass', 'of', 'iron', 'getting', 'light', 'for', 'minded', 'the', 'down', 'world', '.'}
# {'suspension', 'Interstate', 'a', ',', 'reduce', 'to', 'month', 'Commerce', 'rates', 'planned', 'ordered', 'grain', 'do', 'commission', 'their', 'railroads', 'customer', 'freight', 'on', 'of', 'The', 'as', 'they', 'not', 'group', 'loses', 'board', 'this', 'has', 'had', 'again', 'the', '.'}
# {'a', 'developing', 'hope', ',', 'lines', 'to', 'rates', 'and', '100-ton', 'much', 'money', 'cent', 'grain', 'move', 'win', 'lower', 'smaller', 'in', 'can', 'at', 'per', 'some', 'hopper', 'railroads', 'Southern', 'back', 'truckers', 'railway', 'good', 'associated', 'time', 'conventional', '60', 'costs', 'originated', 'half', 'By', 'have', 'barge', 'which', 'The', 'with', 'spent', 'of', 'as', 'they', 'what', 'for', 'about', 'it', 'has', 'reducing', 'business', 'its', 'the', 'car', 'says', 'deal', '.', 'request', 'lost'}
# {'complex', 'against', 'our', 'maze', 'regulatory', 'shows', 'of', 'The', 'up', 'laws', '.', 'action', "board's", 'is', 'what', 'free', 'in', 'enterprise'}
# ...
# {',', 'end', 'signals', 'Liberalism', 'In', 'John', 'defeating', 'in', 'Texas', "Tower's", 'Capet', "''", 'Louis', 'of', 'victory', 'right', 'once', 'again', '.', 'the', 'divine', '``'}
# {'proposes', 'do', 'hit', 'our', 'one', 'Never', 'that', 'confronts', '(', 'time', '25', 'Mar.', 'have', "''", 'Confrontation', 'us', 'of', 'with', 'as', 'It', 'personal', 'no', 'face', 'SR', 'has', 'world', 'who', 'will', 'place', 'all', 'others', 'can', 'at', 'N.C.', 'editorial', 'so', 'those', 'bothers', 'his', 'how', 'than', 'problem', 'sufferer', 'what', 'this', ':', 'know', 'solution', 'the', 'retain', 'other', 'I', '.', 'distress', ',', 'to', 'upon', 'expressed', 'real', 'This', 'relationship', 'complex', 'hopeless', 'me', 'widespread', 'for', 'affects', 'each', '``', 'seems', 'a', 'suffer', 'and', 'in', 'seen', 'he', 'some', 'beyond', 'intimately', 'sympathetically', 'hoping', 'leave', 'him', 'clearly', '?', 'spread', ')', '--', 'we'}
# {'for', 'illustrated', "''", 'you', 'Confrontation', 'writing', 'and', 'great', 'the', 'editorial', 'religion', 'is', 'Thank', 'It', '.', 'both', 'profound', '``'}
# {'whole', 'will', 'to', 'piece', 'times', 'be', 'N.C.', 'that', 'quote', 'so', 'many', 'preacher', 'something', 'this', 'tempted', 'has', 'said', 'the', 'well', 'important', '.'}
# {'a', 'hope', ',', 'will', 'core', 'others', 'very', 'existence', ';', 'feel', 'be', 'our', 'in', 'hit', 'by', 'N.C.', 'that', 'great', 'editorial', 'shared', 'only', 'is', 'my', 'many', "''", 'Confrontation', 'of', 'meant', 'it', 'the', 'Personally', 'I', 'deal', '.', '``'}
# {',', 'should', 'fortify', "''", 'Confrontation', 'Southeast', 'or', 'us', 'all', '.', 'Asia', 'the', 'whether', 'U.S.', 'in', '``'}
# {'a', 'heartbreaking', 'problems', ',', 'will', 'to', 'and', 'Americans', 'necessary', 'idealism', 'confrontation', 'be', 'situation', 'in', 'lands', 'by', 'run', 'N.C.', 'that', 'poverty', 'Corps', 'is', 'hardship', 'Peace', 'young', 'successfully', 'have', 'delving', 'leadership', 'of', 'which', 'into', 'Congratulations', 'see', 'It', 'effective', 'would', 'thwarted', 'for', 'face', 'it', 'existing', '.', 'the', 'heart', 'hence', 'I', 'foreign', 'concur'}
# {'to', 'and', 'areas', 'strength', 'certainly', 'amazing', 'in', 'from', 'continuing', 'editorial', 'so', 'here', 'need', 'living', 'America', 'was', 'uncover', 'those', 'capture', 'many', 'attention', "''", 'Confrontation', 'us', 'of', 'The', 'personally', 'for', 'this', 'appeal', 'it', 'Thanks', 'its', 'the', 'direct', 'world', 'I', 'gained', '.', '``'}
# {'a', 'hope', 'will', 'encourage', 'entering', 'writing', "N.C.'s", 'piece', 'to', 'read', 'are', 'and', 'others', 'Khrushchevs', 'never', 'Shriver', 'Dooleys', 'that', 'whose', 'Corps', 'Schweitzers', 'them', 'editorial', 'Castros', 'is', 'Peace', 'like', 'but', "''", 'Confrontation', 'of', 'The', 'people', 'not', 'would', 'it', 'know', 'humanity', 'the', 'names', 'Sargent', 'I', 'everyone', 'stunning', 'important', '.', ',', 'we', '``'}
# {'will', 'members', "Editor's", 'to', 'and', 'included', 'precisely', 'be', 'Reprints', 'material', 'Corps', 'editorial', 'need', 'volunteers', 'Peace', 'described', 'men', "''", 'A', 'Confrontation', 'distributed', 'among', 'of', 'as', 'official', 'communicate', 'soon', ':', 'note', 'message', 'the', 'who', 'women', '.', 'we', '``'}
# {'?', 'Bostonian', 'Improper'}
# {'a', 'seems', 'fair', 'hope', 'will', 'to', ',', 'month', 'and', 'sport', 'very', 'L.', 'certainly', '1', 'readers', 'blind', 'be', 'rather', 'in', 'by', 'at', 'left', 'F.', "SR's", 'comment', 'James', 'say', 'best', 'King', 'is', 'Messing', 'issue', 'Cleveland', 'impression', "''", 'English', 'fundamentalist', "Lucas's", 'Bible', 'of', 'than', 'his', 'around', 'with', 'us', 'analysis', 'New', 'It', 'first', 'objective', 'dogmatism', 'version', 'this', 'minds', 'perilous', 'April', 'seemed', 'Amory', 'the', 'column', 'I', '.', 'article', '``'}
# {'a', 'current', ',', 'and', 'called', 'Markel', 'ago', 'readers', 'by', 'in', 'protecting', 'yellow', 'that', 'from', 'focus', 'generation', 'track', '(', 'country', 'Lester', '11', 'is', 'probably', 'combination', 'was', 'Mar.', 'stereotype', "''", 'journalism', 'Interpretation', 'Facts', 'his', 'The', 'of', 'straight', 'press', 'which', 'than', 'fact', 'doctored', 'personal', 'reporting', 'opinion', 'this', 'SR', 'right', 'its', '.', 'the', 'news', 'flourished', 'Of', ')', 'pollution', 'invaluable', 'on', 'fancy', 'more', 'article', '``'}
# {'there', ',', 'are', 'and', 'longer', 'now', 'armed', 'media', 'Besides', 'corruptible', 'need', 'is', 'enough', 'journalists', 'of', 'The', 'with', 'protection', 'competing', "don't", 'public', 'no', 'any', 'type', 'this', 'about', 'sophistication', 'numerous', 'We', '.', 'more'}
# {'reporters', 'columns', 'charges', 'until', 'their', 'restricted', 'Second', 'labor', 'causes', 'screen', 'late', 'these', 'two', 'restrictions', 'propaganda', 'press', 'of', 'competing', 'get', 'with', 'picture', 'no', 'about', 'has', 'had', 'knows', 'nation', 'front-page', 'put', 'instance', 'on', 'Wisconsin', 'subjects', 'all', 'seeing', 'boxed', 'tell', 'by', 'accepted', 'Senator', 'McCarthy', 'stories', 'communicating', 'both', 'distortion', 'major', 'complete', 'A', 'his', 'reporter', 'people', 'what', 'unable', 'communicate', 'does', 'perspective', 'its', 'the', 'years', 'average', 'powerless', '.', 'liabilities', ',', 'to', 'writing', 'Yet', 'citizen', 'dispute', 'saw', 'innocent', 'readers', 'several', 'along', 'method', 'unscrupulous', 'misled', 'half', 'Despite', 'but', 'television', 'own', 'for', 'been', 'news', 'a', 'destroyed', 'junior', 'in', 'he', 'from', 'First', 'them', 'sides', 'statements', 'only', 'is', 'was', 'The', 'not', 'effective', 'way', 'it'}
# {'seems', 'a', 'job', 'will', 'provide', 'should', 'to', 'reporters', 'and', 'do', 'ends', 'now', 'relevant', 'their', 'be', 'by', 'print', 'in', 'editors', 'ways', 'less', 'that', 'method', 'possession', 'come', 'subject', 'time', 'present', 'is', 'communicating', 'possible', 'start', 'those', 'have', 'stereotype', 'higher', 'me', 'press', 'of', 'with', 'how', 'The', 'experimenting', 'into', 'than', 'learned', 'It', 'own', 'objective', 'reporting', 'getting', 'for', 'has', 'serve', 'percentage', 'information', 'better', 'the', 'news', 'American', 'abuse', 'manipulate', '.', 'who'}
# {'a', 'an', ',', 'space', 'to', 'and', 'concerned', 'form', 'concerning', 'praised', 'in', 'one', 'intelligent', 'some', 'Southern', 'far', 'so', 'conference', 'is', 'issue', 'like', 'You', 'President', 'have', 'on', 'opinions', 'you', 'press', 'of', 'than', 'as', 'gives', 'idea', 'people', 'see', 'would', "Kennedy's", 'California', 'blackout', 'it', 'devote', 'chance', 'early', 'occasion', 'the', 'news', 'televised', 'activities', 'I', '.', 'more'}
# {'a', ',', 'did', 'Angeles', 'am', 'when', 'that', 'To', 'these', 'begin', 'was', 'Times', 'transcript', 'Eisenhower', 'President', 'conferences', 'press', 'of', 'with', 'they', 'not', 'does', 'all-powerful', 'the', 'Los', 'sure', 'I', 'publish', '.'}
# {'Brinkley', 'sometimes', 'interesting', 'TV', 'networks', 'until', 'their', 'half-hour', 'less', 'obviously', 'could', 'time', 'have', "''", 'or', 'P.M.', 'of', 'get', 'as', '5', 'no', 'summarized', 'commentator', 'Douglas', 'few', 'on', '7', 'all', 'now', 'by', 'Edwards', 'squeeze', 'at', 'glibly', 'hours', 'questions', 'which', 'evening', 'they', 'programs', 'then', 'Up', 'program', 'summary', 'night', 'the', 'criticism', '.', 'are', ',', 'Huntley', 'because', 'run', 'during', 'come', 'This', 'grudgingly', 'snatches', 'conferences', 'day', 'last', 'differential', 'Next', 'news', 'were', 'tapes', '``', 'a', 'cannot', 'and', 'edited', 'middle', 'Even', 'out', 'got', 'them', 'is', 'However', 'fifteen-minute', 'into', 'not', '10:30', 'we'}
# {'a', ',', 'regarding', 'paragraph', 'to', "President's", 'did', 'and', 'Angeles', 'am', 'all', 'interested', 'edited', 'We', 'answer', 'TV', 'removed', 'middle', 'Laos', 'run', 'by', 'one', 'mail', 'stations', 'transcripts', 'out', 'comparing', 'hours', 'that', 'he', 'from', 'subjected', 'during', '(', 'country', 'here', 'conference', 'is', 'being', 'thought', 'even', 'Times', 'snatches', 'enough', 'censored', 'two', 're-runs', 'However', "''", 'questions', 'or', 'of', 'The', 'evening', 'station', 'ABC', 'over', "don't", 'see', 'abuse', 'getting', 'version', 'about', 'had', 'radio', 'know', '.', 'the', 'Los', 'abused', 'found', ')', 'different', 'I', '``'}
# {',', 'to', 'happened', 'did', 'and', 'all', 'TV', 'networks', ';', 'mention', 'in', 'situation', 'local', 'at', 'He', 'independent', 'he', 'if', 'hours', 'that', 'during', 'nothing', 'country', 'also', 'is', 'was', 'letters', 'Times', 'doing', 'many', 'but', 'understand', 'parts', 'of', 'with', 'which', 'evening', 'editor', 'his', "don't", 'not', 'It', 'Inauguration', 're-run', 'fact', 'himself', 'this', 'about', 'wrote', 'it', 'had', 'know', 'column', 'received', 'the', "stations'", 'other', 'apparently', 'I', '--', '.'}
# {'bring', 'this', 'attention', 'to', 'you', '?', 'the', "networks'", 'Can'}
# {'a', ',', 'Propaganda', 'Feb.', 'interested', 'Do', 'Webb', 'in', 'he', "Young's", 'James', 'raised', '(', ')', '11', 'was', 'Need', 'question', 'Avenue', 'College', "''", 'propaganda', 'college', 'For', 'of', 'which', 'SR', ':', 'Madison', '?', 'column', 'the', 'I', 'We', '.', '``'}
# {',', 'definitely', 'and', 'do', ';', 'In', 'one', 'that', 'disintegrate', 'part', 'let', 'excellent', 'is', 'my', 'was', 'of', 'which', 'into', 'shape', 'estimation', 'rounding', 'it', 'had', 'die', 'sad', 'the', '.', 'we'}
# {'a', 'grey', ',', 'and', 'various', 'included', 'principal', 'in', 'one', 'by', 'There', 'schools', 'couple', 'out', 'Canada', 'During', 'several', "Lloyd's", 'England', 'got', 'ours', 'up', 'country', 'also', 'time', 'being', 'both', 'psychological', 'estate', 'Marshall', 'on', 'Neck', 'war', 'propaganda', 'English', 'of', 'which', 'The', 'into', 'they', 'lot', 'learned', 'teaching', 'techniques', 'white', 'for', 'this', 'about', 'it', 'had', 'preceded', 'black', 'its', 'the', 'shades', 'between', 'Field', 'were', 'set', 'We', '.', 'warfare', 'we'}
# {'there', ',', 'to', 'and', 'end', 'every', 'United', 'States', 'instructors', 'taught', 'in', 'one', 'Canada', 'schools', 'out', 'England', 'that', "Lloyd's", 'almost', 'Four', 'up', 'these', 'here', 'teach', 'Neck', 'war', 'propaganda', 'worked', 'us', 'of', 'how', 'as', 'then', 'learned', 'first', 'something', 'about', 'it', 'really', 'students', 'had', 'attended', 'its', 'the', 'curriculum', 'school', 'felt', 'set', 'We', 'Toward', '.', 'we'}
# {'When', 'And', 'study', 'one', 'There', 'that', 'four', 'psychological', 'Pentagon', 'propaganda', 'or', 'of', 'machinery', 'no', 'any', 'has', 'We', 'ever', 'on', 'put', 'who', 'there', 'done', 'happened', 'all', 'apply', 'at', 'revealed', 'teachers', 'so', 'practitioners', 'men', 'A', 'his', 'allowed', 'refresher', 'its', 'the', '.', ',', 'hoped', 'to', 'be', 'schools', 'Alas', 'come', 'might', 'courses', 'nothing', 'academies', 'service', 'year', 'for', 'thing', 'knowledge', 'been', 'attended', 'were', 'felt', 'apparently', 'school', 'abandoned', 'each', 'warfare', 'list', 'reserve', 'did', 'and', 'end', 'such', 'in', 'some', 'back', 'is', 'being', 'sort', 'was', 'not', 'would', 'way', 'disbanded', 'called', 'rust', 'we'}
# {'hope', ',', 'Propaganda', 'and', 'Do', 'made', 'certainly', 'in', 'one', 'sparks', 'some', 'critical', 'field', 'action', 'This', 'is', 'Need', 'College', 'A', "''", 'of', 'Congratulations', 'most', 'this', 'it', '?', 'constructive', '.', 'the', 'years', 'Of', 'I', 'We', 'suggestions', 'on', 'article', '``'}
# {'house', ',', 'Richard', 'to', 'and', 'clean', 'L.', 'chose', 'Communications', 'Association', 'in', 'Tobin', 'Supplement', 'that', 'media', 'Let', 'editorial', '11', 'flattered', 'America', 'Public', 'many', 'Relations', 'us', 'of', 'his', 'public', 'March', 'Society', 'devote', 'the', 'relations', 'American', 'were', 'merger', '.', 'too'}
# {'a', 'to', 'upon', 'and', 'your', 'long', 'in', 'that', 'sorry', 'storm', 'attack', 'was', 'issue', 'of', 'book', 'detailed', 'yet', 'find', 'published', 'not', 'Snow', 'March', 'had', 'been', 'surprised', 'I', '.', '4'}
# {'judgment', 'practice', 'a', 'an', ',', 'should', 'to', 'root', 'will', 'and', 'errors', 'C.', 'made', 'advance', 'your', 'be', 'in', 'before', 'at', 'accepted', 'he', 'become', 'from', 'charged', 'attack', 'take', 'manuscript', 'copy', 'critic', 'is', 'submits', 'sort', 'forthcoming', 'was', 'But', 'publication', 'post-mortem', 'If', 'man', 'his', 'commits', 'book', 'of', 'with', 'which', 'autobiographical', 'get', 'hold', 'find', 'formality', 'able', 'fact', 'Snow', 'One', 'himself', 'this', 'P.', 'him', 'once', 'publisher', 'reviewed', 'the', 'spread', 'Whether', 'important', '.', 'heavily', 'who'}
# {'an', 'And', 'appears', 'read', 'work', 'publicly', 'Watson-Watt', 'Robert', 'copy', "Snow's", 'have', "''", 'of', 'with', 'text', 'published', 'lectures', 'Snow', 'wrote', 'SR', 'titled', 'on', 'compared', 'C.', 'detail', 'Until', 'can', 'at', 'Godkin', 'incautious', 'But', 'privileged', 'which', 'book', 'Government', 'series', 'March', ':', 'its', 'the', 'tale', 'I', '.', 'actually', ',', 'to', 'am', 'be', "'", 'Research', 'page', 'commentaries', '1960', 'for', 'challenge', 'Harvard', '``', "Editor's", 'and', '50', 'advance', 'Science', 'in', '1961', 'from', 'confidence', 'is', 'was', 'gist', 'not', 'analyze', 'Sir', 'P.', 'it', 'note', 'already', 'derived', '4'}
# {'a', 'freely', 'an', ',', 'month', 'to', 'did', 'and', 'such', 'invited', 'reaction', 'advance', 'milder', 'by', 'in', 'print', 'Lectures', 'Godkin', 'that', 'excerpt', 'from', 'Harvard', 'is', 'constitute', 'publication', 'recognize', 'impression', 'but', "book's", "Watson-Watt's", 'leaves', 'University', 'of', 'which', 'book', 'they', 'The', 'text', 'than', 'then', 'Press', 'prepublication', 'not', 'remarks', 'magazine', 'Life', 'this', 'SR', 'April', 'review', 'acknowledge', 'rebuttal', 'the', 'allowing', 'somewhat', 'date', 'publishing', '.', 'Representatives'}
# {'a', 'an', 'to', 'throughout', 'and', 'supposed', 'falsehoods', 'incoherent', 'Lindemann', 'by', 'in', 'Lectures', 'Godkin', 'unclear', 'forceful', 'from', 'Robert', 'marred', "Snow's", 'is', 'those', "''", "Watson-Watt's", 'stating', 'of', "Charles'", 'defend', 'Charles', 'himself', 'argument', 'Sir', 'while', 'rebuttal', 'apparently', 'desire', '.', 'too', '``'}
# {'a', 'an', 'and', 'absurdity', 'reader', 'by', 'at', 'conclusion', 'perverted', 'calls', 'valid', 'military', 'strategists', 'Nonsense', 'admitted', 'presents', "''", 'The', 'with', 'beginning', 'It', 'alike', 'its', 'the', 'historians', '.', 'article', '``'}
# {'an', ',', 'are', 'to', 'choose', 'account', 'Lindemann', 'basis', 'left', 'conception', 'another', 'submits', 'two', 'but', 'aspect', 'authoritative', 'man', 'of', 'than', "Charles'", 'contributing', 'It', 'no', 'Sir', 'enthusiastic', '.', 'the', 'between', 'Lindemanns', 'We', 'impressionistic', 'on', 'more'}
# {'tea', 'are', ',', 'to', 'result', 'and', 'discounted', 'inside', 'radar', 'Lindemann', 'in', 'weight', 'that', 'conception', 'actively', 'so', 'only', 'is', 'lean', 'But', 'outside', 'If', 'believe', 'man', 'of', 'The', "Charles'", 'holds', 'fact', 'supported', 'would', 'any', 'Sir', 'it', '?', 'dissembling', 'the', 'Committee', 'party', 'we', 'I', '.', 'Tizard', 'article'}
# {'a', 'unfortunate', 'an', 'to', 'print', 'at', 'Godkin', 'some', 'from', 'To', 'time', 'unjustifiable', 'reading', 'was', 'casts', 'grave', 'of', 'which', 'book', 'may', 'think', 'people', 'lectures', 'over', 'unable', 'this', 'dissuade', 'it', 'attend', 'aura', 'error', 'the', 'falsehood', 'I', '.', 'article'}

# %% [markdown]
# - Next we need to associate the labels to each of our data sets
# - Then combine together into a test set
#   - We can do this via the `itertools` built-in library
#     - Provides functions for simplifying the way of combining multi
#       iterators
#     - Here `product` is used to generate a cartesian product, in this
#       case adding the label to each element of the flattened data to
#       form a tuple
#       - We could also do this with a list comprehension, and it’s
#         arguably cleaner to do so
#       - Goal here is demonstrating `itertools`
#     - The two labelled datasets can then be merged via `itertools.chain`
#       which combines multiple iterators into one iterator sequentially
#       over each dataset
# - We want to avoid the classifier picking up on some ordering in the
#   data set (i.e. the first $x$ samples are all editorial, then the
#   remaining are fiction)
#   - So we randomly shuffle the data set via `shuffle` from the `random`
#     built-in module

# %%
import itertools
import random

import nltk
from nltk.corpus import brown, stopwords
from typing import Sequence

tell_words = {
    "american",
    "city",
    "congress",
    "country",
    "county",
    "editor",
    "fact",
    "government",
    "national",
    "nuclear",
    "party",
    "peace",
    "political",
    "power",
    "president",
    "public",
    "state",
    "states",
    "united",
    "war",
    "washington",
    "world",
    "big",
    "church",
    "every",
    "eyes",
    "face",
    "felt",
    "found",
    "god",
    "hand",
    "head",
    "home",
    "house",
    "knew",
    "moment",
    "night",
    "room",
    "seemed",
    "stood",
    "think",
    "though",
    "thought",
    "told",
    "voice",
}

# Load the data
english_stopwords = stopwords.words("english")
editorial_paragraphs = brown.paras(categories="editorial")  # load editorial paragraphs
fiction_paragraphs = brown.paras(categories="fiction")  # load only fiction paragraphs


# clean the data
def flatten(paragraph: Sequence[Sequence[str]]) -> Set[str]:
    return {word for sentence in paragraph for word in sentence}


editorial_paragraphs_flattened = [
    flatten(paragraph) for paragraph in editorial_paragraphs
]
fiction_paragraphs_flattened = [flatten(paragraph) for paragraph in fiction_paragraphs]

# Label the data
editorial_paragraphs_labelled = itertools.product(
    editorial_paragraphs_flattened, ("editorial",)
)
fiction_paragraphs_labelled = itertools.product(
    editorial_paragraphs_flattened, ("fiction",)
)
labelled_data = list(
    itertools.chain(editorial_paragraphs_labelled, fiction_paragraphs_labelled)
)

random.shuffle(labelled_data)
labelled_data
# Out:
# [({',',
#    '.',
#    ';',
#    'Board',
#    'City',
#    'Council',
#    'Estimate',
#    'Lawmaking',
#    'Mayor',
#    "Mayor's",
#    'Overriding',
#    'The',
#    'Thus',
#    'a',
#    'able',
#    'add',
#    'administrative',
#    'and',
#    'assignment',
#    'authority',
#    'be',
#    'board',
#    'both',
#    'budget',
#    'budget-altering',
#    'but',
#    'by',
#    'changes',
#    'clearer',
#    'concurrence',
#    'control',
#    'decrease',
#    'diminished',
#    'division',
#    'eliminate',
#    'franchises',
#    'from',
#    'fully',
#    'functions',
#    'in',
#    'increase',
#    'is',
#    'it',
#    'items',
#    'leases',
#    'leasing',
#    'legislative',
#    'made',
#    'mayoral',
#    'now',
#    'of',
#    'on',
#    'or',
#    'other',
#    'over',
#    'partnership',
#    'pier',
#    'power',
#    'property',
#    'removed',
#    'require',
#    'respects',
#    'responsibility',
#    'retains',
#    'sale',
#    'share',
#    'subject',
#    'the',
#    'there',
#    'this',
#    'to',
#    'trusteeship',
#    'two-thirds',
#    'veto',
#    'vote',
#    'while',
#    'will',
#    'zoning'},
#   'fiction'),
#  ({'.',
#    '6',
#    'Prisoners',
#    'Recognition',
#    'Union',
#    'a',
#    'an',
#    'and',
#    'approval',
#    'bar',
#    'be',
#    'cell',
#    'iron',
#    'member',
#    'no',
#    'occupant',
#    'of',
#    'or',
#    'participation',
#    'permitted',
#    'repair',
#    'representative',
#    'rule',
#    'sawed-off',
#    'steel',
#    'that',
#    'the',
#    'to',
#    'union',
#    'without',
#    'workers'},
#   'editorial'),
#  ({'.',
#    'An',
#    'Oriole',
#    'Paul',
#    'Richards',
#    'and',
#    'asked',
#    'ball',
#    'be',
#    'came',
#    'club',
#    'he',
#    'his',
#    'if',
#    'improved',
#    'manager',
#    'out-of-town',
#    'the',
#    'this',
#    'thought',
#    'to',
#    'today',
#    'up',
#    'would',
#    'writer',
#    'year'},
#   'fiction'),
#  ({',',
#    '.',
#    '10-year-old',
#    'Among',
#    'Capitol',
#    'County',
#    'Dist.',
#    'Dwyer',
#    "Dwyer's",
#    'Joseph',
#    'Kind',
#    'M.',
#    'Mr.',
#    'Mrs.',
#    'R-6th',
#    'Rayburn',
#    'Rep.',
#    'Sam',
#    'Speaker',
#    "Speaker's",
#    'They',
#    'Union',
#    'a',
#    'about',
#    'across',
#    'and',
#    'autograph',
#    'boy',
#    'desire',
#    'during',
#    'expressed',
#    'final',
#    'from',
#    'get',
#    'husband',
#    'is',
#    'last',
#    'late',
#    'many',
#    'of',
#    'on',
#    'one',
#    'ran',
#    'session',
#    'stories',
#    'taking',
#    'the',
#    'to',
#    'tour',
#    'was',
#    'weeks',
#    'youngster'},
#   'fiction'),
#  ({"''",
#    ',',
#    '--',
#    '.',
#    '34',
#    '9',
#    'N.M.',
#    'Roswell',
#    'We',
#    '``',
#    'a',
#    'amount',
#    'but',
#    'cohesion',
#    'defeated',
#    'from',
#    'have',
#    'just',
#    'lack',
#    'man',
#    'noted',
#    'of',
#    'returned',
#    'talent',
#    'the',
#    'to',
#    'tremendous',
#    'we',
#    'were',
#    'where',
#    'young'},
#   'editorial'),
#  ({',',
#    '.',
#    'Biblical',
#    'English',
#    'Some',
#    'To',
#    'a',
#    'almost',
#    'anyone',
#    'but',
#    'by',
#    'cadence',
#    'can',
#    'certainly',
#    'fair',
#    'in',
#    'interpretation',
#    'is',
#    'knowledge',
#    'language',
#    'lost',
#    'meaning',
#    'necessity',
#    'newer',
#    'novice',
#    'of',
#    'older',
#    'one',
#    'poetic',
#    'scholar',
#    'significant',
#    'that',
#    'the',
#    'understand',
#    'version',
#    'with',
#    'without'},
#   'fiction'),
#  ({"''",
#    '.',
#    'Aj',
#    'Democratic',
#    'Much',
#    '``',
#    'any',
#    'belongs',
#    'comfortable',
#    'consequence',
#    'every',
#    'from',
#    'its',
#    'knowledge',
#    'of',
#    'organization',
#    'stems',
#    'strength',
#    'that',
#    'the',
#    'to',
#    'volunteer'},
#   'editorial'),
#  ({',',
#    '.',
#    '60,000',
#    'Authority',
#    "Byrd's",
#    "Griffin's",
#    'If',
#    'Roads',
#    'Rural',
#    'These',
#    'and',
#    'are',
#    'contracts',
#    'county',
#    'either',
#    'end',
#    'ever',
#    'is',
#    'like',
#    'look',
#    'making',
#    'men',
#    'miles',
#    'no',
#    'oaths',
#    'of',
#    'one',
#    "pauper's",
#    'promises',
#    'spenders',
#    'started',
#    'telling',
#    'the',
#    'there',
#    'where',
#    'would'},
#   'editorial'),
#  ({',',
#    '.',
#    'American',
#    'He',
#    'House',
#    'acted',
#    'and',
#    'briefly',
#    'common',
#    'flourishes',
#    'good',
#    'it',
#    'made',
#    'oratorical',
#    'plain',
#    'point',
#    'recognized',
#    'sense',
#    'sensibly',
#    'spoke',
#    'the',
#    'to',
#    'upon',
#    'usually',
#    'without'},
#   'editorial'),
#  ({':',
#    'Charter',
#    'I',
#    'Nations',
#    'United',
#    'from',
#    'like',
#    'of',
#    'quote',
#    'the',
#    'to',
#    'would'},
#   'editorial'),
#  ({',',
#    '--',
#    '.',
#    '100-megaton',
#    '15',
#    '20-megaton',
#    '200-megaton',
#    '30-',
#    '50-megaton',
#    '?',
#    'And',
#    'B-52s',
#    'Escalation',
#    'He',
#    'It',
#    'Khrushchev',
#    'Mr.',
#    'So',
#    'Some',
#    'Soviet',
#    'States',
#    'The',
#    'They',
#    'Union',
#    'United',
#    'a',
#    'accurately',
#    'ad',
#    'ago',
#    'already',
#    'although',
#    'and',
#    'apiece',
#    'are',
#    'assume',
#    'at',
#    'be',
#    'begin',
#    'being',
#    'bigger',
#    'biggest',
#    'bomb',
#    'bombs',
#    'but',
#    'cannot',
#    'carrying',
#    'close',
#    'coming',
#    'common',
#    'contestants',
#    'correspondence',
#    'counter-escalation',
#    'course',
#    'crash',
#    'cry',
#    'death',
#    'decided',
#    'device',
#    'do',
#    'dropped',
#    'dropping',
#    'each',
#    'embark',
#    'enemy',
#    'entire',
#    'escalation',
#    'except',
#    'exist',
#    'exploded',
#    'factories',
#    'fairly',
#    'few',
#    'for',
#    'fought',
#    'getting',
#    'grounds',
#    'hand',
#    'has',
#    'have',
#    'he',
#    'his',
#    'however',
#    'hue',
#    'hydrogen',
#    'in',
#    'infinitum',
#    'instead',
#    'is',
#    'it',
#    'least',
#    'made',
#    'make',
#    'measured',
#    'megatons',
#    'more',
#    'moreover',
#    'must',
#    'neutron',
#    'not',
#    'now',
#    'nuclear',
#    'of',
#    'on',
#    'or',
#    'other',
#    'our',
#    'predicted',
#    'predictions',
#    'proceeds',
#    'program',
#    'proving',
#    'raised',
#    'respective',
#    'said',
#    'seems',
#    'side',
#    'since',
#    'some',
#    'soothsayers',
#    'stock',
#    'targets',
#    'that',
#    'the',
#    'their',
#    'them',
#    'then',
#    'thing',
#    'think',
#    'threatens',
#    'time',
#    'to',
#    'two',
#    'until',
#    'unto',
#    'us',
#    'variety',
#    'war',
#    'we',
#    'were',
#    'what',
#    'when',
#    'which',
#    'with',
#    'would',
#    'yet'},
#   'editorial'),
#  ({"''",
#    ',',
#    '--',
#    '.',
#    '26',
#    ':',
#    'Aj',
#    'All',
#    'But',
#    'Health',
#    'It',
#    'October',
#    'On',
#    'PHS',
#    'Public',
#    'Service',
#    'Soviet',
#    'States',
#    'The',
#    'Then',
#    'United',
#    '``',
#    'action',
#    'add',
#    'added',
#    'affected',
#    'agree',
#    'and',
#    'any',
#    'anywhere',
#    'as',
#    'at',
#    'average',
#    'be',
#    'biological',
#    'by',
#    'channels',
#    'citizen',
#    'conceded',
#    'concern',
#    'currents',
#    'damage',
#    'declared',
#    'depths',
#    'determine',
#    'do',
#    'effects',
#    'ever',
#    'extensive',
#    'fallout',
#    'for',
#    'from',
#    'full',
#    'generations',
#    'genetic',
#    'government',
#    'groups',
#    'hand',
#    'health',
#    'how',
#    'ill',
#    'imperative',
#    'in',
#    'individuals',
#    'intake',
#    'is',
#    'it',
#    'large',
#    'least',
#    'levels',
#    'limit',
#    'makes',
#    'many',
#    'more',
#    'most',
#    'new',
#    'nor',
#    'not',
#    'of',
#    'on',
#    'one',
#    'or',
#    'out',
#    'particles',
#    'people',
#    'points',
#    'population',
#    'possible',
#    'possibly',
#    'present',
#    'public',
#    'publicly',
#    'radiation',
#    'radioactive',
#    'recently',
#    'resulting',
#    'risk',
#    "science's",
#    'scientists',
#    'shots',
#    'some',
#    'substances',
#    'succeeding',
#    'than',
#    'that',
#    'the',
#    'these',
#    'this',
#    'to',
#    'tricky',
#    'understood',
#    'undue',
#    'unfortunately',
#    'unknown',
#    'vital',
#    'warrant',
#    'which',
#    'will',
#    'worst-marked'},
#   'editorial'),
#  ({',',
#    '.',
#    'Another',
#    'But',
#    'It',
#    'The',
#    'a',
#    'acceptable',
#    'also',
#    'and',
#    'approaches',
#    'arose',
#    'better',
#    'certain',
#    'comparison',
#    'comprehension',
#    'confrontation',
#    'contribute',
#    'conviction',
#    'developed',
#    'dialogue',
#    'differences',
#    'different',
#    'dimensions',
#    'each',
#    'ethically',
#    'ethics',
#    'expected',
#    'from',
#    'grasp',
#    'grew',
#    'group',
#    'had',
#    'has',
#    'insights',
#    'involving',
#    'issues',
#    'itself',
#    'learn',
#    'much',
#    'nature',
#    'of',
#    "one's",
#    'other',
#    "other's",
#    'own',
#    'philosophical',
#    'political',
#    'positions',
#    'produce',
#    'question',
#    'realization',
#    'solutions',
#    'stimulus',
#    'strong',
#    'substance',
#    'systems',
#    'that',
#    'the',
#    'to',
#    'undeniable',
#    'urgent',
#    'was',
#    'would'},
#   'editorial'),
#  ({'.',
#    '1962',
#    'Assembly',
#    'General',
#    'The',
#    'able',
#    'any',
#    'be',
#    'business',
#    'consider',
#    'has',
#    'important',
#    'in',
#    'is',
#    'it',
#    'manner',
#    'not',
#    'responsible',
#    'that',
#    'to',
#    'tragedy',
#    'transact',
#    'will'},
#   'fiction'),
#  ({"'",
#    "''",
#    ',',
#    '--',
#    '.',
#    'Ambassador',
#    'Dag',
#    'Hammarskjold',
#    'If',
#    'Mr.',
#    'Of',
#    'Stevenson',
#    'The',
#    'U.N.',
#    "U.N.'s",
#    '``',
#    'a',
#    'and',
#    'as',
#    'be',
#    'course',
#    'crisis',
#    'decision',
#    'described',
#    'downhill',
#    'effective',
#    'electing',
#    'faced',
#    'fears',
#    'first',
#    'goes',
#    'gravest',
#    'has',
#    'institution',
#    'is',
#    'it',
#    'late',
#    'may',
#    'meaning',
#    'of',
#    'on',
#    'operational',
#    'path',
#    'problem',
#    'responsibilities',
#    'slippery',
#    'step',
#    'successor',
#    'temporary',
#    'the',
#    'to',
#    'without',
#    'wrong',
#    'yesterday'},
#   'fiction'),
#  ({'(',
#    ')',
#    ':',
#    'Berlin',
#    'Communist',
#    'East',
#    'German',
#    'Germany',
#    'in',
#    'radio',
#    'to'},
#   'editorial'),
#  ({'(',
#    ')',
#    ',',
#    '.',
#    ':',
#    '?',
#    'British',
#    'Castro',
#    'Cheddi',
#    'Guiana',
#    'How',
#    'If',
#    'Inquirer',
#    'Jagan',
#    'Just',
#    'Red',
#    'States',
#    'To',
#    'United',
#    'We',
#    'a',
#    'all',
#    'because',
#    'before',
#    'boss',
#    'burned',
#    'editor',
#    'educated',
#    'few',
#    'get',
#    'go',
#    'gooey',
#    'got',
#    'have',
#    'he',
#    'heads',
#    'home-grown',
#    'in',
#    'is',
#    "isn't",
#    'learn',
#    'many',
#    'must',
#    'new',
#    'newest',
#    'no',
#    'of',
#    'our',
#    'over',
#    'own',
#    'proves',
#    'quite',
#    'reason',
#    'rocks',
#    'specimens',
#    'the',
#    'think',
#    'this',
#    'times',
#    'to',
#    'until',
#    'was',
#    'we',
#    "we've"},
#   'editorial'),
#  ({"''",
#    ',',
#    '.',
#    ':',
#    'Americans',
#    'Ashamed',
#    'Inquirer',
#    'It',
#    'There',
#    'They',
#    'Unfortunately',
#    '``',
#    'a',
#    'addicted',
#    'afraid',
#    'allowed',
#    'anatomy',
#    'and',
#    'are',
#    'bemoan',
#    'bodies',
#    'but',
#    'calisthenics',
#    'do',
#    'editor',
#    'fact',
#    'grown',
#    'have',
#    'heads',
#    'hearts',
#    'is',
#    'lead',
#    'not',
#    'of',
#    'on',
#    'opinion',
#    'our',
#    'part',
#    'peace',
#    'policies',
#    'power',
#    'push-ups',
#    'remedy',
#    'seek',
#    'so',
#    'so-called',
#    'soft',
#    'soft-headed',
#    'soft-heartedness',
#    'softness',
#    'stand-ups',
#    'that',
#    'the',
#    'those',
#    'to',
#    'today',
#    'too',
#    'trend',
#    'we',
#    'wealth',
#    'who',
#    'with',
#    'working',
#    'world',
#    'would',
#    'wrong'},
#   'fiction'),
#  ({"''",
#    ',',
#    '.',
#    '?',
#    'It',
#    'Peace',
#    'Russians',
#    '``',
#    'a',
#    'abiding',
#    'an',
#    'and',
#    'before',
#    'best',
#    'brief',
#    'claim',
#    'covenant',
#    'decided',
#    'extending',
#    'for',
#    'get',
#    'hope',
#    'international',
#    'into',
#    'it',
#    "it's",
#    'jumper',
#    'law',
#    "man's",
#    'moon',
#    'on',
#    'peaceful',
#    'put',
#    "shouldn't",
#    'some',
#    'space',
#    'the',
#    'too',
#    'was',
#    'we',
#    'wonderful',
#    'world',
#    'writers'},
#   'editorial'),
#  ({'(',
#    ')',
#    ',',
#    '.',
#    '23',
#    ':',
#    'Academy',
#    'America',
#    'Cross',
#    'Gerby',
#    'High',
#    'Holy',
#    'Hong',
#    'Indian',
#    'Jemela',
#    'Kong',
#    'Oriental',
#    'School',
#    'Spanish',
#    'Textile',
#    'a',
#    'an',
#    'and',
#    'at',
#    'belly',
#    'born',
#    'but',
#    'dancing',
#    'educated',
#    'family',
#    'father',
#    'has',
#    'in',
#    'learned',
#    'mother',
#    'picnics',
#    'says',
#    'seems',
#    'she',
#    'surname',
#    'was'},
#   'fiction'),
#  ({',',
#    '.',
#    'Brandt',
#    'Orioles',
#    'So',
#    'Triandos',
#    'Walker',
#    'and',
#    'are',
#    'do',
#    'have',
#    'if',
#    'improve',
#    'it',
#    'the',
#    'to',
#    'will'},
#   'fiction'),
#  ({"''",
#    ',',
#    '.',
#    'And',
#    'Frontier',
#    'Kennedy',
#    'Mr.',
#    'New',
#    'Our',
#    'President',
#    'The',
#    'We',
#    '``',
#    'a',
#    'about',
#    'aid',
#    'and',
#    'apologies',
#    'are',
#    'areas',
#    'arms',
#    'battle-cry',
#    'build-up',
#    'but',
#    'complaint',
#    'conventional',
#    'crucial',
#    'economizing',
#    'election',
#    'fiscal',
#    'in',
#    'intransigents',
#    'is',
#    'large',
#    'lost',
#    'many',
#    'measures',
#    'mollify',
#    'most',
#    'not',
#    'of',
#    'party',
#    'persists',
#    'programs',
#    'promises',
#    'regard',
#    'remember',
#    'responsibility',
#    'right',
#    'say',
#    'seriously',
#    'small',
#    'something',
#    'that',
#    'the',
#    'tightening',
#    'to',
#    'too',
#    'trying',
#    'up',
#    'used',
#    'was',
#    'welfare',
#    'wish',
#    'with',
#    'won',
#    'would',
#    'yet'},
#   'fiction'),
#  ({"''",
#    ',',
#    '.',
#    '?',
#    "Aren't",
#    'Besides',
#    'But',
#    'I',
#    'In',
#    '``',
#    'a',
#    'all',
#    'and',
#    'any',
#    'are',
#    'arm',
#    'asked',
#    'at',
#    'be',
#    'because',
#    'beg',
#    'being',
#    'breathless',
#    'but',
#    'by',
#    'can',
#    'case',
#    'certain',
#    'certainty',
#    'consider',
#    "don't",
#    'fevered',
#    'for',
#    'frighten',
#    'good',
#    'grab',
#    'guide',
#    'having',
#    'her',
#    'honesty',
#    'how',
#    'if',
#    'important',
#    'in',
#    'intoxicating',
#    'is',
#    'it',
#    'jitters',
#    'just',
#    'knew',
#    'know',
#    'lasting',
#    'life',
#    'long',
#    'looking',
#    'love',
#    'marriage',
#    'might',
#    'normal',
#    'obscured',
#    'of',
#    'one',
#    'out',
#    'pre-nuptial',
#    'question',
#    'really',
#    'recipe',
#    'relationships',
#    'satisfying',
#    'searchingly',
#    'secret',
#    'she',
#    'signposts',
#    'so',
#    'sometimes',
#    'state',
#    'such',
#    'sure',
#    'test',
#    'that',
#    'the',
#    'threw',
#    'to',
#    'usual',
#    'wait',
#    'wanted',
#    'was',
#    'were',
#    'what',
#    'worth',
#    'you'},
#   'editorial'),
#  ({"''",
#    '(',
#    ')',
#    ',',
#    '.',
#    ':',
#    '?',
#    'Berlin',
#    'China',
#    'Chinese',
#    'Formosa',
#    'Indications',
#    'Khrushchev',
#    'Koreans',
#    'North',
#    'Russia',
#    'Soviet',
#    'The',
#    'Vietnamese',
#    'What',
#    '``',
#    'add',
#    'all',
#    'and',
#    'are',
#    'attacking',
#    'before',
#    'bulk',
#    'coexistence',
#    'countries',
#    'does',
#    'embark',
#    'enough',
#    'exception',
#    'favor',
#    'feel',
#    'half',
#    'hand',
#    'him',
#    'in',
#    'is',
#    'it',
#    'just',
#    'liberating',
#    'liberation',
#    'like',
#    'long',
#    'maintenance',
#    'militarily',
#    'of',
#    'on',
#    'other',
#    'peaceful',
#    'people',
#    'quo',
#    'respective',
#    'southern',
#    'status',
#    'strong',
#    'support',
#    'that',
#    'the',
#    'their',
#    'them',
#    'they',
#    'to',
#    'up',
#    'wars',
#    'with',
#    'world',
#    'would'},
#   'editorial'),
#  ({',',
#    '.',
#    ':',
#    'But',
#    'Dominican',
#    'Republic',
#    'The',
#    'Trujillo',
#    'Unquestionably',
#    'a',
#    'all',
#    'almost',
#    'an',
#    'and',
#    'as',
#    'attracted',
#    'become',
#    'benevolent',
#    'classical',
#    'country',
#    'criticism',
#    'dictatorship',
#    'did',
#    'even',
#    'facilities',
#    'for',
#    'good',
#    'grave',
#    'he',
#    'his',
#    'history',
#    'improved',
#    'in',
#    'industry',
#    'investment',
#    'is',
#    'living',
#    'notably',
#    'of',
#    'opposition',
#    'oppressive',
#    'or',
#    'price',
#    'professedly',
#    'public',
#    'raised',
#    'recent',
#    'roads',
#    'sanitation',
#    'silence',
#    'some',
#    'standard',
#    'study',
#    'such',
#    'tends',
#    'the',
#    'things',
#    'to',
#    'was',
#    'way',
#    'which'},
#   'fiction'),
#  ({',',
#    '?',
#    'But',
#    'I',
#    'John',
#    '``',
#    'and',
#    'baptized',
#    'be',
#    'comest',
#    'forbad',
#    'have',
#    'him',
#    'me',
#    'need',
#    'of',
#    'saying',
#    'thee',
#    'thou',
#    'to'},
#   'editorial'),
#  ({',',
#    '.',
#    'Agency',
#    'Brookmont',
#    'C.',
#    'Cabin',
#    'Capital',
#    'Council',
#    'County',
#    'Darwin',
#    'Echo',
#    'George',
#    'Glen',
#    'High-speed',
#    'In',
#    'John',
#    'Memorial',
#    'Montgomery',
#    'NCTA',
#    'National',
#    'Parkway',
#    'Start',
#    'Stolzenbach',
#    'Such',
#    'Transportation',
#    'Washington',
#    'administrator',
#    'agency',
#    'all',
#    'alluring',
#    'an',
#    'and',
#    'are',
#    'area',
#    'as',
#    'attractive',
#    'be',
#    'before',
#    'between',
#    'buses',
#    'by',
#    'can',
#    'city',
#    'come',
#    'coming',
#    'constitute',
#    'difficult',
#    'do',
#    'downtown',
#    'express',
#    'for',
#    'frankly',
#    'his',
#    'if',
#    'into',
#    'launching',
#    'new',
#    'not',
#    'of',
#    'on',
#    'operating',
#    'outline',
#    'plans',
#    'presented',
#    'presenting',
#    'projects',
#    'rapid',
#    'sample',
#    'seeking',
#    'should',
#    'soon',
#    'such',
#    'support',
#    'the',
#    'this',
#    'to',
#    'transit',
#    'was',
#    'what',
#    'will',
#    'would'},
#   'editorial'),
#  ({"'",
#    "''",
#    '--',
#    '.',
#    ':',
#    'Ahmad',
#    'Bashir',
#    'If',
#    'Inquirer',
#    'Johnson',
#    'Just',
#    'Pakistani',
#    'President',
#    'Vice',
#    '``',
#    'a',
#    'and',
#    'appreciation',
#    'are',
#    'be',
#    'big',
#    'brief',
#    'camel',
#    'could',
#    'done',
#    'driver',
#    "earth's",
#    'editor',
#    'example',
#    'first-class',
#    'for',
#    'good',
#    'heartening',
#    'insignificances',
#    'many',
#    'more',
#    'note',
#    'of',
#    'often',
#    'only',
#    'people',
#    'problems',
#    'providing',
#    'really',
#    'results',
#    'shrink',
#    'such',
#    'the',
#    'they',
#    'this',
#    'to',
#    'will',
#    'with',
#    'would'},
#   'fiction'),
#  ({',',
#    '.',
#    'English',
#    'The',
#    'There',
#    'With',
#    'age',
#    'and',
#    'answer',
#    'archaic',
#    'be',
#    'become',
#    'changing',
#    'contemporary',
#    'continuous',
#    'danger',
#    'however',
#    'is',
#    'jet',
#    'marks',
#    'may',
#    'new',
#    'of',
#    'one',
#    'only',
#    'phrases',
#    'rapidity',
#    'some',
#    'soon',
#    'study',
#    'that',
#    'the',
#    'themselves',
#    'this',
#    'version',
#    'will',
#    'with',
#    'words'},
#   'fiction'),
#  ({',',
#    '.',
#    '25,000',
#    '40,000',
#    ';',
#    'All',
#    'American',
#    'But',
#    'Moloch',
#    'The',
#    'a',
#    'accompaniment',
#    'all',
#    'and',
#    'annual',
#    'any',
#    'at',
#    'be',
#    'become',
#    'blood-lust',
#    'bounds',
#    'butchery',
#    'careers',
#    'children',
#    'country',
#    'cult',
#    'demands',
#    'early',
#    'exceeding',
#    'excessive',
#    'expect',
#    'false',
#    'form',
#    'gods',
#    'heathenish',
#    'human',
#    'idol-worship',
#    'in',
#    'is',
#    'it',
#    'its',
#    'least',
#    'men',
#    'more',
#    'motor-car',
#    'of',
#    'phases',
#    'quota',
#    'reason',
#    'resemble',
#    'sacrifice',
#    'satiate',
#    'so',
#    'sufficient',
#    'than',
#    'the',
#    'their',
#    'there',
#    'things',
#    'this',
#    'to',
#    'unreasonable',
#    'widespread',
#    'without',
#    'women',
#    'would',
#    'year'},
#   'fiction'),
#  ({',',
#    '.',
#    '1952',
#    'A.',
#    'As',
#    "Batista's",
#    'Castro',
#    'Cuba',
#    'Cuban',
#    'Government',
#    'I.',
#    'P.',
#    'The',
#    'about',
#    'and',
#    'as',
#    'before',
#    'began',
#    'best',
#    'bring',
#    'by',
#    'correspondents',
#    'dictatorship',
#    'did',
#    'downfall',
#    'driven',
#    'editors',
#    'exile',
#    'forced',
#    'found',
#    'freedom',
#    'from',
#    'gradually',
#    'in',
#    'into',
#    'it',
#    'its',
#    'itself',
#    'journalism',
#    'knew',
#    'more',
#    'of',
#    'politics',
#    'press',
#    'publishers',
#    'regime',
#    'return',
#    'the',
#    'throttled',
#    'to',
#    'was',
#    'were'},
#   'fiction'),
#  ({'.',
#    'Business',
#    'In',
#    'One',
#    'Southerners',
#    'There',
#    'They',
#    'any',
#    'are',
#    'aware',
#    'causes',
#    'change',
#    'departments',
#    'economic',
#    'for',
#    'from',
#    'greatly',
#    'important',
#    'inclined',
#    'is',
#    'keep',
#    'leaders',
#    'look',
#    'many',
#    'most',
#    'now',
#    'of',
#    'on',
#    'order',
#    'other',
#    'outbreak',
#    'past',
#    'police',
#    'pressure',
#    'putting',
#    'same',
#    'strong',
#    'suffer',
#    'that',
#    'the',
#    'their',
#    'these',
#    'they',
#    'this',
#    'to',
#    'violence',
#    'way',
#    'were'},
#   'fiction'),
#  ({',',
#    '--',
#    '.',
#    ';',
#    'He',
#    'I',
#    'Inauguration',
#    'It',
#    'TV',
#    'Times',
#    'about',
#    'all',
#    'also',
#    'and',
#    'apparently',
#    'at',
#    'but',
#    'column',
#    'country',
#    'did',
#    'doing',
#    "don't",
#    'during',
#    'editor',
#    'evening',
#    'fact',
#    'had',
#    'happened',
#    'he',
#    'himself',
#    'his',
#    'hours',
#    'if',
#    'in',
#    'independent',
#    'is',
#    'it',
#    'know',
#    'letters',
#    'local',
#    'many',
#    'mention',
#    'networks',
#    'not',
#    'nothing',
#    'of',
#    'other',
#    'parts',
#    're-run',
#    'received',
#    'situation',
#    "stations'",
#    'that',
#    'the',
#    'this',
#    'to',
#    'understand',
#    'was',
#    'which',
#    'with',
#    'wrote'},
#   'fiction'),
#  ({',',
#    '.',
#    'Democrats',
#    'He',
#    'House',
#    'Mr.',
#    'Rayburn',
#    'These',
#    'With',
#    'a',
#    'an',
#    'and',
#    'because',
#    'been',
#    'before',
#    'counseling',
#    'did',
#    'do',
#    'duty',
#    'educating',
#    'efforts',
#    'excellent',
#    'expected',
#    'floor',
#    'had',
#    'he',
#    'his',
#    'in',
#    'issue',
#    'it',
#    'its',
#    'leader',
#    'long',
#    'memory',
#    'normally',
#    'on',
#    'out',
#    'patiently',
#    'persuading',
#    'pointed',
#    'political',
#    'public',
#    'rare',
#    'reached',
#    'service',
#    'test',
#    'the',
#    'their',
#    'them',
#    'thing',
#    'to',
#    'were',
#    'when'},
#   'editorial'),
#  ({',',
#    '.',
#    'We',
#    'and',
#    'assumed',
#    'at',
#    'available',
#    'body',
#    'city',
#    'commissions',
#    'committees',
#    'deliberations',
#    'had',
#    'hide',
#    'its',
#    'least',
#    'legislative',
#    'local',
#    'making',
#    'no',
#    'nothing',
#    'objections',
#    'of',
#    'public',
#    'that',
#    'the',
#    'therefore',
#    'this',
#    'to'},
#   'editorial'),
#  ({',',
#    '.',
#    'Dallas',
#    'Negroes',
#    'This',
#    'a',
#    'against',
#    'ago',
#    'all-white',
#    'attitude',
#    'bombings',
#    'change',
#    'conditions',
#    'directed',
#    'from',
#    'in',
#    'into',
#    'is',
#    'moving',
#    'neighborhoods',
#    'of',
#    'prevailed',
#    'previously',
#    'radical',
#    'series',
#    'several',
#    'the',
#    'was',
#    'were',
#    'when',
#    'which',
#    'who',
#    'years'},
#   'editorial'),
#  ({',',
#    '.',
#    'A',
#    'Algeria',
#    'China',
#    'France',
#    'Red',
#    'The',
#    'Tibet',
#    'a',
#    'and',
#    'as',
#    'bleed',
#    'bleeding',
#    'buffer',
#    'but',
#    'by',
#    'difficult',
#    'do',
#    'ever',
#    'extirpating',
#    'friendly',
#    'has',
#    'historically',
#    'hostile',
#    'institutions',
#    'integrate',
#    'is',
#    'likely',
#    'may',
#    'mistake',
#    'never',
#    'not',
#    'only',
#    "people's",
#    'religion',
#    'second',
#    'semi-independent',
#    'served',
#    'she',
#    'sometimes',
#    'state',
#    'succeed',
#    'terrain',
#    'the',
#    'this',
#    'to',
#    'too',
#    'tried',
#    'trying',
#    'vast'},
#   'fiction'),
#  ({':', 'There', 'are', 'dangers', 'other'}, 'fiction'),
#  ({'.',
#    '7',
#    'Council',
#    'Development',
#    'East',
#    'Greenwich',
#    'Island',
#    'Rhode',
#    'agreement',
#    'contract',
#    'could',
#    'enter',
#    'first',
#    'for',
#    'into',
#    'not',
#    'of',
#    'one',
#    'ourselves',
#    'planning',
#    'provide',
#    'services',
#    'the',
#    'to',
#    'towns',
#    'was',
#    'we',
#    'with'},
#   'editorial'),
#  ({"''",
#    ',',
#    '.',
#    '30',
#    ':',
#    'Assembly',
#    'Charter',
#    'Congo',
#    'Far',
#    'In',
#    'It',
#    'Meeting',
#    'New',
#    'Russian',
#    'Sept.',
#    'Smoldering',
#    'The',
#    'They',
#    'Times',
#    'U.N.',
#    'York',
#    '``',
#    'action',
#    'against',
#    'are',
#    'assessments',
#    'comment',
#    'editor',
#    'editorial',
#    'example',
#    'expulsion',
#    'following',
#    'for',
#    'in',
#    'is',
#    'make',
#    'many',
#    'membership',
#    'obligation',
#    'obligations',
#    'of',
#    'or',
#    'pay',
#    'penalty',
#    'prescribed',
#    'refusing',
#    'states',
#    'suspension',
#    'take',
#    'the',
#    'their',
#    'them',
#    'to',
#    'too',
#    'up',
#    'violating',
#    'which',
#    'you',
#    'your'},
#   'editorial'),
#  ({"''",
#    ',',
#    '.',
#    'Adventures',
#    'Decca',
#    'Howard',
#    'In',
#    'Mitchell',
#    'Music',
#    'National',
#    'RCA',
#    'Symphony',
#    'Teaching',
#    'Victor',
#    '``',
#    'a',
#    'ambitious',
#    'an',
#    'and',
#    'are',
#    'called',
#    'commercial',
#    'company',
#    'designed',
#    'each',
#    'elementary',
#    'first',
#    'for',
#    'grades',
#    'guides',
#    'has',
#    'impart',
#    'in',
#    'included',
#    'instruction',
#    'instructional',
#    'is',
#    'large',
#    'library',
#    'not',
#    'one',
#    'only',
#    'perform',
#    'project',
#    'record',
#    'releases',
#    'schools',
#    'series',
#    'stereo',
#    'the',
#    'to',
#    'two',
#    'useful',
#    'which',
#    'with'},
#   'fiction'),
#  ({'.',
#    'The',
#    'affix',
#    'an',
#    'asked',
#    'attachment',
#    'display',
#    'flag',
#    'for',
#    'further',
#    'of',
#    'place',
#    'polling',
#    'premises',
#    'proprietors',
#    'resolution',
#    'that',
#    'the',
#    'their',
#    'to'},
#   'editorial'),
#  ({',',
#    '.',
#    'Naturally',
#    'council',
#    'expanding',
#    'for',
#    'major',
#    'provide',
#    'races',
#    'statewide',
#    'test',
#    'the',
#    'will'},
#   'fiction'),
#  ({',',
#    '.',
#    ':',
#    'As',
#    'I',
#    'New',
#    'Phone',
#    'Times',
#    'York',
#    'a',
#    'business',
#    'constantly',
#    'criticized',
#    'day',
#    'editor',
#    'four',
#    'from',
#    'have',
#    'hours',
#    'man',
#    'of',
#    'service',
#    'telephone',
#    'the',
#    'three',
#    'to',
#    'use'},
#   'editorial'),
#  ({"''",
#    '.',
#    'America',
#    'Confrontation',
#    'I',
#    'Thanks',
#    'The',
#    '``',
#    'amazing',
#    'and',
#    'appeal',
#    'areas',
#    'attention',
#    'capture',
#    'certainly',
#    'continuing',
#    'direct',
#    'editorial',
#    'for',
#    'from',
#    'gained',
#    'here',
#    'in',
#    'it',
#    'its',
#    'living',
#    'many',
#    'need',
#    'of',
#    'personally',
#    'so',
#    'strength',
#    'the',
#    'this',
#    'those',
#    'to',
#    'uncover',
#    'us',
#    'was',
#    'world'},
#   'editorial'),
#  ({'.',
#    'Association',
#    'Broadcasters',
#    'Distilled',
#    'Even',
#    'Institute',
#    'National',
#    'Past',
#    'Spirits',
#    'The',
#    'a',
#    'bars',
#    'code',
#    'commercials',
#    'favor',
#    'for',
#    'had',
#    'hard-liquor',
#    'has',
#    'long',
#    'of',
#    'opinion',
#    'policy',
#    'polls',
#    'popular',
#    'prohibition',
#    'public',
#    'show',
#    'specific',
#    'specifically',
#    'the',
#    'this'},
#   'editorial'),
#  ({':', 'Moscow', 'Russian', 'Sochi', 'TASS', 'datelined', 'in'}, 'fiction'),
#  ({"''",
#    ',',
#    '.',
#    'His',
#    'Molotov',
#    '``',
#    'a',
#    'absence',
#    'altogether',
#    'an',
#    'and',
#    'armed',
#    'as',
#    'at',
#    'averting',
#    'coexistence',
#    'coincide',
#    'cold',
#    'concept',
#    'denial',
#    'enemies',
#    'fact',
#    'foreign',
#    'given',
#    'in',
#    'it',
#    'line',
#    'look',
#    'merely',
#    'moment',
#    'of',
#    'or',
#    'peace',
#    'peaceful',
#    'possibility',
#    'rather',
#    'reducing',
#    'rejects',
#    'state',
#    'the',
#    'this',
#    'those',
#    'to',
#    'upon',
#    'variant',
#    'views',
#    'war',
#    'who',
#    'with',
#    'world'},
#   'editorial'),
#  ({',',
#    '--',
#    '.',
#    'Borak',
#    'But',
#    'Civil',
#    'D.',
#    "Hock's",
#    'Laudably',
#    'Off-Broadway',
#    'Robert',
#    'The',
#    'U.S.',
#    'War',
#    'afford',
#    'and',
#    'be',
#    'boards',
#    'but',
#    'cannot',
#    'chances',
#    'cheap',
#    'classics',
#    'comparatively',
#    'enough',
#    'excuse',
#    'expense',
#    'explanation',
#    'failing',
#    'for',
#    'frequent',
#    'imagination',
#    'imports',
#    'increasing',
#    'is',
#    'it',
#    'itself',
#    'last',
#    'more',
#    'most',
#    'of',
#    'off-beat',
#    'offering',
#    'on',
#    'one',
#    'only',
#    'original',
#    'partly',
#    'playwrights',
#    'prevalence',
#    'producers',
#    'production',
#    'proving',
#    'real',
#    'seems',
#    'slightly',
#    'still',
#    'stunning',
#    'take',
#    'tested',
#    'that',
#    'the',
#    'to',
#    'trouble',
#    'true',
#    'unoriginals',
#    'was',
#    'week',
#    'where',
#    'work'},
#   'fiction'),
#  ({',',
#    '.',
#    'The',
#    '``',
#    'agencies',
#    'and',
#    'authority',
#    'decide',
#    'delegating',
#    'do',
#    'for',
#    'give',
#    'good',
#    'in',
#    'is',
#    'know',
#    'not',
#    'of',
#    'people',
#    'public',
#    'right',
#    'servants',
#    'serve',
#    'sovereignty',
#    'state',
#    'that',
#    'the',
#    'their',
#    'them',
#    'this',
#    'to',
#    'what',
#    'yield'},
#   'editorial'),
#  ({',',
#    '.',
#    'Americans',
#    'For',
#    'Governor',
#    'In',
#    'Leaving',
#    'Nelson',
#    'Rockefeller',
#    'a',
#    'an',
#    'and',
#    'anyone',
#    'are',
#    'arise',
#    'as',
#    'aside',
#    'atmospheric',
#    'be',
#    'case',
#    'cessation',
#    'choice',
#    'clearly',
#    'cogently',
#    'expressed',
#    'for',
#    'good',
#    'has',
#    'increasingly',
#    'is',
#    'large',
#    'moral',
#    'must',
#    'neither',
#    'nor',
#    'not',
#    'now',
#    'number',
#    'of',
#    'on',
#    'one',
#    'our',
#    'part',
#    'particular',
#    'prominent',
#    'proposing',
#    'question',
#    'resumption',
#    'sane',
#    'tests',
#    'that',
#    'the',
#    'to',
#    'unilateral',
#    'why',
#    'would'},
#   'fiction'),
#  ({',',
#    '.',
#    'But',
#    'Here',
#    'Mr.',
#    'Podger',
#    'The',
#    'a',
#    'and',
#    'as',
#    'at',
#    'back',
#    'before',
#    'butterflies',
#    'car',
#    'cool',
#    'could',
#    'council',
#    'dancing',
#    'darkness',
#    'driver',
#    'each',
#    'face',
#    'feel',
#    'for',
#    'friendly',
#    'grin',
#    'his',
#    'immediately',
#    'in',
#    'into',
#    'its',
#    'looked',
#    'midday',
#    'moment',
#    'of',
#    'on',
#    'other',
#    'out',
#    'over',
#    'phenomenon',
#    'private',
#    'road',
#    'room',
#    'see',
#    'shoulder',
#    'sight',
#    'sports',
#    'still',
#    'streaked',
#    'study',
#    'sun-browned',
#    'the',
#    'to',
#    'turtle',
#    'warmth',
#    'waved',
#    'withdrew',
#    'yellow',
#    'young'},
#   'fiction'),
#  ({',',
#    '.',
#    'Long-range',
#    'This',
#    'a',
#    'and',
#    'avoid',
#    'become',
#    'crisis',
#    'crisis-to-crisis',
#    'few',
#    'finance',
#    'financial',
#    'for',
#    'from',
#    'government',
#    'have',
#    'if',
#    'in',
#    'instance',
#    'insured',
#    'is',
#    'may',
#    'musts',
#    'next',
#    'now',
#    'of',
#    'planning',
#    'programs',
#    'session',
#    'state',
#    'the',
#    'them',
#    'to',
#    'two',
#    'ways',
#    'years'},
#   'fiction'),
#  ({"''",
#    ',',
#    '.',
#    '3',
#    'An',
#    'In',
#    '``',
#    'a',
#    'agreement',
#    'allowing',
#    'and',
#    'arbitration',
#    'between',
#    'board',
#    'boards',
#    'case',
#    'convicts',
#    'deadlock',
#    'decide',
#    'doors',
#    'escapees',
#    'federal',
#    'include',
#    'inmates',
#    'issue',
#    'lifer',
#    'locks',
#    'of',
#    'on',
#    'pass',
#    'prison',
#    'should',
#    'the',
#    'to',
#    'two',
#    'type',
#    'used'},
#   'editorial'),
#  ({',',
#    '.',
#    'Kremlin',
#    'While',
#    'additional',
#    'an',
#    'appreciate',
#    'assist',
#    'at',
#    'bellowing',
#    'by',
#    "can't",
#    'coexistence',
#    'contributed',
#    'he',
#    'in',
#    'it',
#    'of',
#    'philosopher',
#    'reason',
#    'rule',
#    'suicide',
#    'the',
#    'those',
#    'thru',
#    'to',
#    'was',
#    'west',
#    'who'},
#   'editorial'),
#  ({',',
#    '.',
#    'Berlin',
#    'Germany',
#    "Sunday's",
#    'This',
#    'West',
#    'Western',
#    'a',
#    'ahead',
#    'and',
#    'coalition',
#    'crucial',
#    'election',
#    'emerging',
#    'face',
#    'fact',
#    'from',
#    'government',
#    'is',
#    'key',
#    'lie',
#    'national',
#    'on',
#    'remains',
#    'tests',
#    'that',
#    'the',
#    'unification',
#    'will',
#    'with'},
#   'editorial'),
#  ({'.',
#    '3',
#    '?',
#    'American',
#    'Does',
#    'and',
#    'attack',
#    'charges',
#    'institutions',
#    'it',
#    'other',
#    'traditional',
#    'unsupportable',
#    'wild',
#    'with'},
#   'editorial'),
#  ({"''",
#    ',',
#    '.',
#    '?',
#    'From',
#    'How',
#    'TV',
#    'Writers',
#    '``',
#    'ads',
#    'adults',
#    'advertising',
#    'also',
#    'appears',
#    'are',
#    'attitude',
#    'bad',
#    'battle',
#    'by',
#    'can',
#    'children',
#    'denying',
#    'due',
#    'entirely',
#    'feel',
#    'finally',
#    'for',
#    'from',
#    'get',
#    'good',
#    'hard-sell',
#    'have',
#    'his',
#    'inspiration',
#    'inspired',
#    'is',
#    'it',
#    'modern',
#    'must',
#    'necessity',
#    'new',
#    'observed',
#    'of',
#    'old-fashioned',
#    'on',
#    'or',
#    'parents',
#    'respect',
#    'responsibility',
#    'so',
#    'some',
#    'sponsor',
#    'still',
#    'take',
#    'taste',
#    'television',
#    'that',
#    'the',
#    'their',
#    'they',
#    'type',
#    'use',
#    'we',
#    'who',
#    'without'},
#   'fiction'),
#  ({',',
#    '.',
#    'Brown',
#    'Democratic',
#    'Gov.',
#    'Moreover',
#    'also',
#    'chairmen',
#    'county',
#    'down',
#    'entire',
#    'from',
#    'hierarchy',
#    'huge',
#    'in',
#    'on',
#    'operation',
#    'participates',
#    'state',
#    'the',
#    'this',
#    'to'},
#   'fiction'),
#  ({',',
#    '.',
#    ':',
#    'As',
#    'I',
#    'New',
#    'Phone',
#    'Times',
#    'York',
#    'a',
#    'business',
#    'constantly',
#    'criticized',
#    'day',
#    'editor',
#    'four',
#    'from',
#    'have',
#    'hours',
#    'man',
#    'of',
#    'service',
#    'telephone',
#    'the',
#    'three',
#    'to',
#    'use'},
#   'fiction'),
#  ({',',
#    '.',
#    '6',
#    'City',
#    'Cowessett',
#    'East',
#    'Feelers',
#    'Greenwich',
#    'Potowomut',
#    'Warwick',
#    'a',
#    'along',
#    'and',
#    'area',
#    'areas',
#    'as',
#    'common',
#    'disposal',
#    'in',
#    'investigation',
#    'last',
#    'newspapers',
#    'of',
#    'out',
#    'put',
#    'reported',
#    'rubbish',
#    'service',
#    'suggesting',
#    'the',
#    'to',
#    'were',
#    'with',
#    'year',
#    'your'},
#   'fiction'),
#  ({"''",
#    ',',
#    '.',
#    ';',
#    'Confrontation',
#    'I',
#    'N.C.',
#    'Personally',
#    '``',
#    'a',
#    'be',
#    'by',
#    'core',
#    'deal',
#    'editorial',
#    'existence',
#    'feel',
#    'great',
#    'hit',
#    'hope',
#    'in',
#    'is',
#    'it',
#    'many',
#    'meant',
#    'my',
#    'of',
#    'only',
#    'others',
#    'our',
#    'shared',
#    'that',
#    'the',
#    'very',
#    'will'},
#   'editorial'),
#  ({',',
#    '.',
#    'Communist',
#    'Hammarskjold',
#    'He',
#    'Mr.',
#    "Nations'",
#    'The',
#    'United',
#    'against',
#    'and',
#    'attacks',
#    'because',
#    'bloc',
#    'controversial',
#    'courageously',
#    'death',
#    'defended',
#    'for',
#    'freedom',
#    'ground',
#    'he',
#    'his',
#    'justice',
#    'leader',
#    'most',
#    'nations',
#    'of',
#    'peace',
#    'removes',
#    'rights',
#    'savage',
#    'small',
#    'stood',
#    'the',
#    'uncompromising',
#    'was',
#    'with'},
#   'editorial'),
#  ({',',
#    '--',
#    '.',
#    'Braddock-against-the-Indians',
#    'But',
#    'Khrushchev',
#    'Moscow',
#    'Mr.',
#    'SEATO',
#    'Washington',
#    'and',
#    'anything',
#    'are',
#    'attempt',
#    'be',
#    'bigger',
#    'bring',
#    'can',
#    'closing',
#    'contest',
#    'disarmament',
#    'enjoyment',
#    'fact',
#    'forces',
#    'from',
#    'get',
#    'has',
#    'he',
#    'home',
#    'idea',
#    'if',
#    'it',
#    'lose',
#    'much',
#    'negotiations',
#    'not',
#    'off',
#    'other',
#    'plus',
#    'probably',
#    'ready',
#    'really',
#    'something',
#    'that',
#    'the',
#    'this',
#    'to',
#    'watching',
#    'will',
#    'with'},
#   'fiction'),
#  ({'.',
#    'Berlin',
#    'Communists',
#    'East',
#    'For',
#    'German',
#    'Germany',
#    'Soviet',
#    'Then',
#    'and',
#    'areas',
#    'as',
#    'began',
#    'between',
#    'by',
#    'capital',
#    'distinction',
#    'for',
#    'government',
#    'honored',
#    'illegally',
#    'into',
#    'it',
#    'laws',
#    'moved',
#    'of',
#    'offices',
#    'promulgating',
#    'puppet',
#    'sector',
#    'separately',
#    'some',
#    'the',
#    'they',
#    'time',
#    'to',
#    'treat',
#    'two',
#    'zone'},
#   'editorial'),
#  ({'.',
#    '98',
#    'Breeding',
#    "Don't",
#    'Gentile',
#    'ask',
#    'better',
#    'can',
#    'do',
#    'drive',
#    'hardly',
#    'him',
#    'in',
#    'might',
#    'more',
#    'move',
#    'runs',
#    'than',
#    'up'},
#   'editorial'),
#  ({"''",
#    ',',
#    '.',
#    'According',
#    'Actually',
#    'Hammarskjold',
#    'Mr.',
#    'Soviet',
#    'Union',
#    '``',
#    'a',
#    'applied',
#    'because',
#    'bestowal',
#    'by',
#    'carrying',
#    'considered',
#    'controversial',
#    'course',
#    'coveted',
#    'dictates',
#    'figure',
#    'following',
#    'given',
#    'he',
#    'headed',
#    'him',
#    'honor',
#    'however',
#    'label',
#    'last',
#    'mandate',
#    'of',
#    'one',
#    'only',
#    'organization',
#    'out',
#    'rather',
#    'report',
#    'spring',
#    'than',
#    'that',
#    'the',
#    'to',
#    'too',
#    'warrant',
#    'was',
#    'world'},
#   'editorial'),
#  ({'(',
#    ')',
#    '.',
#    '29',
#    'American',
#    'Jan.',
#    'Journal',
#    'Providence',
#    'Sunday',
#    'The',
#    'Usually',
#    'a',
#    'are',
#    'article',
#    'as',
#    'asking',
#    'being',
#    'by',
#    'care',
#    'desperate',
#    'disabilities',
#    'for',
#    'front',
#    'get',
#    'gigantic',
#    'giveaway',
#    'hang',
#    'has',
#    'have',
#    'himself',
#    'is',
#    'news',
#    'non-service-connected',
#    'of',
#    'on',
#    'page',
#    'pay',
#    'sounds',
#    'space',
#    'taxpayers',
#    'the',
#    'though',
#    'to',
#    'veteran',
#    'veterans',
#    'victimized',
#    'war',
#    'whether',
#    'who'},
#   'editorial'),
#  ({"''",
#    '(',
#    ')',
#    ',',
#    '.',
#    'ABC',
#    'Angeles',
#    'However',
#    'I',
#    'Laos',
#    'Los',
#    "President's",
#    'TV',
#    'The',
#    'Times',
#    'We',
#    '``',
#    'a',
#    'about',
#    'abuse',
#    'abused',
#    'all',
#    'am',
#    'and',
#    'answer',
#    'being',
#    'by',
#    'censored',
#    'comparing',
#    'conference',
#    'country',
#    'did',
#    'different',
#    "don't",
#    'during',
#    'edited',
#    'enough',
#    'even',
#    'evening',
#    'found',
#    'from',
#    'getting',
#    'had',
#    'he',
#    'here',
#    'hours',
#    'interested',
#    'is',
#    'know',
#    'mail',
#    'middle',
#    'of',
#    'one',
#    'or',
#    'out',
#    'over',
#    'paragraph',
#    'questions',
#    'radio',
#    're-runs',
#    'regarding',
#    'removed',
#    'run',
#    'see',
#    'snatches',
#    'station',
#    'stations',
#    'subjected',
#    'that',
#    'the',
#    'thought',
#    'to',
#    'transcripts',
#    'two',
#    'version'},
#   'fiction'),
#  ({',',
#    '.',
#    '?',
#    'I',
#    'In',
#    'It',
#    'Pets',
#    'Washington',
#    'a',
#    'accompanied',
#    'addition',
#    'afforded',
#    'and',
#    'apartment',
#    'apartments',
#    'are',
#    'at',
#    'be',
#    'break',
#    'burglars',
#    'by',
#    'companionship',
#    'degree',
#    'denied',
#    'dog',
#    'dogs',
#    'enter',
#    'feel',
#    'female',
#    'few',
#    'good',
#    'greater',
#    'growl',
#    'hardy',
#    'if',
#    'in',
#    'into',
#    'leash',
#    'met',
#    'night',
#    'not',
#    'of',
#    'on',
#    'peculiar',
#    'prone',
#    'protection',
#    'provide',
#    'providing',
#    'public',
#    'rather',
#    'residents',
#    'right',
#    'seems',
#    "someone's",
#    'streets',
#    'that',
#    'the',
#    'themselves',
#    'they',
#    'to',
#    'were',
#    'when',
#    'with',
#    'would',
#    'young'},
#   'editorial'),
#  ({',',
#    '.',
#    'After',
#    'Brown',
#    'Charlie',
#    'If',
#    'Joe',
#    'Sue',
#    'about',
#    'all',
#    'and',
#    'another',
#    'answered',
#    'are',
#    'asked',
#    'backs',
#    'became',
#    'been',
#    'children',
#    'do',
#    'does',
#    'done',
#    'embrace',
#    'exhausted',
#    'families',
#    'game',
#    'has',
#    'inquired',
#    'is',
#    'it',
#    'its',
#    'live',
#    'married',
#    'meet',
#    'moment',
#    'now',
#    'of',
#    'old',
#    'one',
#    'outcome',
#    'probable',
#    'professors',
#    'questions',
#    'recognize',
#    'slap',
#    'soon',
#    'that',
#    'the',
#    'they',
#    'was',
#    'whatever',
#    'when',
#    'where',
#    'who'},
#   'editorial'),
#  ({',',
#    '.',
#    '1945',
#    '1958',
#    '30',
#    '40',
#    '90',
#    '92',
#    'If',
#    'November',
#    'Russian',
#    'Soviet',
#    'To',
#    'a',
#    'added',
#    'age',
#    'and',
#    'atomic',
#    'be',
#    'began',
#    'between',
#    'dawn',
#    'far',
#    'fission',
#    'followed',
#    'fusion',
#    'general',
#    'half',
#    'has',
#    'in',
#    'informal',
#    'meaning',
#    'megatons',
#    'moratorium',
#    'must',
#    'new',
#    'of',
#    'pattern',
#    'previous',
#    'produced',
#    'roughly',
#    'series',
#    'shots',
#    'test',
#    'tests',
#    'that',
#    'the',
#    'this',
#    'three-power',
#    'thus',
#    'to',
#    'were',
#    'yield'},
#   'editorial'),
#  ({"'",
#    '.',
#    'A',
#    'GOP',
#    '``',
#    'and',
#    'cities',
#    'committee',
#    'ethnic',
#    'find',
#    'force',
#    'from',
#    'groups',
#    'how',
#    'in',
#    'its',
#    'may',
#    'minority',
#    'out',
#    'party',
#    'seek',
#    'support',
#    'task',
#    'the',
#    'to',
#    'will',
#    'win'},
#   'editorial'),
#  ({',',
#    '.',
#    'Dulles',
#    'Rusk',
#    'States',
#    'The',
#    'United',
#    'a',
#    'balanced',
#    'belief',
#    'danger',
#    'defense',
#    'existed',
#    'grave',
#    'has',
#    'idea',
#    'in',
#    'massive',
#    'of',
#    'removes',
#    'replacing',
#    'retaliation',
#    'strengthens',
#    'that',
#    'the',
#    'theory'},
#   'fiction'),
#  ({',',
#    '.',
#    '40',
#    "It's",
#    'League',
#    'The',
#    'Voters',
#    'Women',
#    'a',
#    'admitting',
#    'and',
#    'contributions',
#    'drive',
#    'financial',
#    'fund',
#    'good',
#    'in',
#    'inviting',
#    'is',
#    'it',
#    'its',
#    'money',
#    'now',
#    'of',
#    'on',
#    'proudly',
#    'regularly',
#    'right',
#    'side',
#    'stands',
#    'the',
#    'use',
#    'windup'},
#   'editorial'),
#  ({'?', 'Bostonian', 'Improper'}, 'editorial'),
#  ({',',
#    '.',
#    'Despite',
#    'When',
#    'all',
#    'and',
#    'anti-secrecy',
#    'argued',
#    'been',
#    'by',
#    'continuously',
#    'down',
#    'else',
#    'fails',
#    'governmental',
#    'governments',
#    'have',
#    'is',
#    'it',
#    'lip',
#    'local',
#    'open',
#    'operations',
#    'paid',
#    'rationalizations',
#    'reservations',
#    'service',
#    'sessions',
#    'slow',
#    'statutes',
#    'subverted',
#    'that',
#    'the'},
#   'editorial'),
#  ({',',
#    '.',
#    'CDC',
#    'Carvey',
#    'Democratic',
#    'Where',
#    'actually',
#    'before',
#    'believes',
#    'boundaries',
#    'by',
#    'club',
#    'clubs',
#    'district',
#    'existed',
#    'flourish',
#    'he',
#    'henceforth',
#    'increase',
#    'left',
#    'many',
#    'membership',
#    'new',
#    'one',
#    'only',
#    'reapportionment',
#    'says',
#    'split',
#    'that',
#    'these',
#    'two',
#    'which',
#    'will'},
#   'fiction'),
#  ({',',
#    '--',
#    '.',
#    'American',
#    "God's",
#    'If',
#    'We',
#    'Yet',
#    'a',
#    'accept',
#    'add',
#    'and',
#    'are',
#    'as',
#    'attendance',
#    'back',
#    'bears',
#    'bestow',
#    'bit',
#    'break',
#    'bruise',
#    'bucks',
#    'burden',
#    'but',
#    'buying',
#    'cash',
#    'church',
#    'comfortable',
#    'conceptions',
#    'conform',
#    'congregations',
#    'cruelty',
#    'defeat',
#    'do',
#    'draw',
#    'due',
#    'expect',
#    'expecting',
#    'few',
#    'first',
#    'for',
#    'from',
#    'good',
#    'he',
#    'him',
#    'his',
#    'in',
#    'infinite',
#    'instead',
#    'interpretation',
#    'is',
#    'lean',
#    'listening',
#    'man',
#    'minds',
#    'minister',
#    'not',
#    'of',
#    'ones',
#    'ostentatious',
#    'our',
#    'own',
#    'press',
#    'readily',
#    'return',
#    'sacrifice',
#    'saintliness',
#    'satisfactions',
#    'sins',
#    'soul',
#    'strength',
#    'stress',
#    'such',
#    'tell',
#    'the',
#    'their',
#    'them',
#    'this',
#    'through',
#    'to',
#    'upon',
#    'us',
#    'we',
#    'week',
#    'what',
#    'while',
#    'who',
#    'with',
#    "won't",
#    'word'},
#   'editorial'),
#  ({',',
#    '.',
#    'California',
#    'I',
#    "Kennedy's",
#    'President',
#    'Southern',
#    'You',
#    'a',
#    'activities',
#    'an',
#    'and',
#    'as',
#    'blackout',
#    'chance',
#    'concerned',
#    'concerning',
#    'conference',
#    'devote',
#    'early',
#    'far',
#    'form',
#    'gives',
#    'have',
#    'idea',
#    'in',
#    'intelligent',
#    'is',
#    'issue',
#    'it',
#    'like',
#    'more',
#    'news',
#    'occasion',
#    'of',
#    'on',
#    'one',
#    'opinions',
#    'people',
#    'praised',
#    'press',
#    'see',
#    'so',
#    'some',
#    'space',
#    'televised',
#    'than',
#    'the',
#    'to',
#    'would',
#    'you'},
#   'editorial'),
#  ({',',
#    '.',
#    '1953',
#    'Act',
#    'Brown',
#    'California',
#    'Legislature',
#    'Sacramento',
#    'Since',
#    'The',
#    'be',
#    'business',
#    'but',
#    'conducted',
#    'did',
#    'efforts',
#    'enacting',
#    'five',
#    'full',
#    'guarantees',
#    'has',
#    'however',
#    'implementation',
#    'in',
#    'lawmakers',
#    'led',
#    'loopholes',
#    'nation',
#    'noble',
#    'not',
#    'of',
#    'plug',
#    'public',
#    'publicly',
#    'remaining',
#    'sessions',
#    'shall',
#    'taken',
#    'that',
#    'the',
#    'these',
#    'this',
#    'until',
#    'words',
#    'year'},
#   'editorial'),
#  ({',',
#    '.',
#    'Balaguer',
#    'Ciudad',
#    'Mr.',
#    'None',
#    'Outwardly',
#    'Trujillo',
#    'a',
#    'and',
#    'calm',
#    'coalition',
#    'control',
#    'elections',
#    'excuse',
#    'family',
#    'free',
#    'further',
#    'government',
#    'have',
#    'his',
#    'in',
#    'is',
#    'leaders',
#    'no',
#    'of',
#    'offer',
#    'opposition',
#    'preliminary',
#    'remains',
#    'spring',
#    'suspect',
#    'the',
#    'to'},
#   'editorial'),
#  ({',',
#    '.',
#    'Kremlin',
#    'While',
#    'additional',
#    'an',
#    'appreciate',
#    'assist',
#    'at',
#    'bellowing',
#    'by',
#    "can't",
#    'coexistence',
#    'contributed',
#    'he',
#    'in',
#    'it',
#    'of',
#    'philosopher',
#    'reason',
#    'rule',
#    'suicide',
#    'the',
#    'those',
#    'thru',
#    'to',
#    'was',
#    'west',
#    'who'},
#   'fiction'),
#  ({'(',
#    ')',
#    ',',
#    '.',
#    'Communists',
#    'Douglas',
#    'Masaryk',
#    'against',
#    'aid',
#    'and',
#    'consistently',
#    'destruction',
#    'died',
#    'etc.',
#    'for',
#    'foreign',
#    'freedom',
#    'has',
#    'housing',
#    'individual',
#    'killed',
#    'of',
#    'people',
#    'principles',
#    'public',
#    'the',
#    'to',
#    'uphold',
#    'voted',
#    'who'},
#   'fiction'),
#  ({'.',
#    '1957',
#    "Adenauer's",
#    'Bundestag',
#    'Chancellor',
#    'Christian',
#    'Democratic',
#    'In',
#    'Inevitably',
#    'Party',
#    'a',
#    'absolute',
#    'but',
#    'compromise',
#    'deal',
#    'enjoyed',
#    'enough',
#    'form',
#    'gained',
#    'government',
#    'has',
#    'in',
#    'it',
#    'little',
#    'lose',
#    'majority',
#    'means',
#    'must',
#    'new',
#    'of',
#    'one',
#    'only',
#    'order',
#    'parties',
#    'rival',
#    'since',
#    'slipped',
#    'some',
#    'strength',
#    'the',
#    'this',
#    'to',
#    'two',
#    'voting',
#    'was',
#    'which',
#    'with'},
#   'editorial'),
#  ({',',
#    '.',
#    '350th',
#    'Bible',
#    'English',
#    'James',
#    'King',
#    'New',
#    'Scriptures',
#    'Testament',
#    'The',
#    'a',
#    'anniversary',
#    'as',
#    'being',
#    'celebrated',
#    'contemporary',
#    'first',
#    'into',
#    'is',
#    'new',
#    'of',
#    'part',
#    'publishing',
#    'simultaneously',
#    'the',
#    'today',
#    'translation',
#    'undertaken',
#    'with'},
#   'editorial'),
#  ({'(',
#    ')',
#    ',',
#    '.',
#    '367',
#    ':',
#    'A',
#    'Alan',
#    'Berlin',
#    'Clark',
#    'Department',
#    'East',
#    'Lippmann',
#    'Nation',
#    'Or',
#    'State',
#    'Tanks',
#    'The',
#    'Walter',
#    'West',
#    'Western',
#    'a',
#    'again',
#    'and',
#    'are',
#    'at',
#    'avail',
#    'be',
#    'blocks',
#    'border',
#    'both',
#    'boundary',
#    'bring',
#    'but',
#    'can',
#    'city',
#    'commentators',
#    'compromise',
#    'down',
#    'driving',
#    'escort',
#    'for',
#    'glow',
#    'graveyard',
#    'hand',
#    'handwriting',
#    'have',
#    'helpful',
#    'hope',
#    'if',
#    'in',
#    'into',
#    'intransigence',
#    'is',
#    'it',
#    'leave',
#    'lies',
#    'lined',
#    'materials',
#    'military',
#    'monument',
#    'more',
#    'no',
#    'not',
#    'of',
#    'officials',
#    'on',
#    'only',
#    'other',
#    'out',
#    'p.',
#    'passes',
#    'refusing',
#    'reunite',
#    'save',
#    'see',
#    'show',
#    'sides',
#    'sober',
#    'spelled',
#    'that',
#    'the',
#    'their',
#    'them',
#    'to',
#    'triumph',
#    'two',
#    'under',
#    'up',
#    'wall',
#    'wants',
#    'what',
#    'which',
#    'will',
#    'without'},
#   'fiction'),
#  ({',',
#    '.',
#    '1960',
#    '1961',
#    'Brooks',
#    'Robby',
#    "Robby's",
#    'Robinson',
#    'You',
#    'and',
#    'be',
#    'better',
#    "can't",
# ...
#    'those',
#    'to',
#    'traditional',
#    'wedded',
#    'who',
#    'would'},
#   'editorial'),
#  ({',',
#    '.',
#    '1920',
#    '1961',
#    'A',
#    'Adams',
#    'Amsterdam',
#    'Berniece',
#    'But',
#    'Cyril',
#    'Dalton',
#    'Girls',
#    'I',
#    'Janssen',
#    'Jarvis',
#    'Mrs.',
#    'N.Y.',
#    'New',
#    'Ring',
#    'Robert',
#    'Theater',
#    'Walter',
#    'Ziegfeld',
#    'a',
#    'and',
#    'be',
#    'bevy',
#    'bread',
#    'by',
#    'century',
#    'could',
#    'determined',
#    'down',
#    'dreams',
#    'glamorous',
#    'gone',
#    'grandmothers',
#    'has',
#    'low-calorie',
#    'no',
#    'of',
#    'old',
#    'order',
#    'quarter',
#    'sashayed',
#    'seafood',
#    'see',
#    'since',
#    'staircases',
#    'the',
#    'this',
#    'to',
#    'up',
#    'walking',
#    'watching',
#    'were'},
#   'fiction'),
#  ({',',
#    '.',
#    'Assembly',
#    'General',
#    'It',
#    'The',
#    'a',
#    'abandoning',
#    'adjourns',
#    'an',
#    'and',
#    'atmosphere',
#    'brought',
#    'conjunction',
#    'convened',
#    'crisis',
#    'day',
#    'decision',
#    'education',
#    'faced',
#    'from',
#    'good',
#    'governor',
#    'has',
#    'immediately',
#    'in',
#    'issue',
#    'it',
#    'met',
#    'much',
#    'not',
#    'of',
#    'on',
#    'performed',
#    'public',
#    'risk',
#    'schools',
#    'session',
#    'showdown',
#    'squarely',
#    'struggle',
#    'the',
#    'to',
#    'today',
#    'was',
#    'which',
#    'with'},
#   'editorial'),
#  ({'.',
#    'In',
#    'It',
#    'about',
#    'any',
#    'areas',
#    'automate',
#    'been',
#    'brought',
#    'company',
#    'dialing',
#    'effort',
#    'few',
#    'great',
#    'has',
#    'keep',
#    'last',
#    'managed',
#    'many',
#    'mechanization',
#    'mental',
#    'my',
#    'new',
#    'not',
#    'of',
#    'on',
#    'part',
#    'service',
#    'telephone',
#    'the',
#    'their',
#    'this',
#    'to',
#    'up',
#    'ways',
#    'which',
#    'with',
#    'years'},
#   'fiction'),
#  ({"''",
#    ',',
#    '.',
#    'Association',
#    'Catholic',
#    'Ethics',
#    'International',
#    'October',
#    'Peace',
#    'Protestants',
#    'Two',
#    'Washington',
#    '``',
#    'a',
#    'addresses',
#    'and',
#    'annual',
#    'another',
#    'at',
#    'be',
#    'by',
#    'dais',
#    'delivered',
#    'dialogue',
#    'discussant',
#    'effective',
#    'for',
#    'in',
#    'introduction',
#    'last',
#    'meeting',
#    'of',
#    'on',
#    'one',
#    'peace',
#    'persuasion',
#    'principal',
#    'principle',
#    'prominent',
#    'proved',
#    'religious',
#    'speaker',
#    'strikingly',
#    'tended',
#    'the',
#    'thirty-fourth',
#    'to',
#    'was',
#    'weekend',
#    'were',
#    'when'},
#   'editorial'),
#  ({',',
#    '.',
#    'But',
#    'Georgia',
#    'The',
#    'are',
#    'areas',
#    'dragging',
#    'has',
#    'in',
#    'intensive',
#    'is',
#    'made',
#    'many',
#    'other',
#    'program',
#    'reforms',
#    'so',
#    'some',
#    'still',
#    'treatment',
#    'true',
#    'we',
#    'well',
#    'working'},
#   'editorial'),
#  ({'.',
#    'You',
#    'any',
#    'better',
#    "can't",
#    'certainly',
#    'did',
#    'do',
#    'expect',
#    'infield',
#    'it',
#    'last',
#    'than',
#    'the',
#    'to',
#    'year'},
#   'fiction'),
#  ({',',
#    '.',
#    '39-year-old',
#    "Aircraft's",
#    'At',
#    'B.',
#    'CDC',
#    'Carvey',
#    'Democratic',
#    "He's",
#    'Hughes',
#    'Jr.',
#    'Thomas',
#    'amateur',
#    'an',
#    'approached',
#    'develop',
#    'duties',
#    'engineering',
#    'fashion',
#    'hard-nosed',
#    'head',
#    'helping',
#    'his',
#    'in',
#    'is',
#    'missiles',
#    'moon',
#    'normal',
#    'of',
#    'politico',
#    'profession',
#    'the',
#    'unorthodox',
#    'whose'},
#   'fiction'),
#  ({"''",
#    '(',
#    ')',
#    ',',
#    '.',
#    'Bertha',
#    'Had',
#    'I',
#    'Madeira',
#    "Today's",
#    'Voice',
#    '``',
#    'a',
#    'been',
#    'clarified',
#    'floor',
#    'granted',
#    'have',
#    'incorrect',
#    'information',
#    'matter',
#    'obtained',
#    'of',
#    'on',
#    'personal',
#    'point',
#    'privilege',
#    'raised',
#    'regret',
#    'she',
#    'that',
#    'the',
#    'would'},
#   'fiction'),
#  ({"''",
#    '(',
#    ')',
#    ',',
#    '.',
#    '12',
#    '1944',
#    '1949',
#    'After',
#    'American',
#    'Berlin',
#    'British',
#    'Council',
#    'Foreign',
#    'French',
#    'Germany',
#    'Greater',
#    'It',
#    'Ministers',
#    'September',
#    'Soviet',
#    'The',
#    '``',
#    'a',
#    'administrative',
#    'airlift',
#    'and',
#    'any',
#    'area',
#    'be',
#    'blockade',
#    'by',
#    'city',
#    'comprising',
#    'declared',
#    'designated',
#    'division',
#    'effects',
#    'entire',
#    'for',
#    'four',
#    'in',
#    'joint',
#    'later',
#    'mitigate',
#    'not',
#    'occupation',
#    'of',
#    'one',
#    'part',
#    'present',
#    'protocol',
#    'purpose',
#    'respectively',
#    'special',
#    'the',
#    'three',
#    'to',
#    'troops',
#    'under',
#    'wartime',
#    'was',
#    'zones'},
#   'editorial'),
#  ({"''",
#    '.',
#    'Florida',
#    'The',
#    '``',
#    'a',
#    'and',
#    'arise',
#    'as',
#    'assess',
#    'at',
#    'both',
#    'civil',
#    'committee',
#    'continues',
#    'efforts',
#    'entire',
#    'equitable',
#    'feel',
#    'from',
#    'has',
#    'in',
#    'its',
#    'levels',
#    'local',
#    'of',
#    'problems',
#    'program',
#    'progressed',
#    'review',
#    'rights',
#    'sound',
#    'spectrum',
#    'state',
#    'that',
#    'the',
#    'they',
#    'time',
#    'to',
#    'transition'},
#   'fiction'),
#  ({',',
#    '.',
#    'Pod',
#    'Podgers',
#    'September',
#    'The',
#    'This',
#    'a',
#    'about',
#    'ages',
#    'all',
#    'always',
#    'bursting',
#    'but',
#    'cool',
#    'cottage',
#    'evening',
#    'front',
#    'gathering',
#    'holding',
#    'in',
#    'little',
#    'moving',
#    'neighborhood',
#    'night',
#    'not',
#    'of',
#    'on',
#    'people',
#    'plenty',
#    'same',
#    'spent',
#    'still',
#    'summer',
#    'the',
#    'was',
#    'way',
#    'were',
#    'with',
#    'year'},
#   'editorial'),
#  ({'.',
#    'Betting',
#    'But',
#    'Labor',
#    'Secretary',
#    'a',
#    'activity',
#    'apparently',
#    'as',
#    'be',
#    'economic',
#    'even',
#    'for',
#    'forecasting',
#    'hazardous',
#    'he',
#    'his',
#    'is',
#    'job',
#    'men',
#    'now',
#    'of',
#    'prognosticator',
#    'reputation',
#    'requires',
#    'risk',
#    'specialist',
#    'that',
#    'the',
#    'to',
#    'trends',
#    'undertaking',
#    'unemployment',
#    'willing'},
#   'editorial'),
#  ({',',
#    '.',
#    '100',
#    'Berlin',
#    'Khrushchev',
#    'Meanwhile',
#    'Moscow',
#    'TNT',
#    'West',
#    'a',
#    'adding',
#    'backward',
#    'bit',
#    'bomb',
#    'build',
#    'by',
#    "can't",
#    'communism',
#    'equal',
#    'heads',
#    'his',
#    'in',
#    'into',
#    'justice',
#    'knock',
#    'law',
#    'march',
#    'million',
#    'oafs',
#    'of',
#    'promising',
#    'see',
#    'sense',
#    'surrendering',
#    'the',
#    'those',
#    'to',
#    'tons',
#    'wallop',
#    'was',
#    'who',
#    'with',
#    'world'},
#   'editorial'),
#  ({',',
#    '.',
#    '50',
#    "Florida's",
#    'Problems',
#    'The',
#    'While',
#    'a',
#    'advisory',
#    'among',
#    'and',
#    'arisen',
#    'been',
#    'but',
#    'by',
#    'cases',
#    'committee',
#    'fast',
#    'field',
#    'good',
#    'handled',
#    'have',
#    'in',
#    'is',
#    'most',
#    'move',
#    'one',
#    'others',
#    'out',
#    'progress',
#    'real',
#    'record',
#    'reported',
#    'restraint',
#    'sensitive',
#    'slowly',
#    'some',
#    'stands',
#    'the',
#    'think',
#    'this',
#    'too',
#    'understanding',
#    'we',
#    'with'},
#   'fiction'),
#  ({',',
#    '.',
#    'Committee',
#    'National',
#    'Republican',
#    'Since',
#    'always',
#    'analyzed',
#    'and',
#    'as',
#    'autumn',
#    'cities',
#    'defeat',
#    'finds',
#    'in',
#    'is',
#    'it',
#    'its',
#    'larger',
#    'last',
#    'not',
#    'obvious',
#    'occurred',
#    'of',
#    'suspected',
#    'that',
#    'the',
#    'true',
#    'wisely'},
#   'editorial'),
#  ({',',
#    '.',
#    '?',
#    'Commissioners',
#    'I',
#    'a',
#    'and',
#    'apartments',
#    'attack',
#    'based',
#    'be',
#    'but',
#    'consider',
#    'dog',
#    'dogs',
#    'for',
#    'get',
#    'grant',
#    'his',
#    'how',
#    'if',
#    'in',
#    'lady',
#    'landlords',
#    'liberalizing',
#    'like',
#    'looking',
#    'may',
#    'molest',
#    'not',
#    'of',
#    'on',
#    'or',
#    'person',
#    'practice',
#    'prohibiting',
#    'protective',
#    'purse',
#    'quick',
#    'really',
#    'roaming',
#    'snatch',
#    'streets',
#    'strolling',
#    'suggest',
#    'that',
#    'the',
#    'to',
#    'together',
#    'training',
#    'were',
#    'with',
#    'would',
#    'you',
#    'young'},
#   'editorial'),
#  ({"''",
#    ',',
#    '?',
#    'What',
#    '``',
#    'any',
#    'beans',
#    'come',
#    'do',
#    'echoed',
#    'in',
#    'of',
#    'others',
#    'potatoes',
#    'the',
#    'those',
#    'tomatoes',
#    'us',
#    'will',
#    'with',
#    'world'},
#   'fiction'),
#  ({"''",
#    ',',
#    '.',
#    'If',
#    'Politics',
#    'Say',
#    '``',
#    'a',
#    'accelerating',
#    'accuses',
#    'adage',
#    'an',
#    'deny',
#    "don't",
#    'game',
#    'he',
#    'horse',
#    'is',
#    'it',
#    'lying',
#    'of',
#    'old',
#    'opponent',
#    'runs',
#    'thief',
#    'you'},
#   'editorial'),
#  ({'.',
#    '7',
#    'Council',
#    'Development',
#    'East',
#    'Greenwich',
#    'Island',
#    'Rhode',
#    'agreement',
#    'contract',
#    'could',
#    'enter',
#    'first',
#    'for',
#    'into',
#    'not',
#    'of',
#    'one',
#    'ourselves',
#    'planning',
#    'provide',
#    'services',
#    'the',
#    'to',
#    'towns',
#    'was',
#    'we',
#    'with'},
#   'fiction'),
#  ({',',
#    '.',
#    'Secondly',
#    'So',
#    'VA',
#    'a',
#    'can',
#    'chance',
#    'effects',
#    'going',
#    'have',
#    'he',
#    'his',
#    'hospital',
#    'in',
#    'is',
#    'keeps',
#    'knows',
#    'leaves',
#    'longer',
#    'no',
#    'observe',
#    'of',
#    'or',
#    'patient',
#    'physician',
#    'surgery',
#    'that',
#    'the',
#    'to',
#    'treatment',
#    'until',
#    'veteran',
#    'visit',
#    'when'},
#   'fiction'),
#  ({'.',
#    'British',
#    'But',
#    'States',
#    'United',
#    'a',
#    'and',
#    'back',
#    'been',
#    'by',
#    'cease-fire',
#    'conference',
#    'fall',
#    'followed',
#    'for',
#    'has',
#    'interested',
#    'is',
#    'last',
#    'moving',
#    'now',
#    'observers',
#    'of',
#    'outside',
#    'patrolled',
#    'plan',
#    'position',
#    'powers',
#    'pro-neutralist',
#    'ready',
#    'since',
#    'the',
#    'to',
#    'toward'},
#   'editorial'),
#  ({',',
#    '.',
#    '100-ton',
#    '60',
#    'By',
#    'Southern',
#    'The',
#    'a',
#    'about',
#    'and',
#    'as',
#    'associated',
#    'at',
#    'back',
#    'barge',
#    'business',
#    'can',
#    'car',
#    'cent',
#    'conventional',
#    'costs',
#    'deal',
#    'developing',
#    'for',
#    'good',
#    'grain',
#    'half',
#    'has',
#    'have',
#    'hope',
#    'hopper',
#    'in',
#    'it',
#    'its',
#    'lines',
#    'lost',
#    'lower',
#    'money',
#    'move',
#    'much',
#    'of',
#    'originated',
#    'per',
#    'railroads',
#    'railway',
#    'rates',
#    'reducing',
#    'request',
#    'says',
#    'smaller',
#    'some',
#    'spent',
#    'the',
#    'they',
#    'time',
#    'to',
#    'truckers',
#    'what',
#    'which',
#    'win',
#    'with'},
#   'fiction'),
#  ({',',
#    '--',
#    '.',
#    "Governor's",
#    'Russians',
#    'The',
#    'What',
#    'a',
#    'ahead',
#    'argument',
#    'arguments',
#    'as',
#    'asserted',
#    'be',
#    'because',
#    'become',
#    'brutalized',
#    'closer',
#    'come',
#    'course',
#    'demand',
#    'desirable',
#    'does',
#    'enable',
#    'ethical',
#    'from',
#    'get',
#    'have',
#    'he',
#    'in',
#    'is',
#    'leap',
#    'make',
#    'many',
#    'may',
#    'might',
#    'militarily',
#    'missing',
#    'moral',
#    'needed',
#    'not',
#    'now',
#    'nuclear',
#    'of',
#    'one',
#    'or',
#    'possibility',
#    'premise',
#    'right',
#    'similar',
#    'so',
#    'superiority',
#    'supply',
#    'taken',
#    'tests',
#    'that',
#    'the',
#    'their',
#    'to',
#    'unless',
#    'unwittingly',
#    'us',
#    'was',
#    'we',
#    'what',
#    'which',
#    'would'},
#   'editorial'),
#  ({"''",
#    ',',
#    '.',
#    '1',
#    'Amory',
#    'April',
#    'Bible',
#    'Cleveland',
#    'English',
#    'F.',
#    'I',
#    'It',
#    'James',
#    'King',
#    'L.',
#    "Lucas's",
#    'Messing',
#    'New',
#    "SR's",
#    '``',
#    'a',
#    'analysis',
#    'and',
#    'around',
#    'article',
#    'at',
#    'be',
#    'best',
#    'blind',
#    'by',
#    'certainly',
#    'column',
#    'comment',
#    'dogmatism',
#    'fair',
#    'first',
#    'fundamentalist',
#    'his',
#    'hope',
#    'impression',
#    'in',
#    'is',
#    'issue',
#    'left',
#    'minds',
#    'month',
#    'objective',
#    'of',
#    'perilous',
#    'rather',
#    'readers',
#    'say',
#    'seemed',
#    'seems',
#    'sport',
#    'than',
#    'the',
#    'this',
#    'to',
#    'us',
#    'version',
#    'very',
#    'will',
#    'with'},
#   'fiction'),
#  ({',',
#    '.',
#    '1961',
#    'But',
#    'In',
#    'The',
#    'Washington',
#    'a',
#    'acreage',
#    'and',
#    'been',
#    'between',
#    'billion',
#    'by',
#    'declared',
#    'distance',
#    'dollar',
#    'exchange',
#    'farmers',
#    'feed',
#    'fertilizer',
#    'fiasco',
#    'for',
#    'grain',
#    'growers',
#    'has',
#    'higher',
#    'in',
#    'on',
#    'outsmarted',
#    'planted',
#    'pledged',
#    'pouring',
#    'price',
#    'program',
#    'reduction',
#    'rows',
#    'secretary',
#    'shortening',
#    'sponsored',
#    'supports',
#    'the',
#    'which'},
#   'editorial'),
#  ({'.',
#    ':',
#    'Defends',
#    'Expressway',
#    'I',
#    'Inquirer',
#    'Schuylkill',
#    'Without',
#    'an',
#    'and',
#    'be',
#    'been',
#    'big',
#    'carrying',
#    'concrete',
#    'editor',
#    'for',
#    'future',
#    'had',
#    'highways',
#    'idea',
#    'if',
#    'it',
#    'just',
#    'massive',
#    'not',
#    'of',
#    'on',
#    'rock',
#    'still',
#    'the',
#    'there',
#    'these',
#    'to',
#    'trucks',
#    'worked',
#    'would',
#    "wouldn't"},
#   'editorial'),
#  ({',',
#    '.',
#    'Letter',
#    'Most',
#    'Occasional',
#    'Our',
#    'a',
#    'and',
#    'another',
#    'are',
#    'art',
#    'be',
#    'but',
#    'by',
#    'called',
#    'companies',
#    'consists',
#    'could',
#    'creditors',
#    'days',
#    'do',
#    'dying',
#    'forget',
#    'individuals',
#    'is',
#    'letter',
#    'letters',
#    'mail',
#    'many',
#    'mostly',
#    'not',
#    'nothing',
#    'of',
#    'one',
#    'sent',
#    'that',
#    'these',
#    'to',
#    'truly',
#    'typewritten',
#    'us',
#    'writing',
#    'written'},
#   'fiction'),
#  ({',',
#    '.',
#    'It',
#    'Newark',
#    'actively',
#    'also',
#    'and',
#    'by',
#    'challenge',
#    'civic',
#    'community',
#    'desire',
#    'exhibit',
#    'him',
#    'in',
#    'life',
#    'live',
#    'make',
#    'of',
#    'participate',
#    'phase',
#    'presented',
#    'religious',
#    'school',
#    'should',
#    'so',
#    'that',
#    'the',
#    'this',
#    'to',
#    'up',
#    'will'},
#   'fiction'),
#  ({',',
#    '.',
#    'A',
#    'We',
#    'a',
#    'adapt',
#    'and',
#    'autism',
#    'believe',
#    'can',
#    'child',
#    'conditions',
#    'defect',
#    'deviation',
#    'differently',
#    'difficulties',
#    'extent',
#    'help',
#    'his',
#    'inborn',
#    'is',
#    'large',
#    'like',
#    'many',
#    'mother',
#    'of',
#    'other',
#    'so',
#    'that',
#    'think',
#    'to'},
#   'editorial'),
#  ({"''",
#    ',',
#    '.',
#    '1962',
#    'Aj',
#    'Carvey',
#    'Democratic',
#    'Hence',
#    'Like',
#    '``',
#    'a',
#    'attention',
#    'be',
#    'lavishing',
#    'most',
#    'on',
#    'partisan',
#    'predicts',
#    'spokesmen',
#    'the',
#    "they're",
#    'tremendously',
#    'will',
#    'year'},
#   'fiction'),
#  ({'.',
#    'N.C.',
#    'be',
#    'has',
#    'important',
#    'many',
#    'piece',
#    'preacher',
#    'quote',
#    'said',
#    'so',
#    'something',
#    'tempted',
#    'that',
#    'the',
#    'this',
#    'times',
#    'to',
#    'well',
#    'whole',
#    'will'},
#   'editorial'),
#  ({'?', 'Mental', 'telepathy'}, 'editorial'),
#  ({"''",
#    '.',
#    'Florida',
#    'The',
#    '``',
#    'a',
#    'and',
#    'arise',
#    'as',
#    'assess',
#    'at',
#    'both',
#    'civil',
#    'committee',
#    'continues',
#    'efforts',
#    'entire',
#    'equitable',
#    'feel',
#    'from',
#    'has',
#    'in',
#    'its',
#    'levels',
#    'local',
#    'of',
#    'problems',
#    'program',
#    'progressed',
#    'review',
#    'rights',
#    'sound',
#    'spectrum',
#    'state',
#    'that',
#    'the',
#    'they',
#    'time',
#    'to',
#    'transition'},
#   'editorial'),
#  ({'.',
#    'Angeles',
#    'During',
#    'Los',
#    'a',
#    'about',
#    'actually',
#    'an',
#    'day',
#    'dozen',
#    'drivers',
#    'driving',
#    'entire',
#    'impossible',
#    'lane',
#    'me',
#    'occasions',
#    'of',
#    'oncoming',
#    'one',
#    'out',
#    'permit',
#    'pull',
#    'recent',
#    'side',
#    'stopped',
#    'street',
#    'there',
#    'to',
#    'traffic',
#    'were',
#    'when'},
#   'fiction'),
#  ...]

# %% [markdown]
# - To use the classifier we have to convert our paragraphs into a
#   *feature set*
#   - Form of a dictionary mapping features to values
# - Here our features are the presence or absence of a given tell word
#   - Marked via a boolean flag
# - Again can be implemented via a simple function `define_features`
#   - We use a *dictionary comprehension* for the function implementation
#     (See again the discussion of list comprehensions and set
#     comprehensions)

# %%
import itertools
import random

import nltk
from nltk.corpus import brown, stopwords
from typing import Sequence

tell_words = {
    "american",
    "city",
    "congress",
    "country",
    "county",
    "editor",
    "fact",
    "government",
    "national",
    "nuclear",
    "party",
    "peace",
    "political",
    "power",
    "president",
    "public",
    "state",
    "states",
    "united",
    "war",
    "washington",
    "world",
    "big",
    "church",
    "every",
    "eyes",
    "face",
    "felt",
    "found",
    "god",
    "hand",
    "head",
    "home",
    "house",
    "knew",
    "moment",
    "night",
    "room",
    "seemed",
    "stood",
    "think",
    "though",
    "thought",
    "told",
    "voice",
}

# Load the data
english_stopwords = stopwords.words("english")
editorial_paragraphs = brown.paras(categories="editorial")  # load editorial paragraphs
fiction_paragraphs = brown.paras(categories="fiction")  # load only fiction paragraphs


# clean the data
def flatten(paragraph: Sequence[Sequence[str]]) -> Set[str]:
    return {word for sentence in paragraph for word in sentence}


editorial_paragraphs_flattened = [
    flatten(paragraph) for paragraph in editorial_paragraphs
]
fiction_paragraphs_flattened = [flatten(paragraph) for paragraph in fiction_paragraphs]

# Label the data
editorial_paragraphs_labelled = itertools.product(
    editorial_paragraphs_flattened, ("editorial",)
)
fiction_paragraphs_labelled = itertools.product(
    editorial_paragraphs_flattened, ("fiction",)
)
labelled_data = list(
    itertools.chain(editorial_paragraphs_labelled, fiction_paragraphs_labelled)
)
random.shuffle(labelled_data)


# create the feature sets
def define_features(paragraph: Set[str], feature_words: Set[str]) -> dict[str, bool]:
    features = {word: word in feature_words for word in paragraph}
    return features


feature_data = [
    (define_features(paragraph, tell_words), label)
    for paragraph, label in labelled_data
]

# split into test and training
train_data = feature_data[:1400]
test_data = feature_data[1400:]

print("test data sample:\n", test_data[0:10])
# Out:
# test data sample:
#  [({'a': False, 'Fairmount': False, 'will': False, ',': False, 'to': False, 'because': False, 'very': False, 'Commission': False, 'Washington': False, 'in': False, 'signs': False, 'Square': False, 'some': False, 'road': False, 'good': False, 'responsible': False, 'is': False, "it's": False, 'my': False, 'start': False, 'Park': False, 'on': False, 'two': False, 'atmosphere': False, 'doubt': False, 'but': False, 'proposals': False, 'The': False, 'of': False, 'seem': False, 'may': False, 'people': False, 'ideological': False, 'small': False, 'posted': False, 'no': False, 'for': False, 'change': False, 'it': False, 'thing': False, 'has': False, ':': False, 'know': False, 'approve': False, 'matter': False, 'the': False, 'saying': False, 'I': False, '.': False, 'Totalitarianism': False}, 'editorial'), ({'nor': False, 'neither': False, 'wage': False, 'reflecting': False, 'talks': False, 'circles': False, 'dear': False, 'certainly': False, 'peace': True, 'Washington': False, 'listeners': False, 'great': False, 'Pentagon': False, 'have': False, 'opinions': False, 'war': True, 'Well': False, "''": False, 'forces': False, 'of': False, 'eliminate': False, 'as': False, 'point': False, 'over': False, 'no': False, 'position': False, 'knows': False, 'negotiations': False, 'friction': False, 'will': False, 'there': False, 'all': False, 'Kennedy': False, 'West': False, 'conventional': False, 'despite': False, 'A': False, 'they': False, 'political': True, 'Berlin': False, "Kennedy's": False, 'this': False, 'ones': False, 'Bonn': False, 'the': False, 'between': False, '.': False, 'are': False, ',': False, 'to': False, "President's": False, 'speech': False, 'In': False, 'be': False, 'cross': False, 'come': False, 'ready': False, 'currents': False, 'real': False, 'Whenever': False, 'shouting': False, 'nuclear': True, 'for': False, 'treaty': False, 'better': False, 'were': False, 'pressure': False, '``': False, 'always': False, 'and': False, 'struggle': False, 'clique': False, 'in': False, 'senseless': False, 'some': False, 'from': False, 'them': False, 'behind': False, 'is': False, 'advisers': False, 'not': False, 'sensible': False, 'really': False, 'economic': False, 'succumbed': False}, 'fiction'), ({'a': False, 'job': False, 'Secretary': False, 'to': False, 'Betting': False, 'now': False, 'prognosticator': False, 'be': False, 'undertaking': False, 'he': False, 'that': False, 'willing': False, 'risk': False, 'requires': False, 'hazardous': False, 'is': False, 'even': False, 'But': False, 'men': False, 'unemployment': False, 'of': False, 'his': False, 'as': False, 'Labor': False, 'for': False, 'forecasting': False, 'specialist': False, 'the': False, 'trends': False, 'activity': False, 'economic': False, 'apparently': False, '.': False, 'reputation': False}, 'editorial'), ({',': False, 'bombs': False, 'to': False, 'Nagasaki': False, 'when': False, 'and': False, 'Inquirer': False, 'led': False, 'ago': False, 'race': False, 'in': False, 'our': False, 'arms': False, 'dropped': False, 'out': False, 'shame': False, 'To': False, 'Hiroshima': False, 'everlasting': False, 'of': False, 'editor': True, 'first': False, 'nuclear': True, 'this': False, 'sixteen': False, ':': False, '.': False, 'the': False, 'world': True, 'years': False, 'on': False, 'we': False}, 'fiction'), ({'will': False, 'much': False, 'How': False, '?': False, 'get': False, 'fallout': False, 'we': False}, 'fiction'), ({'a': False, 'question': False, 'seventh': False, 'can': False, ':': False, 'some': False, 'added': False, '7': False, 'instances': False, 'In': False, '.': False, 'be': False}, 'editorial'), ({'are': False, ',': False, 'states': True, 'How': False, 'Heaven': False, ';': False, 'in': False, 'spirit': False, 'blest': False, 'that': False, 'poor': False, 'James': False, 'kingdom': False, 'To': False, 'King': False, 'is': False, 'those': False, 'reads': False, "''": False, 'Bible': False, 'of': False, 'The': False, 'theirs': False, 'they': False, 'heaven': False, 'illustrate':  ...

# %% [markdown]
# - Now that the data has been cleaned and converted to the required input
#   format we can classify it
# - Here we train an `nltk.NaiveBayesClassifier` on the training set, and
#   then assess it’s effectiveness on the test data

# %%
import itertools
import random

import nltk
from nltk.corpus import brown, stopwords
from typing import Sequence

tell_words = {
    "american",
    "city",
    "congress",
    "country",
    "county",
    "editor",
    "fact",
    "government",
    "national",
    "nuclear",
    "party",
    "peace",
    "political",
    "power",
    "president",
    "public",
    "state",
    "states",
    "united",
    "war",
    "washington",
    "world",
    "big",
    "church",
    "every",
    "eyes",
    "face",
    "felt",
    "found",
    "god",
    "hand",
    "head",
    "home",
    "house",
    "knew",
    "moment",
    "night",
    "room",
    "seemed",
    "stood",
    "think",
    "though",
    "thought",
    "told",
    "voice",
}

# Load the data
english_stopwords = stopwords.words("english")
editorial_paragraphs = brown.paras(categories="editorial")  # load editorial paragraphs
fiction_paragraphs = brown.paras(categories="fiction")  # load only fiction paragraphs


# clean the data
def flatten(paragraph: Sequence[Sequence[str]]) -> Set[str]:
    return {word for sentence in paragraph for word in sentence}


editorial_paragraphs_flattened = [
    flatten(paragraph) for paragraph in editorial_paragraphs
]
fiction_paragraphs_flattened = [flatten(paragraph) for paragraph in fiction_paragraphs]

# Label the data
editorial_paragraphs_labelled = itertools.product(
    editorial_paragraphs_flattened, ("editorial",)
)
fiction_paragraphs_labelled = itertools.product(
    editorial_paragraphs_flattened, ("fiction",)
)
labelled_data = list(
    itertools.chain(editorial_paragraphs_labelled, fiction_paragraphs_labelled)
)
random.shuffle(labelled_data)


# create the feature sets
def define_features(paragraph: Set[str], feature_words: Set[str]) -> dict[str, bool]:
    features = {word: word in feature_words for word in paragraph}
    return features


feature_data = [
    (define_features(paragraph, tell_words), label)
    for paragraph, label in labelled_data
]

# split into test and training
train_data = feature_data[:1400]
test_data = feature_data[1400:]

# train and test the model
bayes = nltk.NaiveBayesClassifier.train(train_data)  # Train the model
print(bayes.classify(train_data[0][0]))  # classify a training set paragraph

print(
    "Which features (tell words) were assessed to be the most significant indicators?"
)
bayes.show_most_informative_features()

print("Accuracy:", nltk.classify.accuracy(bayes, test_data))  # Assess the accuracy
# Out:
# editorial
# Which features (tell words) were assessed to be the most significant indicators?
# Most Informative Features
#                     stop = False          editor : fictio =      5.1 : 1.0
#                       60 = False          editor : fictio =      3.7 : 1.0
#                   Carvey = False          editor : fictio =      3.7 : 1.0
#                       H. = False          editor : fictio =      3.1 : 1.0
#                      Red = False          editor : fictio =      3.1 : 1.0
#                   figure = False          editor : fictio =      3.1 : 1.0
#                  follows = False          editor : fictio =      3.1 : 1.0
#                generally = False          editor : fictio =      3.1 : 1.0
#                  opposed = False          editor : fictio =      3.1 : 1.0
#                  revenue = False          editor : fictio =      3.1 : 1.0
# Accuracy: 0.14521452145214522

# %% [markdown]
# - The model should perform better than a 50 / 50 guess
#   - Obviously we could use a wider set of features rather than just the
#     presence of certain words
# - For more advanced natural language work with NLTK consider the [Online
#   book](https://www.nltk.org/book/) authored by the library creators
#
# ## Summary
#
# - NLTK is a specialised library for natural language processing
# - It includes sample texts and tokenizers that can be downloaded and
#   explored
# - `FreqDist` is used to explore the frequency and distribution of words
#   in a text
# - `Text` provides methods for introspection on the contents of a text
# - NLTK provides built-in support for classifiers that can be used to
#   train models to categorise text
#
# ## Questions and Answers
#
# 1.  How would you load the text *Emma* by Jane Austen as words,
#     sentences and paragraphs?
#
#     - First we need to identify the name of the text by using `fileids`
#
#       ``` python
#          from nltk.corpus import gutenberg
#
#          gutenberg.fileids()
#       ```
#
#           ['austen-emma.txt',
#            'austen-persuasion.txt',
#            'austen-sense.txt',
#            'bible-kjv.txt',
#            'blake-poems.txt',
#            'bryant-stories.txt',
#            'burgess-busterbrown.txt',
#            'carroll-alice.txt',
#            'chesterton-ball.txt',
#            'chesterton-brown.txt',
#            'chesterton-thursday.txt',
#            'edgeworth-parents.txt',
#            'melville-moby_dick.txt',
#            'milton-paradise.txt',
#            'shakespeare-caesar.txt',
#            'shakespeare-hamlet.txt',
#            'shakespeare-macbeth.txt',
#            'whitman-leaves.txt']
#
#       - We can then load words
#
#         ``` python
#          from nltk.corpus import gutenberg
#
#          emma_words = gutenberg.words("austen-emma.txt")
#          emma_words
#         ```
#
#             ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', ...]
#
#       - Sentences
#
#         ``` python
#          from nltk.corpus import gutenberg
#
#          emma_sentences = gutenberg.sents("austen-emma.txt")
#          emma_sentences
#         ```
#
#             [['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']'], ['VOLUME', 'I'], ...]
#
#       - Paragraphs
#
#         ``` python
#             from nltk.corpus import gutenberg
#
#             emma_paragraphs = gutenberg.paras("austen-emma.txt")
#             emma_paragraphs
#         ```
#
#             [[['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']']], [['VOLUME', 'I']], ...]
#
# 2.  Count the occurrences of the word Alice in *Alice in Wonderland* by
#     Lewis Carroll
#
#     - Again first load the dataset
#
#       ``` python
#          from nltk.corpus import gutenberg
#
#          alice_words = gutenberg.words("carroll-alice.txt")
#       ```
#
#     - Then we want to apply a `FreqDist` to this and access the `Alice`
#       key
#
#       ``` python
#         import nltk
#         alice_dist = nltk.FreqDist(alice_words)
#
#         print("Alice appears", alice_dist["Alice"], "times in Alice in Wonderland by Lewis Carroll")
#       ```
#
#           Alice appears 396 times in Alice in Wonderland by Lewis Carroll
#
# 3.  Use tabulate to view the top 10 words in *Alice in Wonderland*,
#     excluding punctuation and stop words
#
#     - We can repeat the process from before
#
#     - First we use `string.punctuation` to remove punctuation
#
#     - Then we load the `stopwords` corpus to remove stop words
#
#     - Finally we create our `FreqDist` and call `tabulate`
#
#       ``` python
#          import string
#
#          import nltk
#          from nltk.corpus import gutenberg, stopwords
#
#          alice = gutenberg.words("carroll-alice.txt")
#
#          # filter out punctuation
#          alice_filtered = [word for word in alice if word not in string.punctuation]
#
#          # filter out stopwords
#          english_stopwords = stopwords.words("english")
#          alice_filtered = [word for word in alice_filtered if word.lower() not in english_stopwords]
#
#          alice_dist = nltk.FreqDist(alice_filtered)
#          alice_dist.tabulate(10)
#       ```
#
#             said     ,'  Alice     !'     .'     ?'     -- little    one   know
#              456    397    396    278    187    154    140    125     94     87
#
# 4.  Find words that are similar to “rabbit” in *Alice in Wonderland*
#
#     - First we need to load the text into a `Text` object
#
#     - We can then call the `similar` method
#
#       ``` python
#          import nltk
#          from nltk.corpus import gutenberg
#          from nltk.text import Text
#
#          alice = gutenberg.words("carroll-alice.txt")
#          alice_text = Text(alice)
#          print("Words similar to 'rabbit' in Alice in Wonderland are:")
#          alice_text.similar("rabbit")
#       ```
#
#           Words similar to 'rabbit' in Alice in Wonderland are:
#           king duchess caterpillar queen hatter dormouse gryphon cat mouse other
#           game jury well way question hall door table key pool
#
# 5.  Use the corpus `names` to find the ten most frequently occurring
#     names in *Hamlet*
#
#     - This is a slightly more involved example
#
#     - First we have to download the `names` corpus
#
#       ``` python
#          import nltk
#
#          nltk.download("names")
#
#          from nltk.corpus import names
#
#          male_names = names.words("male.txt")
#          print("First ten male names:\n", male_names[:10])
#
#          female_names = names.words("female.txt")
#          print("First ten female names:\n", female_names[:10])
#       ```
#
#           First ten male names:
#            ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
#           First ten female names:
#            ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']
#
#           [nltk_data] Downloading package names to /home/runner/nltk_data...
#           [nltk_data]   Package names is already up-to-date!
#
#     - We can then load the data set and retain only valid names
#
#     - Then simply report the ten most common via `FreqDist`
#
#       ``` python
#          from nltk import gutenberg
#
#          hamlet_words = gutenberg.words("shakespeare-hamlet")
#
#          hamlet_words_filtered = [name for word in hamlet_words if (name := word.capitalize()) in male_names or name in female_names]
#
#          hamlet_name_dist = nltk.FreqDist(hamelet_words_filtered)
#          hamlet_name_dist.most_common(10)
#       ```
#
#       <pre><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
#       <span class="ansi-red-fg">ImportError</span>                               Traceback (most recent call last)
#       <span class="ansi-cyan-fg">Cell</span><span class="ansi-cyan-fg"> </span><span class="ansi-green-fg">In[31]</span><span class="ansi-green-fg">, line 1</span>
#       <span class="ansi-green-fg">----&gt; </span><span class="ansi-green-fg">1</span> <span style="font-weight:bold;color:rgb(0,135,0)">from</span> nltk <span style="font-weight:bold;color:rgb(0,135,0)">import</span> gutenberg
#       <span class="ansi-green-fg">      2</span>
#       <span class="ansi-green-fg">      3</span> hamlet_words = gutenberg.words(<span class="ansi-yellow-fg">"shakespeare-hamlet"</span>)
#       <span class="ansi-green-fg">      4</span>
#
#       <span class="ansi-red-fg">ImportError</span>: cannot import name 'gutenberg' from 'nltk' (/home/runner/work/foundational-data-science-for-python/foundational-data-science-for-python/.venv/lib/python3.14/site-packages/nltk/__init__.py)</pre>
#
# We’ve recreated the above answers below as complete cells so you can
# interact with them in the notebook

# %%
from nltk.corpus import gutenberg

print("Question 1")

emma_words = gutenberg.words("austen-emma.txt")
print("First 10 words:", emma_words[:10])

emma_sentences = gutenberg.sents("austen-emma.txt")
print("First two sentences:", emma_sentences[:2])

emma_paragraphs = gutenberg.paras("austen-emma.txt")
print("First paragraph:", emma_paragraphs[0])
# Out:
# Question 1
# First 10 words: ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER']
# First two sentences: [['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']'], ['VOLUME', 'I']]
# First paragraph: [['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']']]

# %%
import string

import nltk
from nltk.corpus import gutenberg, stopwords
from nltk.text import Text


print("Question 2")
alice_words = gutenberg.words("carroll-alice.txt")
alice_dist = nltk.FreqDist(alice_words)

print(
    "Alice appears",
    alice_dist["Alice"],
    "times in Alice in Wonderland by Lewis Carroll",
)


print("Question 3")

# filter out punctuation
alice_filtered = [word for word in alice if word not in string.punctuation]

# filter out stopwords
english_stopwords = stopwords.words("english")
alice_filtered = [
    word for word in alice_filtered if word.lower() not in english_stopwords
]

caesar_dist = nltk.FreqDist(caesar_filtered)
caesar_dist.tabulate(10)

print("Question 4")

alice = gutenberg.words("carroll-alice.txt")
alice_text = Text(alice)
print(
    "Words similar to 'rabbit' in Alice in Wonderland are:\n",
    alice_text.similar("rabbit"),
)
# Out:
# Question 2
# Alice appears 396 times in Alice in Wonderland by Lewis Carroll
# Question 3
#  Caesar  Brutus     Bru    haue   shall   Cassi    thou Cassius  Antony    know
#     189     161     153     128     107     107     100      85      75      66
# Question 4
# king duchess caterpillar queen hatter dormouse gryphon cat mouse other
# game jury well way question hall door table key pool
# Words similar to 'rabbit' in Alice in Wonderland are:
#  None

# %%
import nltk
from nltk.corpus import gutenberg, names


male_names = names.words("male.txt")
female_names = names.words("female.txt")

hamlet_words = gutenberg.words("shakespeare-hamlet")

hamlet_words_filtered = [
    name
    for word in hamlet_words
    if (name := word.capitalize()) in male_names or name in female_names
]

hamlet_name_dist = nltk.FreqDist(hamelet_words_filtered)
hamlet_name_dist.most_common(10)
